# %%
# Data Manipulation and Preparation
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# PyTorch
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# Evaluation metrics and visualisation
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Ensure GPU usage
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

import itertools
import time
import csv
# Out:
# Using device: cuda

# %%
# Load cleaned dataset
df = pd.read_csv('btc_1h_spot_prem_combined.csv', parse_dates=['open_time'])

# %%
df.columns
# Out:
# Index(['open_time', 'open_spot', 'high_spot', 'low_spot', 'close_spot',
#        'volume_spot', 'close_time', 'quote_volume_spot', 'trade_count_spot',
#        'taker_buy_base_spot', 'taker_buy_quote_spot', 'open_premium',
#        'high_premium', 'low_premium', 'close_premium'],
#       dtype='object')

# %%
spot_simple_features = [
    'open_spot',
    'high_spot',
    'low_spot',
    'close_spot',
    'volume_spot'
]

premium_features = [
    'open_premium',
    'high_premium',
    'low_premium',
    'close_premium'
]

# %%
merged_features = spot_simple_features + premium_features

# %%
df.isnull().sum()
# Out:
# open_time               0
# open_spot               0
# high_spot               0
# low_spot                0
# close_spot              0
# volume_spot             0
# close_time              0
# quote_volume_spot       0
# trade_count_spot        0
# taker_buy_base_spot     0
# taker_buy_quote_spot    0
# open_premium            0
# high_premium            0
# low_premium             0
# close_premium           0
# dtype: int64

# %%
print("Date Range:", df['open_time'].min(), "to", df['open_time'].max())
# Out:
# Date Range: 2020-01-01 00:00:00 to 2024-04-30 00:00:00

# %%
pd.set_option('display.float_format', '{:.6f}'.format)

# %%
merged_features
# Out:
# ['open_spot',
#  'high_spot',
#  'low_spot',
#  'close_spot',
#  'volume_spot',
#  'open_premium',
#  'high_premium',
#  'low_premium',
#  'close_premium']

# %%
# Function to create sequences
def create_sequences(data, target, window_size):
    sequences = []
    labels = []
    for i in range(len(data) - window_size):
        seq = data[i:i + window_size]
        label = target[i + window_size]
        sequences.append(seq)
        labels.append(label)
    return np.array(sequences), np.array(labels)

class LSTMModel(nn.Module):
    def __init__(self, input_dim, lstm_dim, dense_dim, output_dim, num_layers=1, dropout=0.0, activation_function=nn.ReLU):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_dim, lstm_dim, num_layers=num_layers, batch_first=True, dropout=(dropout if num_layers > 1 else 0))
        self.fc1 = nn.Linear(lstm_dim, dense_dim)
        self.activation = activation_function()
        self.fc2 = nn.Linear(dense_dim, output_dim)
    
    def forward(self, x):
        x, _ = self.lstm(x)
        x = x[:, -1, :] 
        x = self.fc1(x)
        x = self.activation(x)
        x = self.fc2(x)
        return x

def train_and_evaluate(data, target_column, window_size=10, lstm_dim=50, dense_dim=50, num_layers=1, dropout=0.0, lr=0.001, batch_size=64, num_epochs=1000, optimizer_type='Adam', patience=10, activation_function=nn.ReLU):
    # Clear CUDA cache
    torch.cuda.empty_cache()
    
    # Prepare data
    X = data.values
    y = data[target_column].values.reshape(-1, 1)  # Reshape y to match scaler's expected input

    scaler_X = MinMaxScaler()
    X_scaled = scaler_X.fit_transform(X)

    scaler_y = MinMaxScaler()
    y_scaled = scaler_y.fit_transform(y)

    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, shuffle=False)
    X_train_seq, y_train_seq = create_sequences(X_train, y_train, window_size)
    X_test_seq, y_test_seq = create_sequences(X_test, y_test, window_size)

    X_train_tensor = torch.tensor(X_train_seq, dtype=torch.float32).to(device)
    X_test_tensor = torch.tensor(X_test_seq, dtype=torch.float32).to(device)
    y_train_tensor = torch.tensor(y_train_seq, dtype=torch.float32).view(-1, 1).to(device)
    y_test_tensor = torch.tensor(y_test_seq, dtype=torch.float32).view(-1, 1).to(device)

    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

    train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

    # Model parameters
    input_dim = X_train_tensor.shape[2]
    output_dim = 1

    model = LSTMModel(input_dim, lstm_dim, dense_dim, output_dim, num_layers, dropout, activation_function).to(device)

    # Define loss
    criterion = nn.MSELoss()
    
    # Select optimizer
    if optimizer_type == 'Adam':
        optimizer = optim.Adam(model.parameters(), lr=lr)
    elif optimizer_type == 'RMSprop':
        optimizer = optim.RMSprop(model.parameters(), lr=lr)
    elif optimizer_type == 'SGD':
        optimizer = optim.SGD(model.parameters(), lr=lr)
    elif optimizer_type == 'SGD with Momentum':
        optimizer = optim.SGD(model.parameters(), lr=lr, momentum=0.9)
    elif optimizer_type == 'AdamW':
        optimizer = optim.AdamW(model.parameters(), lr=lr)
    else:
        raise ValueError("Unsupported optimizer type")

    # Training loop
    best_loss = float('inf')
    patience_counter = 0
    start_time = time.time()
    
    for epoch in range(num_epochs):
        model.train()
        for inputs, labels in train_loader:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for inputs, labels in test_loader:
                outputs = model(inputs)
                val_loss += criterion(outputs, labels).item()
        
        val_loss /= len(test_loader)
        
        if val_loss < best_loss:
            best_loss = val_loss
            patience_counter = 0
            torch.save(model.state_dict(), 'best_model.pth')
        else:
            patience_counter += 1
            if patience_counter >= patience:
                break

    training_time = time.time() - start_time

    model.load_state_dict(torch.load('best_model.pth'))

    # Evaluate the model
    model.eval()
    evaluation_start_time = time.time()
    with torch.no_grad():
        train_predictions = model(X_train_tensor).cpu().numpy()
        test_predictions = model(X_test_tensor).cpu().numpy()

        # Inverse transform predictions and actual values
        train_predictions_inverse = scaler_y.inverse_transform(train_predictions)
        test_predictions_inverse = scaler_y.inverse_transform(test_predictions)
        y_train_inverse = scaler_y.inverse_transform(y_train_seq)
        y_test_inverse = scaler_y.inverse_transform(y_test_seq)

        train_mse = mean_squared_error(y_train_inverse, train_predictions_inverse)
        test_mse = mean_squared_error(y_test_inverse, test_predictions_inverse)
        train_mae = mean_absolute_error(y_train_inverse, train_predictions_inverse)
        test_mae = mean_absolute_error(y_test_inverse, test_predictions_inverse)
        train_rmse = np.sqrt(train_mse)
        test_rmse = np.sqrt(test_mse)
        train_r2 = r2_score(y_train_inverse, train_predictions_inverse)
        test_r2 = r2_score(y_test_inverse, test_predictions_inverse)
        
        # Calculate accuracy-like metric with tighter threshold
        def calculate_accuracy(y_true, y_pred, percentage=0.01):
            range_y = y_true.max() - y_true.min()
            threshold = percentage * range_y
            diff = np.abs(y_true - y_pred)
            accuracy = np.mean(diff < threshold)
            return accuracy

        train_acc = calculate_accuracy(y_train_inverse, train_predictions_inverse)
        test_acc = calculate_accuracy(y_test_inverse, test_predictions_inverse)

    evaluation_time = time.time() - evaluation_start_time

    result = {
        "window_size": window_size,
        "lstm_dim": lstm_dim,
        "num_layers": num_layers,
        "dense_dim": dense_dim,
        "dropout": dropout,
        "lr": lr,
        "batch_size": batch_size,
        "num_epochs": num_epochs,
        "optimizer_type": optimizer_type,
        "activation_function": activation_function.__name__,
        "train_mse": train_mse,
        "test_mse": test_mse,
        "train_mae": train_mae,
        "test_mae": test_mae,
        "train_rmse": train_rmse,
        "test_rmse": test_rmse,
        "train_r2": train_r2,
        "test_r2": test_r2,
        "train_acc": train_acc,
        "test_acc": test_acc,
        "training_time": training_time,
        "evaluation_time": evaluation_time,
        "patience": patience  
    }

    # Save result to a CSV file
    with open('results_btc_merged1.csv', 'a', newline='') as f:
        writer = csv.DictWriter(f, fieldnames=result.keys())
        if f.tell() == 0:
            writer.writeheader()
        writer.writerow(result)

    # Print summary of the results
    print(f"Finished model with parameters: {param_dict}")
    print(f"Results: Train MSE: {train_mse:.4f}, Test MSE: {test_mse:.4f}, Train MAE: {train_mae:.4f}, Test MAE: {test_mae:.4f}")
    print(f"Train RMSE: {train_rmse:.4f}, Test RMSE: {test_rmse:.4f}, Train R2: {train_r2:.4f}, Test R2: {test_r2:.4f}")
    print(f"Train Accuracy: {train_acc:.4f}, Test Accuracy: {test_acc:.4f}")
    print(f"Training Time: {training_time:.4f} seconds, Evaluation Time: {evaluation_time:.4f} seconds\n")

    return result

# %%
import winsound

# Added activation functions to the parameter space
parameter_space = {
    'window_size': [24],
    'lstm_dim': [96, 128, 150],
    'dense_dim': [96, 128, 150],
    'num_layers': [1],
    'dropout': [0.001, 0.01],
    'lr': [0.0001, 0.00005],
    'batch_size': [64],
    'optimizer_type': ['Adam'],
    'patience': [24, 32],
    'activation_function': [nn.ReLU, nn.Tanh]
}

# Use all features
all_features = ['open_spot', 'high_spot', 'low_spot', 'volume_spot', 'open_premium', 'high_premium', 'low_premium', 'close_premium']
data_subset = df[all_features + ['close_spot']]

# Grid search
for params in itertools.product(*parameter_space.values()):
    param_dict = dict(zip(parameter_space.keys(), params))
    print(f"Running model with parameters: {param_dict}")
    train_and_evaluate(data=data_subset, target_column='close_spot', **param_dict)



def play_beep():
    duration = 1000
    freq = 440
    winsound.Beep(freq, duration)

play_beep()
# Out:
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 66765.4531, Test MSE: 62231.8305, Train MAE: 144.6301, Test MAE: 140.0773
# Train RMSE: 258.3901, Test RMSE: 249.4631, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9654, Test Accuracy: 0.9465
# Training Time: 107.3452 seconds, Evaluation Time: 0.3320 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 65047.2328, Test MSE: 60130.9685, Train MAE: 146.6444, Test MAE: 139.3223
# Train RMSE: 255.0436, Test RMSE: 245.2162, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9674, Test Accuracy: 0.9470
# Training Time: 196.0909 seconds, Evaluation Time: 0.3222 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 66658.9322, Test MSE: 60964.6385, Train MAE: 153.6613, Test MAE: 139.4214
# Train RMSE: 258.1839, Test RMSE: 246.9102, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9664, Test Accuracy: 0.9459
# Training Time: 187.7977 seconds, Evaluation Time: 0.4121 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 65302.4024, Test MSE: 60746.9503, Train MAE: 141.1797, Test MAE: 138.6795
# Train RMSE: 255.5433, Test RMSE: 246.4690, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9664, Test Accuracy: 0.9466
# Training Time: 128.4434 seconds, Evaluation Time: 0.4245 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 72940.5762, Test MSE: 70248.3982, Train MAE: 150.3447, Test MAE: 148.3674
# Train RMSE: 270.0751, Test RMSE: 265.0441, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9613, Test Accuracy: 0.9387
# Training Time: 143.1627 seconds, Evaluation Time: 0.3435 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 64717.8690, Test MSE: 60457.9954, Train MAE: 140.9181, Test MAE: 138.3829
# Train RMSE: 254.3971, Test RMSE: 245.8821, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9671, Test Accuracy: 0.9457
# Training Time: 253.8074 seconds, Evaluation Time: 0.4327 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 66022.4053, Test MSE: 61600.6659, Train MAE: 142.4985, Test MAE: 140.1845
# Train RMSE: 256.9483, Test RMSE: 248.1948, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9660, Test Accuracy: 0.9449
# Training Time: 254.2318 seconds, Evaluation Time: 0.4635 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 64753.2373, Test MSE: 60269.2424, Train MAE: 142.4900, Test MAE: 138.0093
# Train RMSE: 254.4666, Test RMSE: 245.4979, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9671, Test Accuracy: 0.9461
# Training Time: 260.2171 seconds, Evaluation Time: 0.3405 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 69245.6104, Test MSE: 61489.7514, Train MAE: 161.5825, Test MAE: 139.4429
# Train RMSE: 263.1456, Test RMSE: 247.9713, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9654, Test Accuracy: 0.9459
# Training Time: 110.5403 seconds, Evaluation Time: 0.4197 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 65949.6706, Test MSE: 60847.8707, Train MAE: 146.0301, Test MAE: 138.9668
# Train RMSE: 256.8067, Test RMSE: 246.6736, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9661, Test Accuracy: 0.9463
# Training Time: 129.7128 seconds, Evaluation Time: 0.3894 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 64366.6080, Test MSE: 60268.7391, Train MAE: 141.6668, Test MAE: 138.1706
# Train RMSE: 253.7058, Test RMSE: 245.4969, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9672, Test Accuracy: 0.9461
# Training Time: 195.4241 seconds, Evaluation Time: 0.3279 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 64624.9004, Test MSE: 60093.8567, Train MAE: 140.2672, Test MAE: 138.1805
# Train RMSE: 254.2143, Test RMSE: 245.1405, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9666, Test Accuracy: 0.9469
# Training Time: 219.3798 seconds, Evaluation Time: 0.3915 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 65421.7203, Test MSE: 61047.7586, Train MAE: 141.6755, Test MAE: 139.5866
# Train RMSE: 255.7767, Test RMSE: 247.0784, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9663, Test Accuracy: 0.9463
# Training Time: 292.1000 seconds, Evaluation Time: 0.3900 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 68300.6728, Test MSE: 62969.0675, Train MAE: 145.4426, Test MAE: 139.8979
# Train RMSE: 261.3440, Test RMSE: 250.9364, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9637, Test Accuracy: 0.9465
# Training Time: 155.7608 seconds, Evaluation Time: 0.4648 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 66494.2668, Test MSE: 63022.9575, Train MAE: 146.2870, Test MAE: 142.6618
# Train RMSE: 257.8648, Test RMSE: 251.0437, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9657, Test Accuracy: 0.9428
# Training Time: 289.4433 seconds, Evaluation Time: 0.3926 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 65327.5636, Test MSE: 60675.2902, Train MAE: 142.0360, Test MAE: 138.4576
# Train RMSE: 255.5926, Test RMSE: 246.3235, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9663, Test Accuracy: 0.9470
# Training Time: 178.8164 seconds, Evaluation Time: 0.3779 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 66669.3946, Test MSE: 61351.4344, Train MAE: 150.3287, Test MAE: 140.1391
# Train RMSE: 258.2042, Test RMSE: 247.6922, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9661, Test Accuracy: 0.9455
# Training Time: 162.7437 seconds, Evaluation Time: 0.3895 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 64772.3827, Test MSE: 60255.4112, Train MAE: 142.0669, Test MAE: 138.3254
# Train RMSE: 254.5042, Test RMSE: 245.4698, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9669, Test Accuracy: 0.9470
# Training Time: 186.5742 seconds, Evaluation Time: 0.3575 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 65310.8007, Test MSE: 60585.1662, Train MAE: 149.4787, Test MAE: 139.0926
# Train RMSE: 255.5598, Test RMSE: 246.1405, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9672, Test Accuracy: 0.9461
# Training Time: 226.9077 seconds, Evaluation Time: 0.4755 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 65579.2519, Test MSE: 61102.8669, Train MAE: 142.6592, Test MAE: 139.0861
# Train RMSE: 256.0845, Test RMSE: 247.1899, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9662, Test Accuracy: 0.9458
# Training Time: 130.3852 seconds, Evaluation Time: 0.3715 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 65598.3854, Test MSE: 61425.4054, Train MAE: 142.4137, Test MAE: 140.6342
# Train RMSE: 256.1218, Test RMSE: 247.8415, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9660, Test Accuracy: 0.9446
# Training Time: 268.9681 seconds, Evaluation Time: 0.3703 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 67869.7381, Test MSE: 61597.0862, Train MAE: 151.9902, Test MAE: 139.1758
# Train RMSE: 260.5182, Test RMSE: 248.1876, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9652, Test Accuracy: 0.9482
# Training Time: 141.7922 seconds, Evaluation Time: 0.4171 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 67098.1465, Test MSE: 62303.2124, Train MAE: 144.8572, Test MAE: 139.7115
# Train RMSE: 259.0331, Test RMSE: 249.6061, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9648, Test Accuracy: 0.9453
# Training Time: 201.5610 seconds, Evaluation Time: 0.3672 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 64007.9226, Test MSE: 59760.5493, Train MAE: 140.4700, Test MAE: 137.7668
# Train RMSE: 252.9979, Test RMSE: 244.4597, Train R2: 0.9998, Test R2: 0.9997
# Train Accuracy: 0.9675, Test Accuracy: 0.9477
# Training Time: 367.5017 seconds, Evaluation Time: 0.4401 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 67398.5971, Test MSE: 61957.4827, Train MAE: 151.1599, Test MAE: 141.7115
# Train RMSE: 259.6124, Test RMSE: 248.9126, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9655, Test Accuracy: 0.9451
# Training Time: 132.7812 seconds, Evaluation Time: 0.3684 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 65212.8483, Test MSE: 60453.0510, Train MAE: 141.6472, Test MAE: 139.2073
# Train RMSE: 255.3681, Test RMSE: 245.8720, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9662, Test Accuracy: 0.9459
# Training Time: 129.4418 seconds, Evaluation Time: 0.3833 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 65416.3540, Test MSE: 60730.4474, Train MAE: 146.8376, Test MAE: 139.0239
# Train RMSE: 255.7662, Test RMSE: 246.4355, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9666, Test Accuracy: 0.9461
# Training Time: 194.2135 seconds, Evaluation Time: 0.3265 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 63838.3921, Test MSE: 59715.6900, Train MAE: 139.7198, Test MAE: 137.6014
# Train RMSE: 252.6626, Test RMSE: 244.3679, Train R2: 0.9998, Test R2: 0.9997
# Train Accuracy: 0.9676, Test Accuracy: 0.9475
# Training Time: 282.9259 seconds, Evaluation Time: 0.5343 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 67106.9991, Test MSE: 62328.1502, Train MAE: 144.4753, Test MAE: 140.5226
# Train RMSE: 259.0502, Test RMSE: 249.6561, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9653, Test Accuracy: 0.9451
# Training Time: 178.8548 seconds, Evaluation Time: 0.4144 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 65435.0514, Test MSE: 60688.2267, Train MAE: 141.2747, Test MAE: 139.2929
# Train RMSE: 255.8028, Test RMSE: 246.3498, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9662, Test Accuracy: 0.9465
# Training Time: 209.8549 seconds, Evaluation Time: 0.4455 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 65690.6352, Test MSE: 60445.6721, Train MAE: 151.1882, Test MAE: 140.0088
# Train RMSE: 256.3018, Test RMSE: 245.8570, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9673, Test Accuracy: 0.9465
# Training Time: 337.5596 seconds, Evaluation Time: 0.4977 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 65196.0133, Test MSE: 60634.3242, Train MAE: 141.4699, Test MAE: 138.8657
# Train RMSE: 255.3351, Test RMSE: 246.2404, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9667, Test Accuracy: 0.9457
# Training Time: 245.0723 seconds, Evaluation Time: 0.4209 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 67931.9165, Test MSE: 63110.6191, Train MAE: 152.1810, Test MAE: 143.1983
# Train RMSE: 260.6375, Test RMSE: 251.2183, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9654, Test Accuracy: 0.9446
# Training Time: 108.2832 seconds, Evaluation Time: 0.5112 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 65769.2633, Test MSE: 61208.1176, Train MAE: 142.2502, Test MAE: 138.8973
# Train RMSE: 256.4552, Test RMSE: 247.4027, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9661, Test Accuracy: 0.9461
# Training Time: 110.3188 seconds, Evaluation Time: 0.3740 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 63999.8942, Test MSE: 60003.1351, Train MAE: 142.8226, Test MAE: 137.7681
# Train RMSE: 252.9820, Test RMSE: 244.9554, Train R2: 0.9998, Test R2: 0.9997
# Train Accuracy: 0.9675, Test Accuracy: 0.9471
# Training Time: 287.1467 seconds, Evaluation Time: 0.4040 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 65977.5208, Test MSE: 61257.9808, Train MAE: 141.8617, Test MAE: 140.5394
# Train RMSE: 256.8609, Test RMSE: 247.5035, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9658, Test Accuracy: 0.9457
# Training Time: 130.2555 seconds, Evaluation Time: 0.3900 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 69018.5845, Test MSE: 66784.2829, Train MAE: 147.4038, Test MAE: 145.6043
# Train RMSE: 262.7139, Test RMSE: 258.4266, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9639, Test Accuracy: 0.9397
# Training Time: 168.3756 seconds, Evaluation Time: 0.4130 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 65614.4932, Test MSE: 60404.0518, Train MAE: 146.3097, Test MAE: 138.5409
# Train RMSE: 256.1533, Test RMSE: 245.7724, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9665, Test Accuracy: 0.9469
# Training Time: 173.3898 seconds, Evaluation Time: 0.4006 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 66073.2753, Test MSE: 64333.8588, Train MAE: 143.2348, Test MAE: 144.5456
# Train RMSE: 257.0472, Test RMSE: 253.6412, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9660, Test Accuracy: 0.9401
# Training Time: 263.7810 seconds, Evaluation Time: 0.3649 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 64298.2553, Test MSE: 60040.0944, Train MAE: 139.7608, Test MAE: 137.8457
# Train RMSE: 253.5710, Test RMSE: 245.0308, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9670, Test Accuracy: 0.9471
# Training Time: 285.9554 seconds, Evaluation Time: 0.4059 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 65887.3678, Test MSE: 61379.8072, Train MAE: 143.0174, Test MAE: 140.7900
# Train RMSE: 256.6853, Test RMSE: 247.7495, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9661, Test Accuracy: 0.9447
# Training Time: 145.8934 seconds, Evaluation Time: 0.3984 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 67228.1742, Test MSE: 61033.9559, Train MAE: 153.2621, Test MAE: 139.6753
# Train RMSE: 259.2840, Test RMSE: 247.0505, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9659, Test Accuracy: 0.9466
# Training Time: 104.9437 seconds, Evaluation Time: 0.4268 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 65085.3250, Test MSE: 60300.2161, Train MAE: 141.8887, Test MAE: 138.9373
# Train RMSE: 255.1183, Test RMSE: 245.5610, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9666, Test Accuracy: 0.9470
# Training Time: 145.6887 seconds, Evaluation Time: 0.3979 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 63981.8134, Test MSE: 59759.0687, Train MAE: 139.9453, Test MAE: 137.9360
# Train RMSE: 252.9463, Test RMSE: 244.4567, Train R2: 0.9998, Test R2: 0.9997
# Train Accuracy: 0.9672, Test Accuracy: 0.9477
# Training Time: 230.6255 seconds, Evaluation Time: 0.4485 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 66404.9974, Test MSE: 62881.3358, Train MAE: 144.0320, Test MAE: 141.7786
# Train RMSE: 257.6917, Test RMSE: 250.7615, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9655, Test Accuracy: 0.9426
# Training Time: 186.2931 seconds, Evaluation Time: 0.3354 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 65962.1696, Test MSE: 60953.6716, Train MAE: 146.0079, Test MAE: 139.3823
# Train RMSE: 256.8310, Test RMSE: 246.8880, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9662, Test Accuracy: 0.9469
# Training Time: 175.0430 seconds, Evaluation Time: 0.4025 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 67528.1518, Test MSE: 61728.8217, Train MAE: 153.7784, Test MAE: 140.6099
# Train RMSE: 259.8618, Test RMSE: 248.4529, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9661, Test Accuracy: 0.9446
# Training Time: 211.2549 seconds, Evaluation Time: 0.3756 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 65596.8943, Test MSE: 61002.1038, Train MAE: 142.5092, Test MAE: 138.8326
# Train RMSE: 256.1189, Test RMSE: 246.9860, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9659, Test Accuracy: 0.9459
# Training Time: 178.9223 seconds, Evaluation Time: 0.3056 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 65711.4069, Test MSE: 61100.3498, Train MAE: 146.6067, Test MAE: 139.6563
# Train RMSE: 256.3424, Test RMSE: 247.1848, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9661, Test Accuracy: 0.9455
# Training Time: 116.7678 seconds, Evaluation Time: 3.5994 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 64260.1142, Test MSE: 59926.4769, Train MAE: 140.5836, Test MAE: 137.7825
# Train RMSE: 253.4958, Test RMSE: 244.7988, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9672, Test Accuracy: 0.9479
# Training Time: 176.9525 seconds, Evaluation Time: 1.6925 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 64762.7430, Test MSE: 60615.8945, Train MAE: 141.7550, Test MAE: 139.0226
# Train RMSE: 254.4853, Test RMSE: 246.2030, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9670, Test Accuracy: 0.9463
# Training Time: 162.1250 seconds, Evaluation Time: 0.7474 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 64704.4133, Test MSE: 59981.5672, Train MAE: 141.8748, Test MAE: 137.8643
# Train RMSE: 254.3706, Test RMSE: 244.9113, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9669, Test Accuracy: 0.9466
# Training Time: 135.2521 seconds, Evaluation Time: 0.5597 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 65166.9934, Test MSE: 60911.0557, Train MAE: 142.5262, Test MAE: 139.0621
# Train RMSE: 255.2783, Test RMSE: 246.8017, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9666, Test Accuracy: 0.9457
# Training Time: 237.5651 seconds, Evaluation Time: 0.7334 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 65369.4242, Test MSE: 61327.8970, Train MAE: 142.9661, Test MAE: 140.2954
# Train RMSE: 255.6744, Test RMSE: 247.6447, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9665, Test Accuracy: 0.9462
# Training Time: 170.5673 seconds, Evaluation Time: 1.0729 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 65734.9931, Test MSE: 60712.2258, Train MAE: 145.8716, Test MAE: 138.5364
# Train RMSE: 256.3884, Test RMSE: 246.3985, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9664, Test Accuracy: 0.9466
# Training Time: 230.5373 seconds, Evaluation Time: 3.7777 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 64741.3210, Test MSE: 60114.1387, Train MAE: 141.6434, Test MAE: 138.4868
# Train RMSE: 254.4432, Test RMSE: 245.1818, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9668, Test Accuracy: 0.9474
# Training Time: 263.7614 seconds, Evaluation Time: 7.8978 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 65518.8306, Test MSE: 61150.7884, Train MAE: 141.5363, Test MAE: 138.9734
# Train RMSE: 255.9665, Test RMSE: 247.2869, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9661, Test Accuracy: 0.9453
# Training Time: 134.6596 seconds, Evaluation Time: 2.9848 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 65650.2964, Test MSE: 61462.8106, Train MAE: 145.8694, Test MAE: 141.4956
# Train RMSE: 256.2231, Test RMSE: 247.9169, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9665, Test Accuracy: 0.9465
# Training Time: 112.7603 seconds, Evaluation Time: 1.9551 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 64382.7564, Test MSE: 60345.7396, Train MAE: 140.9103, Test MAE: 139.1167
# Train RMSE: 253.7376, Test RMSE: 245.6537, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9674, Test Accuracy: 0.9459
# Training Time: 222.7753 seconds, Evaluation Time: 1.9298 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# ...
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 66290.5902, Test MSE: 61055.0196, Train MAE: 146.0547, Test MAE: 139.5385
# Train RMSE: 257.4696, Test RMSE: 247.0931, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9655, Test Accuracy: 0.9457
# Training Time: 217.5945 seconds, Evaluation Time: 0.4365 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 65024.5429, Test MSE: 60529.4518, Train MAE: 140.3728, Test MAE: 138.3174
# Train RMSE: 254.9991, Test RMSE: 246.0273, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9663, Test Accuracy: 0.9466
# Training Time: 192.2703 seconds, Evaluation Time: 0.4179 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 64893.6185, Test MSE: 60748.6741, Train MAE: 141.7378, Test MAE: 139.6107
# Train RMSE: 254.7423, Test RMSE: 246.4725, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9668, Test Accuracy: 0.9462
# Training Time: 276.6627 seconds, Evaluation Time: 0.5260 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 66742.4708, Test MSE: 61184.8848, Train MAE: 148.5569, Test MAE: 139.5330
# Train RMSE: 258.3456, Test RMSE: 247.3558, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9657, Test Accuracy: 0.9467
# Training Time: 171.0346 seconds, Evaluation Time: 0.6006 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 66106.7718, Test MSE: 62136.7835, Train MAE: 144.2505, Test MAE: 140.6323
# Train RMSE: 257.1124, Test RMSE: 249.2725, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9658, Test Accuracy: 0.9450
# Training Time: 118.0503 seconds, Evaluation Time: 0.4844 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 64596.0660, Test MSE: 59935.6392, Train MAE: 142.3569, Test MAE: 137.8131
# Train RMSE: 254.1576, Test RMSE: 244.8176, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9672, Test Accuracy: 0.9478
# Training Time: 169.9670 seconds, Evaluation Time: 0.5394 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 64181.3376, Test MSE: 59907.3678, Train MAE: 141.2655, Test MAE: 137.7830
# Train RMSE: 253.3404, Test RMSE: 244.7598, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9669, Test Accuracy: 0.9470
# Training Time: 272.0053 seconds, Evaluation Time: 0.4184 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 64091.4098, Test MSE: 59703.0733, Train MAE: 139.8295, Test MAE: 137.8453
# Train RMSE: 253.1628, Test RMSE: 244.3421, Train R2: 0.9998, Test R2: 0.9997
# Train Accuracy: 0.9671, Test Accuracy: 0.9481
# Training Time: 235.9879 seconds, Evaluation Time: 0.4178 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 65533.7690, Test MSE: 60867.2912, Train MAE: 145.3169, Test MAE: 138.7326
# Train RMSE: 255.9956, Test RMSE: 246.7130, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9665, Test Accuracy: 0.9457
# Training Time: 281.8421 seconds, Evaluation Time: 0.4185 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 66331.7012, Test MSE: 61130.4590, Train MAE: 142.7461, Test MAE: 138.8280
# Train RMSE: 257.5494, Test RMSE: 247.2457, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9654, Test Accuracy: 0.9469
# Training Time: 148.7893 seconds, Evaluation Time: 0.4389 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 66301.6737, Test MSE: 61556.2106, Train MAE: 144.8567, Test MAE: 139.4054
# Train RMSE: 257.4911, Test RMSE: 248.1052, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9660, Test Accuracy: 0.9442
# Training Time: 194.2387 seconds, Evaluation Time: 0.4160 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 64389.6598, Test MSE: 59740.1784, Train MAE: 141.8017, Test MAE: 137.6434
# Train RMSE: 253.7512, Test RMSE: 244.4180, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9673, Test Accuracy: 0.9470
# Training Time: 364.4348 seconds, Evaluation Time: 0.4320 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 66479.1673, Test MSE: 61264.7514, Train MAE: 148.6640, Test MAE: 139.3530
# Train RMSE: 257.8355, Test RMSE: 247.5172, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9659, Test Accuracy: 0.9461
# Training Time: 131.3210 seconds, Evaluation Time: 0.4218 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 67636.4140, Test MSE: 61233.7484, Train MAE: 154.9066, Test MAE: 140.4931
# Train RMSE: 260.0700, Test RMSE: 247.4545, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9657, Test Accuracy: 0.9467
# Training Time: 110.6339 seconds, Evaluation Time: 0.4169 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 65523.2642, Test MSE: 61098.6595, Train MAE: 146.4745, Test MAE: 138.8646
# Train RMSE: 255.9751, Test RMSE: 247.1814, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9666, Test Accuracy: 0.9462
# Training Time: 163.6194 seconds, Evaluation Time: 0.4603 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 64313.7096, Test MSE: 59918.9923, Train MAE: 139.9725, Test MAE: 138.2220
# Train RMSE: 253.6015, Test RMSE: 244.7836, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9669, Test Accuracy: 0.9471
# Training Time: 221.5622 seconds, Evaluation Time: 0.4209 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 67392.5885, Test MSE: 63582.1280, Train MAE: 144.3160, Test MAE: 142.4134
# Train RMSE: 259.6008, Test RMSE: 252.1550, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9653, Test Accuracy: 0.9445
# Training Time: 174.1264 seconds, Evaluation Time: 0.4334 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 65754.4427, Test MSE: 60787.3835, Train MAE: 144.9514, Test MAE: 139.0667
# Train RMSE: 256.4263, Test RMSE: 246.5510, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9663, Test Accuracy: 0.9469
# Training Time: 202.4492 seconds, Evaluation Time: 0.4189 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 65507.9713, Test MSE: 61388.7093, Train MAE: 143.4487, Test MAE: 139.9729
# Train RMSE: 255.9453, Test RMSE: 247.7674, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9658, Test Accuracy: 0.9459
# Training Time: 238.1003 seconds, Evaluation Time: 0.4198 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.01, 'lr': 5e-05, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 32, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 65653.4878, Test MSE: 61226.1405, Train MAE: 141.9970, Test MAE: 139.0556
# Train RMSE: 256.2294, Test RMSE: 247.4392, Train R2: 0.9997, Test R2: 0.9997
# Train Accuracy: 0.9660, Test Accuracy: 0.9461
# Training Time: 183.0526 seconds, Evaluation Time: 0.4194 seconds
