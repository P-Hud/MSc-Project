# %%
# Data Manipulation and Preparation
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# PyTorch
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# Evaluation metrics and visualisation
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error

# Ensure GPU usage
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

import itertools
import time
import csv
import json
from IPython.display import Audio, display
import winsound
from threading import Thread
# Out:
# Using device: cuda

# %%
# Load cleaned dataset
df = pd.read_csv('BTC_1h_w_Diffs.csv', parse_dates=['open_time'])

# Convert to datetime 
df['open_time'] = pd.to_datetime(df['open_time'])
df['close_time'] = pd.to_datetime(df['close_time'])

# %%
def create_sequences(data, target, window_size):
    sequences = []
    labels = []
    for i in range(len(data) - window_size):
        seq = data[i:i + window_size]
        label = target[i + window_size]
        sequences.append(seq)
        labels.append(label)
    return np.array(sequences), np.array(labels)

def prepare_data(df, target_column, window_size, feature_columns):
    X = df[feature_columns].values
    y = df[target_column].values.reshape(-1, 1)
    
    scaler_X = MinMaxScaler()
    X_scaled = scaler_X.fit_transform(X)

    scaler_y = MinMaxScaler()
    y_scaled = scaler_y.fit_transform(y)

    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, shuffle=False)
    X_train_seq, y_train_seq = create_sequences(X_train, y_train, window_size)
    X_test_seq, y_test_seq = create_sequences(X_test, y_test, window_size)

    return X_train_seq, X_test_seq, y_train_seq, y_test_seq, scaler_y

class LSTMModel(nn.Module):
    def __init__(self, input_dim, lstm_dim, dense_dim, output_dim, num_layers=1, dropout=0.0):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_dim, lstm_dim, num_layers=num_layers, batch_first=True, dropout=dropout)
        self.fc1 = nn.Linear(lstm_dim, dense_dim)
        self.activation = nn.Tanh()
        self.fc2 = nn.Linear(dense_dim, output_dim)

    def forward(self, x):
        x, _ = self.lstm(x)
        x = x[:, -1, :]
        x = self.fc1(x)
        x = self.activation(x)
        x = self.fc2(x)
        return x

def train_and_evaluate(df, target_column, feature_columns, params, file_prefix='results', use_early_stopping=True, plot_loss=False):
    result = {} 
    try:
        # Extract parameters
        window_size = params['window_size']
        lstm_dim = params['lstm_dim']
        dense_dim = params['dense_dim']
        num_layers = params['num_layers']
        dropout = params['dropout']
        lr = params['lr']
        batch_size = params['batch_size']
        num_epochs = params['num_epochs']
        optimizer_type = params['optimizer_type']
        patience = params['patience']

        # Clear CUDA cache
        torch.cuda.empty_cache()

        # Prepare data
        X_train_seq, X_test_seq, y_train_seq, y_test_seq, scaler_y = prepare_data(df, target_column, window_size, feature_columns)

        # Convert to PyTorch tensors
        X_train_tensor = torch.tensor(X_train_seq, dtype=torch.float32).to(device)
        X_test_tensor = torch.tensor(X_test_seq, dtype=torch.float32).to(device)
        y_train_tensor = torch.tensor(y_train_seq, dtype=torch.float32).view(-1, 1).to(device)
        y_test_tensor = torch.tensor(y_test_seq, dtype=torch.float32).view(-1, 1).to(device)

        # Create data loaders
        train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
        test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
        train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
        test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

        # Model parameters
        input_dim = X_train_tensor.shape[2]
        output_dim = 1

        model = LSTMModel(input_dim, lstm_dim, dense_dim, output_dim, num_layers, dropout).to(device)

        # Define loss and optimizer
        criterion = nn.MSELoss()
        optimizer = getattr(optim, optimizer_type)(model.parameters(), lr=lr)

        # Training loop
        best_loss = float('inf')
        patience_counter = 0
        start_time = time.time()

        training_losses = []
        validation_losses = []

        for epoch in range(num_epochs):
            model.train()
            epoch_train_loss = 0
            for inputs, labels in train_loader:
                optimizer.zero_grad()
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()
                epoch_train_loss += loss.item()

            epoch_train_loss /= len(train_loader)
            training_losses.append(epoch_train_loss)

            model.eval()
            val_loss = 0
            with torch.no_grad():
                for inputs, labels in test_loader:
                    outputs = model(inputs)
                    val_loss += criterion(outputs, labels).item()

            val_loss /= len(test_loader)
            validation_losses.append(val_loss)

            # if use_early_stopping:
            #     if val_loss < best_loss:
            #         best_loss = val_loss
            #         patience_counter = 0
            #         torch.save(model.state_dict(), f'{file_prefix}_{target_column}_best_model.pth')
            #     else:
            #         patience_counter += 1
            #         if patience_counter >= patience:
            #             break

        training_time = time.time() - start_time

        # # Save the final model if early stopping was not used or not triggered
        # if not use_early_stopping or patience_counter < patience:
        #     torch.save(model.state_dict(), f'{file_prefix}_{target_column}_final_model.pth')

        # Evaluate the model
        model.eval()
        evaluation_start_time = time.time()
        with torch.no_grad():
            train_predictions = model(X_train_tensor).cpu().numpy()
            test_predictions = model(X_test_tensor).cpu().numpy()

            # Inverse transform predictions and actual values
            y_train_seq = y_train_seq.reshape(-1, 1)
            y_test_seq = y_test_seq.reshape(-1, 1)
            train_predictions_inverse = scaler_y.inverse_transform(train_predictions)
            test_predictions_inverse = scaler_y.inverse_transform(test_predictions)
            y_train_inverse = scaler_y.inverse_transform(y_train_seq)
            y_test_inverse = scaler_y.inverse_transform(y_test_seq)

            # Invert log transformation
            train_predictions_inverse = np.exp(train_predictions_inverse) - 1
            test_predictions_inverse = np.exp(test_predictions_inverse) - 1
            y_train_inverse = np.exp(y_train_inverse) - 1
            y_test_inverse = np.exp(y_test_inverse) - 1

            train_mse = mean_squared_error(y_train_inverse, train_predictions_inverse)
            test_mse = mean_squared_error(y_test_inverse, test_predictions_inverse)
            train_mae = mean_absolute_error(y_train_inverse, train_predictions_inverse)
            test_mae = mean_absolute_error(y_test_inverse, test_predictions_inverse)
            train_rmse = np.sqrt(train_mse)
            test_rmse = np.sqrt(test_mse)
            train_r2 = r2_score(y_train_inverse, train_predictions_inverse)
            test_r2 = r2_score(y_test_inverse, test_predictions_inverse)

            # train_mape = np.mean(np.abs((y_train_inverse - train_predictions_inverse) / y_train_inverse)) * 100
            # test_mape = np.mean(np.abs((y_test_inverse - test_predictions_inverse) / y_test_inverse)) * 100

            train_directional_acc = np.mean(np.sign(y_train_inverse[1:] - y_train_inverse[:-1]) == np.sign(train_predictions_inverse[1:] - train_predictions_inverse[:-1]))
            test_directional_acc = np.mean(np.sign(y_test_inverse[1:] - y_test_inverse[:-1]) == np.sign(test_predictions_inverse[1:] - test_predictions_inverse[:-1]))

        evaluation_time = time.time() - evaluation_start_time

        result = {
            "window_size": window_size,
            "lstm_dim": lstm_dim,
            "num_layers": num_layers,
            "dense_dim": dense_dim,
            "dropout": dropout,
            "lr": lr,
            "batch_size": batch_size,
            "num_epochs": num_epochs,
            "optimizer_type": optimizer_type,
            "train_mse": train_mse,
            "test_mse": test_mse,
            "train_mae": train_mae,
            "test_mae": test_mae,
            "train_rmse": train_rmse,
            "test_rmse": test_rmse,
            "train_r2": train_r2,
            "test_r2": test_r2,
            # "train_mape": train_mape,
            # "test_mape": test_mape,
            "train_directional_acc": train_directional_acc,
            "test_directional_acc": test_directional_acc,
            "training_time": training_time,
            "evaluation_time": evaluation_time,
            "patience": patience
        }

        # Save result to a CSV file
        with open(f'{file_prefix}_{target_column}.csv', 'a', newline='') as f:
            writer = csv.DictWriter(f, fieldnames=result.keys())
            if f.tell() == 0:
                writer.writeheader()  # Write header only if file is empty
            writer.writerow(result)

        # Print summary of the results
        print(f"Results: Train MAE: {train_mae:.4f}, Test MAE: {test_mae:.4f}")
        # print(f"Train MAPE: {train_mape:.4f}, Test MAPE: {test_mape:.4f}")
        print(f"Train Directional Accuracy: {train_directional_acc:.4f}, Test Directional Accuracy: {test_directional_acc:.4f}")
        print(f"Training Time: {training_time:.4f} seconds, Evaluation Time: {evaluation_time:.4f} seconds\n")

        # Plot loss over epochs if specified
        if plot_loss:
            plot_loss_over_epochs(training_losses, validation_losses, f'{file_prefix}_{target_column}', start_epoch=3)

    except Exception as e:
        print(f"An error occurred: {e}")
        # Ensure result is always defined, even in case of error
        result = {
            "window_size": window_size,
            "lstm_dim": lstm_dim,
            "num_layers": num_layers,
            "dense_dim": dense_dim,
            "dropout": dropout,
            "lr": lr,
            "batch_size": batch_size,
            "num_epochs": num_epochs,
            "optimizer_type": optimizer_type,
            "error": str(e)
        }

    return result

# %%
# Define parameter space
parameter_space = {
    'window_size': [24],
    'lstm_dim': [110, 150, 190],
    'dense_dim': [110, 150, 190],
    'num_layers': [1],
    'dropout': [0.0, 0.001],
    'lr': [0.0001, 0.0002],
    'num_epochs': [100, 150, 200],
    'batch_size': [64],
    'optimizer_type': ['Adam'],
    'patience': [24],
    'activation_function': [nn.Tanh, nn.ReLU],
}

# %%
# Define target column
target_column = ['diff']

# Define feature combination
features = ['diff_high', 'diff_low', 'high', 'low', 'close', 'diff', 'volume',
       'quote_vol', 'count', 'buy_base', 'buy_quote']

# %%
# Start total timer
start = time.time()

# Calculate total number of models
total_models = len(list(itertools.product(*parameter_space.values())))

# Initialize model counter
model_counter = 1

# Grid search
for params in itertools.product(*parameter_space.values()):
    param_dict = dict(zip(parameter_space.keys(), params))
    print(f"Running model {model_counter}/{total_models} with parameters: {param_dict}\n")
    
    # Run with fixed epochs
    print('Results:\n')
    train_and_evaluate(df, target_column=target_column, feature_columns=features, params=param_dict, file_prefix='results1.3', use_early_stopping=False, plot_loss=False)
    
    # Increment model counter
    model_counter += 1

# Calculate total time
end = time.time()
total_time = end - start

# Print the total time taken
print(f"Total time taken: {total_time} seconds")
# Out:
# Running model 1/216 with parameters: {'window_size': 24, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 140.3278, Test MAE: 137.5297
# Train Directional Accuracy: 0.5098, Test Directional Accuracy: 0.5057
# Training Time: 102.6965 seconds, Evaluation Time: 0.1617 seconds
#
# Running model 2/216 with parameters: {'window_size': 24, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 144.8942, Test MAE: 140.7704
# Train Directional Accuracy: 0.5236, Test Directional Accuracy: 0.5155
# Training Time: 102.7836 seconds, Evaluation Time: 0.1611 seconds
#
# Running model 3/216 with parameters: {'window_size': 24, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 147.2146, Test MAE: 144.5616
# Train Directional Accuracy: 0.5015, Test Directional Accuracy: 0.4989
# Training Time: 154.9811 seconds, Evaluation Time: 0.1847 seconds
#
# Running model 4/216 with parameters: {'window_size': 24, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE:
216 with parameters: {'window_size': 24, 'lstm_dim': 190, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0002, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 145.4741, Test MAE: 140.1856
# Train Directional Accuracy: 0.5141, Test Directional Accuracy: 0.5028
# Training Time: 244.1925 seconds, Evaluation Time: 0.8727 seconds
#
# Total time taken: 36878.822030067444 seconds

# %%
# Define target column
target_column = ['log_diff']

# Define feature combination
features = ['diff_log_high', 'diff_log_low', 'log_high', 'log_low', 'log_close', 'log_diff', 'volume',
       'quote_vol', 'count', 'buy_base', 'buy_quote']

# %%
# Define parameter space
parameter_space = {
    'window_size': [24],
    'lstm_dim': [110, 150, 190],
    'dense_dim': [110, 150, 190],
    'num_layers': [1],
    'dropout': [0.0, 0.001],
    'lr': [0.0001, 0.0002],
    'num_epochs': [100, 150, 200],
    'batch_size': [64],
    'optimizer_type': ['Adam'],
    'patience': [24],
    'activation_function': [nn.Tanh],
}

# %%
# Start total timer
start = time.time()

# Calculate total number of models
total_models = len(list(itertools.product(*parameter_space.values())))

# Initialize model counter
model_counter = 1

# Grid search
for params in itertools.product(*parameter_space.values()):
    param_dict = dict(zip(parameter_space.keys(), params))
    print(f"Running model {model_counter}/{total_models} with parameters: {param_dict}\n")
    
    # Run with fixed epochs
    print('Results:\n')
    train_and_evaluate(df, target_column=target_column, feature_columns=features, params=param_dict, file_prefix='results1.4', use_early_stopping=False, plot_loss=False)
    
    # Increment model counter
    model_counter += 1

# Calculate total time
end = time.time()
total_time = end - start

# Print the total time taken
print(f"Total time taken: {total_time} seconds")

# Function to play a beep sound in a loop
def play_beep():
    while not stop_beep_flag:
        winsound.Beep(2000, 600)
        time.sleep(0.7)
        
# Start the beep sound
stop_beep_flag = False
beep_thread = Thread(target=play_beep)
beep_thread.start()

# Wait for user interaction to stop the beep sound
input("Press Enter to stop the beep sound...")
stop_beep_flag = True
beep_thread.join()
print("Beep sound stopped.")
# Out:
# Running model 1/108 with parameters: {'window_size': 24, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0047, Test MAE: 0.0031
# Train Directional Accuracy: 0.5555, Test Directional Accuracy: 0.5555
# Training Time: 107.2530 seconds, Evaluation Time: 0.1703 seconds
#
# Running model 2/108 with parameters: {'window_size': 24, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0047, Test MAE: 0.0030
# Train Directional Accuracy: 0.5534, Test Directional Accuracy: 0.5480
# Training Time: 163.7408 seconds, Evaluation Time: 0.1859 seconds
#
# Running model 3/108 with parameters: {'window_size': 24, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0046, Test MAE: 0.0031
# Train Directional Accuracy: 0.5587, Test Directional Accuracy: 0.5449
# Training Time: 221.7271 seconds, Evaluation Time: 0.1882 seconds
#
# Running model 4/108 with parameters: {'window_size': 24, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0048, Test MAE: 0.0033
# Train Directional Accuracy: 0.5642, Test Directional Accuracy: 0.5623
# Training Time: 109.9792 seconds, Evaluation Time: 0.2030 seconds
#
# Running model 5/108 with parameters: {'window_size': 24, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0046, Test MAE: 0.0030
# Train Directional Accuracy: 0.5935, Test Directional Accuracy: 0.5739
# Training Time: 156.9148 seconds, Evaluation Time: 0.1902 seconds
#
# Running model 6/108 with parameters: {'window_size': 24, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0046, Test MAE: 0.0030
# Train Directional Accuracy: 0.5750, Test Directional Accuracy: 0.5278
# Training Time: 208.7017 seconds, Evaluation Time: 0.1802 seconds
#
# Running model 7/108 with parameters: {'window_size': 24, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0046, Test MAE: 0.0030
# Train Directional Accuracy: 0.5694, Test Directional Accuracy: 0.5650
# Training Time: 104.4198 seconds, Evaluation Time: 0.2312 seconds
#
# Running model 8/108 with parameters: {'window_size': 24, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0047, Test MAE: 0.0031
# Train Directional Accuracy: 0.5533, Test Directional Accuracy: 0.5434
# Training Time: 156.3083 seconds, Evaluation Time: 0.1897 seconds
#
# Running model 9/108 with parameters: {'window_size': 24, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0047, Test MAE: 0.0031
# Train Directional Accuracy: 0.5453, Test Directional Accuracy: 0.5278
# Training Time: 205.5819 seconds, Evaluation Time: 0.1726 seconds
#
# Running model 10/108 with parameters: {'window_size': 24, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0002, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0046, Test MAE: 0.0030
# Train Directional Accuracy: 0.5590, Test Directional Accuracy: 0.5473
# Training Time: 103.2199 seconds, Evaluation Time: 0.1676 seconds
#
# Running model 11/108 with parameters: {'window_size': 24, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0002, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0047, Test MAE: 0.0031
# Train Directional Accuracy: 0.6018, Test Directional Accuracy: 0.5874
# Training Time: 159.8677 seconds, Evaluation Time: 0.2017 seconds
#
# Running model 12/108 with parameters: {'window_size': 24, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0002, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0047, Test MAE: 0.0031
# Train Directional Accuracy: 0.
108 with parameters: {'window_size': 24, 'lstm_dim': 190, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0046, Test MAE: 0.0030
# Train Directional Accuracy: 0.5875, Test Directional Accuracy: 0.5645
# Training Time: 250.7800 seconds, Evaluation Time: 1.2807 seconds
#
# Running model 102/108 with parameters: {'window_size': 24, 'lstm_dim': 190, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0048, Test MAE: 0.0032
# Train Directional Accuracy: 0.5788, Test Directional Accuracy: 0.5344
# Training Time: 331.9819 seconds, Evaluation Time: 1.2962 seconds
#
# Running model 103/108 with parameters: {'window_size': 24, 'lstm_dim': 190, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0047, Test MAE: 0.0030
# Train Directional Accuracy: 0.5532, Test Directional Accuracy: 0.5596
# Training Time: 165.8340 seconds, Evaluation Time: 1.3042 seconds
#
# Running model 104/108 with parameters: {'window_size': 24, 'lstm_dim': 190, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0047, Test MAE: 0.0032
# Train Directional Accuracy: 0.5567, Test Directional Accuracy: 0.5517
# Training Time: 255.6012 seconds, Evaluation Time: 1.2580 seconds
#
# Running model 105/108 with parameters: {'window_size': 24, 'lstm_dim': 190, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0046, Test MAE: 0.0030
# Train Directional Accuracy: 0.5739, Test Directional Accuracy: 0.5549
# Training Time: 329.4560 seconds, Evaluation Time: 1.2774 seconds
#
# Running model 106/108 with parameters: {'window_size': 24, 'lstm_dim': 190, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0002, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0046, Test MAE: 0.0030
# Train Directional Accuracy: 0.5606, Test Directional Accuracy: 0.5496
# Training Time: 163.8733 seconds, Evaluation Time: 1.1963 seconds
#
# Running model 107/108 with parameters: {'window_size': 24, 'lstm_dim': 190, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0002, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0047, Test MAE: 0.0030
# Train Directional Accuracy: 0.6338, Test Directional Accuracy: 0.6322
# Training Time: 240.9680 seconds, Evaluation Time: 1.2089 seconds
#
# Running model 108/108 with parameters: {'window_size': 24, 'lstm_dim': 190, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0002, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0046, Test MAE: 0.0030
# Train Directional Accuracy: 0.5632, Test Directional Accuracy: 0.5155
# Training Time: 315.4230 seconds, Evaluation Time: 1.2679 seconds
#
# Total time taken: 21669.478563785553 seconds
# Press Enter to stop the beep sound...
# Beep sound stopped.

# %%
# Helper functions
def create_sequences(data, target, window_size):
    sequences = []
    labels = []
    for i in range(len(data) - window_size):
        seq = data[i:i + window_size]
        label = target[i + window_size]
        sequences.append(seq)
        labels.append(label)
    return np.array(sequences), np.array(labels)

def prepare_data(df, target_column, window_size, feature_columns):
    X = df[feature_columns].values
    y = df[target_column].values.reshape(-1, 1)
    
    scaler_X = MinMaxScaler()
    X_scaled = scaler_X.fit_transform(X)

    scaler_y = MinMaxScaler()
    y_scaled = scaler_y.fit_transform(y)

    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, shuffle=False)
    X_train_seq, y_train_seq = create_sequences(X_train, y_train, window_size)
    X_test_seq, y_test_seq = create_sequences(X_test, y_test, window_size)

    return X_train_seq, X_test_seq, y_train_seq, y_test_seq, scaler_y

def train_and_evaluate(df, target_column, feature_columns, params, file_prefix='results', use_early_stopping=True, plot_loss=False):
    result = {} 
    try:
        # Extract parameters
        window_size = params['window_size']
        lstm_dim = params['lstm_dim']
        dense_dim = params['dense_dim']
        num_layers = params['num_layers']
        dropout = params['dropout']
        lr = params['lr']
        batch_size = params['batch_size']
        num_epochs = params['num_epochs']
        optimizer_type = params['optimizer_type']
        patience = params['patience']
        activation_function = params['activation_function']

        # Clear CUDA cache
        torch.cuda.empty_cache()

        # Prepare data
        X_train_seq, X_test_seq, y_train_seq, y_test_seq, scaler_y = prepare_data(df, target_column, window_size, feature_columns)

        # Convert to PyTorch tensors
        X_train_tensor = torch.tensor(X_train_seq, dtype=torch.float32).to(device)
        X_test_tensor = torch.tensor(X_test_seq, dtype=torch.float32).to(device)
        y_train_tensor = torch.tensor(y_train_seq, dtype=torch.float32).view(-1, 1).to(device)
        y_test_tensor = torch.tensor(y_test_seq, dtype=torch.float32).view(-1, 1).to(device)

        # Create data loaders
        train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
        test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
        train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
        test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

        # Model parameters
        input_dim = X_train_tensor.shape[2]
        output_dim = 1

        model = LSTMModel(input_dim, lstm_dim, dense_dim, output_dim, num_layers, dropout, activation_function).to(device)

        # Define loss and optimizer
        criterion = nn.MSELoss()
        optimizer = getattr(optim, optimizer_type)(model.parameters(), lr=lr)

        # Training loop
        best_loss = float('inf')
        patience_counter = 0
        start_time = time.time()

        training_losses = []
        validation_losses = []

        for epoch in range(num_epochs):
            model.train()
            epoch_train_loss = 0
            for inputs, labels in train_loader:
                optimizer.zero_grad()
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()
                epoch_train_loss += loss.item()

            epoch_train_loss /= len(train_loader)
            training_losses.append(epoch_train_loss)

            model.eval()
            val_loss = 0
            with torch.no_grad():
                for inputs, labels in test_loader:
                    outputs = model(inputs)
                    val_loss += criterion(outputs, labels).item()

            val_loss /= len(test_loader)
            validation_losses.append(val_loss)

        training_time = time.time() - start_time

        # Evaluate the model
        model.eval()
        evaluation_start_time = time.time()
        with torch.no_grad():
            train_predictions = model(X_train_tensor).cpu().numpy()
            test_predictions = model(X_test_tensor).cpu().numpy()

            # Inverse transform predictions and actual values
            train_predictions_inverse = scaler_y.inverse_transform(train_predictions)
            test_predictions_inverse = scaler_y.inverse_transform(test_predictions)
            y_train_inverse = scaler_y.inverse_transform(y_train_seq)
            y_test_inverse = scaler_y.inverse_transform(y_test_seq)

            # Invert log transformation if the target variable was log-transformed
            if target_column.startswith('log_'):
                train_predictions_inverse = np.exp(train_predictions_inverse) - 1
                test_predictions_inverse = np.exp(test_predictions_inverse) - 1
                y_train_inverse = np.exp(y_train_inverse) - 1
                y_test_inverse = np.exp(y_test_inverse) - 1

            train_mse = mean_squared_error(y_train_inverse, train_predictions_inverse)
            test_mse = mean_squared_error(y_test_inverse, test_predictions_inverse)
            train_mae = mean_absolute_error(y_train_inverse, train_predictions_inverse)
            test_mae = mean_absolute_error(y_test_inverse, test_predictions_inverse)
            train_rmse = np.sqrt(train_mse)
            test_rmse = np.sqrt(test_mse)
            train_r2 = r2_score(y_train_inverse, train_predictions_inverse)
            test_r2 = r2_score(y_test_inverse, test_predictions_inverse)

            train_directional_acc = np.mean(np.sign(y_train_inverse[1:] - y_train_inverse[:-1]) == np.sign(train_predictions_inverse[1:] - train_predictions_inverse[:-1]))
            test_directional_acc = np.mean(np.sign(y_test_inverse[1:] - y_test_inverse[:-1]) == np.sign(test_predictions_inverse[1:] - test_predictions_inverse[:-1]))

        evaluation_time = time.time() - evaluation_start_time

        result = {
            "window_size": window_size,
            "lstm_dim": lstm_dim,
            "num_layers": num_layers,
            "dense_dim": dense_dim,
            "dropout": dropout,
            "lr": lr,
            "batch_size": batch_size,
            "num_epochs": num_epochs,
            "optimizer_type": optimizer_type,
            "train_mse": train_mse,
            "test_mse": test_mse,
            "train_mae": train_mae,
            "test_mae": test_mae,
            "train_rmse": train_rmse,
            "test_rmse": test_rmse,
            "train_r2": train_r2,
            "test_r2": test_r2,
            "train_directional_acc": train_directional_acc,
            "test_directional_acc": test_directional_acc,
            "training_time": training_time,
            "evaluation_time": evaluation_time,
            "patience": patience,
            "activation_function": activation_function.__name__
        }

        # Save result to a CSV file
        with open(f'{file_prefix}_{target_column}.csv', 'a', newline='') as f:
            writer = csv.DictWriter(f, fieldnames=result.keys())
            if f.tell() == 0:
                writer.writeheader()  # Write header only if file is empty
            writer.writerow(result)

        # Print summary of the results
        print(f"Results: Train MAE: {train_mae:.4f}, Test MAE: {test_mae:.4f}")
        print(f"Train Directional Accuracy: {train_directional_acc:.4f}, Test Directional Accuracy: {test_directional_acc:.4f}")
        print(f"Training Time: {training_time:.4f} seconds, Evaluation Time: {evaluation_time:.4f} seconds\n")

        # Plot loss over epochs if specified
        if plot_loss:
            plot_loss_over_epochs(training_losses, validation_losses, f'{file_prefix}_{target_column}', start_epoch=3)

    except Exception as e:
        print(f"An error occurred: {e}")
        result = {
            "window_size": window_size,
            "lstm_dim": lstm_dim,
            "num_layers": num_layers,
            "dense_dim": dense_dim,
            "dropout": dropout,
            "lr": lr,
            "batch_size": batch_size,
            "num_epochs": num_epochs,
            "optimizer_type": optimizer_type,
            "error": str(e)
        }

    return result

# %%
# Define parameter space
parameter_space = {
    'window_size': [24],
    'lstm_dim': [110, 150, 190],
    'dense_dim': [110, 150, 190],
    'num_layers': [1],
    'dropout': [0.0, 0.001],
    'lr': [0.0001, 0.0002],
    'num_epochs': [100, 150, 200],
    'batch_size': [64],
    'optimizer_type': ['Adam'],
    'patience': [24],
    'activation_function': [nn.Tanh, nn.ReLU],
}

# %%
# Define target column
target_column = 'log_diff'

# Define feature combination
features = ['diff_log_high', 'diff_log_low', 'log_high', 'log_low', 'log_close', 'log_diff', 'volume',
       'quote_vol', 'count', 'buy_base', 'buy_quote', 'high_p', 'low_p', 'close_p']

# %%
# Start total timer
start = time.time()

# Calculate total number of models
total_models = len(list(itertools.product(*parameter_space.values())))

# Initialize model counter
model_counter = 1

# Grid search
for params in itertools.product(*parameter_space.values()):
    param_dict = dict(zip(parameter_space.keys(), params))
    print(f"Running model {model_counter}/{total_models} with parameters: {param_dict}\n")
    
    # Run with fixed epochs
    print('Results:\n')
    train_and_evaluate(df, target_column=target_column, feature_columns=features, params=param_dict, file_prefix='results1.5', use_early_stopping=False, plot_loss=False)
    
    # Increment model counter
    model_counter += 1

# Calculate total time
end = time.time()
total_time = end - start

# Print the total time taken
print(f"Total time taken: {total_time} seconds")
# Out:
# Running model 1/216 with parameters: {'window_size': 24, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0047, Test MAE: 0.0031
# Train Directional Accuracy: 0.5620, Test Directional Accuracy: 0.5644
# Training Time: 105.1456 seconds, Evaluation Time: 0.1833 seconds
#
# Running model 2/216 with parameters: {'window_size': 24, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 0.0050, Test MAE: 0.0035
# Train Directional Accuracy: 0.5535, Test Directional Accuracy: 0.5635
# Training Time: 105.4440 seconds, Evaluation Time: 0.1937 seconds
#
# Running model 3/216 with parameters: {'window_size': 24, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0047, Test MAE: 0.0030
# Train Directional Accuracy: 0.5445, Test Directional Accuracy: 0.5424
# Training Time: 160.3946 seconds, Evaluation Time: 0.1632 seconds
#
# Running model 4/216 with parameters: {'window_size': 24, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 0.0047, Test MAE: 0.0031
# Train Directional Accuracy: 0.5422, Test Directional Accuracy: 0.5521
# Training Time: 165.4035 seconds, Evaluation Time: 0.1683 seconds
#
# Running model 5/216 with parameters: {'window_size': 24, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0048, Test MAE: 0.0033
# Train Directional Accuracy: 0.5468, Test Directional Accuracy: 0.5468
# Training Time: 212.5123 seconds, Evaluation Time: 0.1897 seconds
#
# Running model 6/216 with parameters: {'window_size': 24, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 0.0048, Test MAE: 0.0033
# Train Directional Accuracy: 0.5766, Test Directional Accuracy: 0.5900
# Training Time: 208.6146 seconds, Evaluation Time: 0.1623 seconds
#
# Running model 7/216 with parameters: {'window_size': 24, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0046, Test MAE: 0.0030
# Train Directional Accuracy: 0.
216 with parameters: {'window_size': 24, 'lstm_dim': 190, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 0.0048, Test MAE: 0.0033
# Train Directional Accuracy: 0.5684, Test Directional Accuracy: 0.5710
# Training Time: 246.5554 seconds, Evaluation Time: 0.9027 seconds
#
# Running model 199/216 with parameters: {'window_size': 24, 'lstm_dim': 190, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0050, Test MAE: 0.0036
# Train Directional Accuracy: 0.5826, Test Directional Accuracy: 0.5943
# Training Time: 122.9736 seconds, Evaluation Time: 0.9037 seconds
#
# Running model 200/216 with parameters: {'window_size': 24, 'lstm_dim': 190, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 0.0046, Test MAE: 0.0031
# Train Directional Accuracy: 0.5764, Test Directional Accuracy: 0.5903
# Training Time: 122.6752 seconds, Evaluation Time: 0.8955 seconds
#
# Running model 201/216 with parameters: {'window_size': 24, 'lstm_dim': 190, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0046, Test MAE: 0.0031
# Train Directional Accuracy: 0.5415, Test Directional Accuracy: 0.5087
# Training Time: 184.5830 seconds, Evaluation Time: 0.8977 seconds
#
# Running model 202/216 with parameters: {'window_size': 24, 'lstm_dim': 190, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 0.0046, Test MAE: 0.0030
# Train Directional Accuracy: 0.5496, Test Directional Accuracy: 0.5357
# Training Time: 185.0151 seconds, Evaluation Time: 0.9072 seconds
#
# Running model 203/216 with parameters: {'window_size': 24, 'lstm_dim': 190, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0047, Test MAE: 0.0033
# Train Directional Accuracy: 0.5431, Test Directional Accuracy: 0.5136
# Training Time: 246.2699 seconds, Evaluation Time: 0.9206 seconds
#
# Running model 204/216 with parameters: {'window_size': 24, 'lstm_dim': 190, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 0.0046, Test MAE: 0.0030
# Train Directional Accuracy: 0.5367, Test Directional Accuracy: 0.5110
# Training Time: 245.9480 seconds, Evaluation Time: 0.8914 seconds
#
# Running model 205/216 with parameters: {'window_size': 24, 'lstm_dim': 190, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0047, Test MAE: 0.0031
# Train Directional Accuracy: 0.5387, Test Directional Accuracy: 0.5426
# Training Time: 122.6320 seconds, Evaluation Time: 0.9135 seconds
#
# Running model 206/216 with parameters: {'window_size': 24, 'lstm_dim': 190, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 0.0047, Test MAE: 0.0031
# Train Directional Accuracy: 0.5671, Test Directional Accuracy: 0.5747
# Training Time: 123.2409 seconds, Evaluation Time: 0.8996 seconds
#
# Running model 207/216 with parameters: {'window_size': 24, 'lstm_dim': 190, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0047, Test MAE: 0.0032
# Train Directional Accuracy: 0.5577, Test Directional Accuracy: 0.5669
# Training Time: 185.4288 seconds, Evaluation Time: 0.9078 seconds
#
# Running model 208/216 with parameters: {'window_size': 24, 'lstm_dim': 190, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 0.0047, Test MAE: 0.0031
# Train Directional Accuracy: 0.5447, Test Directional Accuracy: 0.5481
# Training Time: 186.5527 seconds, Evaluation Time: 0.9054 seconds
#
# Running model 209/216 with parameters: {'window_size': 24, 'lstm_dim': 190, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0046, Test MAE: 0.0031
# Train Directional Accuracy: 0.5665, Test Directional Accuracy: 0.5554
# Training Time: 246.9909 seconds, Evaluation Time: 0.9033 seconds
#
# Running model 210/216 with parameters: {'window_size': 24, 'lstm_dim': 190, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 0.0047, Test MAE: 0.0032
# Train Directional Accuracy: 0.5590, Test Directional Accuracy: 0.5525
# Training Time: 247.0454 seconds, Evaluation Time: 0.9002 seconds
#
# Running model 211/216 with parameters: {'window_size': 24, 'lstm_dim': 190, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0002, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0046, Test MAE: 0.0030
# Train Directional Accuracy: 0.5684, Test Directional Accuracy: 0.5684
# Training Time: 123.0584 seconds, Evaluation Time: 0.8924 seconds
#
# Running model 212/216 with parameters: {'window_size': 24, 'lstm_dim': 190, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0002, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 0.0046, Test MAE: 0.0030
# Train Directional Accuracy: 0.5709, Test Directional Accuracy: 0.5773
# Training Time: 124.2645 seconds, Evaluation Time: 0.8991 seconds
#
# Running model 213/216 with parameters: {'window_size': 24, 'lstm_dim': 190, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0002, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0048, Test MAE: 0.0033
# Train Directional Accuracy: 0.5408, Test Directional Accuracy: 0.5054
# Training Time: 185.4284 seconds, Evaluation Time: 0.8912 seconds
#
# Running model 214/216 with parameters: {'window_size': 24, 'lstm_dim': 190, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0002, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 0.0047, Test MAE: 0.0032
# Train Directional Accuracy: 0.5551, Test Directional Accuracy: 0.5218
# Training Time: 185.4787 seconds, Evaluation Time: 0.9187 seconds
#
# Running model 215/216 with parameters: {'window_size': 24, 'lstm_dim': 190, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0002, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0046, Test MAE: 0.0030
# Train Directional Accuracy: 0.5375, Test Directional Accuracy: 0.5116
# Training Time: 247.8729 seconds, Evaluation Time: 0.8967 seconds
#
# Running model 216/216 with parameters: {'window_size': 24, 'lstm_dim': 190, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0002, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 0.0046, Test MAE: 0.0031
# Train Directional Accuracy: 0.5214, Test Directional Accuracy: 0.4898
# Training Time: 248.1614 seconds, Evaluation Time: 0.8968 seconds
#
# Total time taken: 39304.221575737 seconds

# %%
# Define parameter space
parameter_space = {
    'window_size': [24],
    'lstm_dim': [150],
    'dense_dim': [190],
    'num_layers': [1],
    'dropout': [0.0005, 0.001, 0.0015],
    'lr': [0.0001, 0.00015, 0.00005],
    'num_epochs': [150],
    'batch_size': [64],
    'optimizer_type': ['Adam', 'AdamW'],
    'patience': [24],
    'activation_function': [nn.Tanh, nn.ReLU],
}

# %%
# Define target column
target_column = 'log_close'

# Define feature combination
features = ['log_high', 'log_low', 'log_close', 'volume',
       'quote_vol', 'count', 'buy_base', 'buy_quote', 'high_p', 'low_p', 'close_p']

# %%
# Start total timer
start = time.time()

# Calculate total number of models
total_models = len(list(itertools.product(*parameter_space.values())))

# Initialize model counter
model_counter = 1

# Grid search
for params in itertools.product(*parameter_space.values()):
    param_dict = dict(zip(parameter_space.keys(), params))
    print(f"Running model {model_counter}/{total_models} with parameters: {param_dict}\n")
    
    # Run with fixed epochs
    print('Results:\n')
    train_and_evaluate(df, target_column=target_column, feature_columns=features, params=param_dict, file_prefix='results1.6', use_early_stopping=False, plot_loss=False)
    
    # Increment model counter
    model_counter += 1

# Calculate total time
end = time.time()
total_time = end - start

# Print the total time taken
print(f"Total time taken: {total_time} seconds")
# Out:
# Running model 1/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0005, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 144.3075, Test MAE: 144.3739
# Train Directional Accuracy: 0.4720, Test Directional Accuracy: 0.4708
# Training Time: 182.1372 seconds, Evaluation Time: 0.4218 seconds
#
# Running model 2/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0005, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 239.8147, Test MAE: 310.1753
# Train Directional Accuracy: 0.4713, Test Directional Accuracy: 0.4703
# Training Time: 182.6123 seconds, Evaluation Time: 0.4089 seconds
#
# Running model 3/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0005, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 179.3765, Test MAE: 235.3216
# Train Directional Accuracy: 0.4718, Test Directional Accuracy: 0.4717
# Training Time: 180.8259 seconds, Evaluation Time: 0.4043 seconds
#
# Running model 4/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0005, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 153.4461, Test MAE: 155.0875
# Train Directional Accuracy: 0.4730, Test Directional Accuracy: 0.4716
# Training Time: 182.9720 seconds, Evaluation Time: 0.4149 seconds
#
# Running model 5/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0005, 'lr': 0.00015, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 217.3196, Test MAE: 292.8968
# Train Directional Accuracy: 0.4710, Test Directional Accuracy: 0.4732
# Training Time: 180.6991 seconds, Evaluation Time: 0.4098 seconds
#
# Running model 6/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0005, 'lr': 0.00015, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 140.9969, Test MAE: 140.0378
# Train Directional Accuracy: 0.4712, Test Directional Accuracy: 0.4716
# Training Time: 181.2009 seconds, Evaluation Time: 0.4168 seconds
#
# Running model 7/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0005, 'lr': 0.00015, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 155.0080, Test MAE: 187.6792
# Train Directional Accuracy: 0.4706, Test Directional Accuracy: 0.4736
# Training Time: 181.6810 seconds, Evaluation Time: 0.4017 seconds
#
# Running model 8/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0005, 'lr': 0.00015, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 144.2249, Test MAE: 147.4744
# Train Directional Accuracy: 0.4712, Test Directional Accuracy: 0.4720
# Training Time: 182.2407 seconds, Evaluation Time: 0.4083 seconds
#
# Running model 9/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0005, 'lr': 5e-05, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 164.3942, Test MAE: 180.8021
# Train Directional Accuracy: 0.4707, Test Directional Accuracy: 0.4730
# Training Time: 181.4828 seconds, Evaluation Time: 0.4044 seconds
#
# Running model 10/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0005, 'lr': 5e-05, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 159.2130, Test MAE: 164.8429
# Train Directional Accuracy: 0.4699, Test Directional Accuracy: 0.4700
# Training Time: 181.7321 seconds, Evaluation Time: 0.4129 seconds
#
# Running model 11/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0005, 'lr': 5e-05, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 158.0079, Test MAE: 153.3013
# Train Directional Accuracy: 0.4703, Test Directional Accuracy: 0.4726
# Training Time: 181.9237 seconds, Evaluation Time: 0.4064 seconds
#
# Running model 12/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0005, 'lr': 5e-05, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE:
36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0015, 'lr': 0.00015, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 151.7384, Test MAE: 176.9189
# Train Directional Accuracy: 0.4718, Test Directional Accuracy: 0.4725
# Training Time: 178.3237 seconds, Evaluation Time: 0.4011 seconds
#
# Running model 30/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0015, 'lr': 0.00015, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 160.3977, Test MAE: 178.5740
# Train Directional Accuracy: 0.4710, Test Directional Accuracy: 0.4732
# Training Time: 179.8854 seconds, Evaluation Time: 0.4043 seconds
#
# Running model 31/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0015, 'lr': 0.00015, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 148.0837, Test MAE: 162.0630
# Train Directional Accuracy: 0.4720, Test Directional Accuracy: 0.4726
# Training Time: 180.4169 seconds, Evaluation Time: 0.4218 seconds
#
# Running model 32/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0015, 'lr': 0.00015, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 141.7967, Test MAE: 140.4060
# Train Directional Accuracy: 0.4714, Test Directional Accuracy: 0.4714
# Training Time: 179.8692 seconds, Evaluation Time: 0.4103 seconds
#
# Running model 33/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0015, 'lr': 5e-05, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 195.4425, Test MAE: 246.4526
# Train Directional Accuracy: 0.4698, Test Directional Accuracy: 0.4730
# Training Time: 179.0511 seconds, Evaluation Time: 0.4053 seconds
#
# Running model 34/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0015, 'lr': 5e-05, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 150.4046, Test MAE: 155.4189
# Train Directional Accuracy: 0.4692, Test Directional Accuracy: 0.4713
# Training Time: 178.5077 seconds, Evaluation Time: 0.4018 seconds
#
# Running model 35/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0015, 'lr': 5e-05, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 172.8347, Test MAE: 216.9968
# Train Directional Accuracy: 0.4709, Test Directional Accuracy: 0.4717
# Training Time: 180.2477 seconds, Evaluation Time: 0.4053 seconds
#
# Running model 36/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0015, 'lr': 5e-05, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 153.4032, Test MAE: 171.2369
# Train Directional Accuracy: 0.4691, Test Directional Accuracy: 0.4697
# Training Time: 180.5168 seconds, Evaluation Time: 0.4014 seconds
#
# Total time taken: 6527.387030363083 seconds

# %%
# Define feature combination
features = ['log_high', 'log_low', 'log_close', 'volume',
       'quote_vol', 'count', 'buy_base', 'buy_quote']

# %%
# Start total timer
start = time.time()

# Calculate total number of models
total_models = len(list(itertools.product(*parameter_space.values())))

# Initialize model counter
model_counter = 1

# Grid search
for params in itertools.product(*parameter_space.values()):
    param_dict = dict(zip(parameter_space.keys(), params))
    print(f"Running model {model_counter}/{total_models} with parameters: {param_dict}\n")
    
    # Run with fixed epochs
    print('Results:\n')
    train_and_evaluate(df, target_column=target_column, feature_columns=features, params=param_dict, file_prefix='results1.7', use_early_stopping=False, plot_loss=False)
    
    # Increment model counter
    model_counter += 1

# Calculate total time
end = time.time()
total_time = end - start

# Print the total time taken
print(f"Total time taken: {total_time} seconds")

# Start the beep sound
stop_beep_flag = False
beep_thread = Thread(target=play_beep)
beep_thread.start()


input("Press Enter to stop the beep sound...")
stop_beep_flag = True
beep_thread.join()
print("Beep sound stopped.")
# Out:
# Running model 1/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0005, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 194.0308, Test MAE: 259.0770
# Train Directional Accuracy: 0.4714, Test Directional Accuracy: 0.4713
# Training Time: 180.2746 seconds, Evaluation Time: 0.3930 seconds
#
# Running model 2/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0005, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 149.5041, Test MAE: 145.6035
# Train Directional Accuracy: 0.4720, Test Directional Accuracy: 0.4697
# Training Time: 209.3033 seconds, Evaluation Time: 0.5021 seconds
#
# Running model 3/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0005, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 148.5787, Test MAE: 145.8926
# Train Directional Accuracy: 0.4703, Test Directional Accuracy: 0.4697
# Training Time: 222.3292 seconds, Evaluation Time: 0.5541 seconds
#
# Running model 4/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0005, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 200.4441, Test MAE: 283.8072
# Train Directional Accuracy: 0.4704, Test Directional Accuracy: 0.4700
# Training Time: 227.5298 seconds, Evaluation Time: 0.5257 seconds
#
# Running model 5/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0005, 'lr': 0.00015, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 146.8618, Test MAE: 154.9124
# Train Directional Accuracy: 0.4703, Test Directional Accuracy: 0.
36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 166.8684, Test MAE: 187.6372
# Train Directional Accuracy: 0.4697, Test Directional Accuracy: 0.4707
# Training Time: 180.5670 seconds, Evaluation Time: 0.4075 seconds
#
# Running model 24/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.001, 'lr': 5e-05, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 162.4199, Test MAE: 173.9586
# Train Directional Accuracy: 0.4678, Test Directional Accuracy: 0.4713
# Training Time: 180.1632 seconds, Evaluation Time: 0.4003 seconds
#
# Running model 25/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0015, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 141.1666, Test MAE: 139.2424
# Train Directional Accuracy: 0.4714, Test Directional Accuracy: 0.4712
# Training Time: 179.9003 seconds, Evaluation Time: 0.4173 seconds
#
# Running model 26/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0015, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 145.4994, Test MAE: 158.2477
# Train Directional Accuracy: 0.4717, Test Directional Accuracy: 0.4717
# Training Time: 177.8175 seconds, Evaluation Time: 0.4217 seconds
#
# Running model 27/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0015, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 181.8190, Test MAE: 244.7701
# Train Directional Accuracy: 0.4706, Test Directional Accuracy: 0.4714
# Training Time: 179.5724 seconds, Evaluation Time: 0.4013 seconds
#
# Running model 28/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0015, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 151.3261, Test MAE: 153.6417
# Train Directional Accuracy: 0.4719, Test Directional Accuracy: 0.4724
# Training Time: 178.8809 seconds, Evaluation Time: 0.4283 seconds
#
# Running model 29/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0015, 'lr': 0.00015, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 204.2147, Test MAE: 271.7106
# Train Directional Accuracy: 0.4696, Test Directional Accuracy: 0.4699
# Training Time: 178.1130 seconds, Evaluation Time: 0.4183 seconds
#
# Running model 30/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0015, 'lr': 0.00015, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 161.8780, Test MAE: 194.4651
# Train Directional Accuracy: 0.4715, Test Directional Accuracy: 0.4701
# Training Time: 179.3599 seconds, Evaluation Time: 0.4323 seconds
#
# Running model 31/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0015, 'lr': 0.00015, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 259.9510, Test MAE: 384.9715
# Train Directional Accuracy: 0.4703, Test Directional Accuracy: 0.4687
# Training Time: 179.9852 seconds, Evaluation Time: 0.3983 seconds
#
# Running model 32/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0015, 'lr': 0.00015, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 209.1604, Test MAE: 268.7854
# Train Directional Accuracy: 0.4704, Test Directional Accuracy: 0.4679
# Training Time: 178.2566 seconds, Evaluation Time: 0.4028 seconds
#
# Running model 33/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0015, 'lr': 5e-05, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 148.8754, Test MAE: 146.3997
# Train Directional Accuracy: 0.4702, Test Directional Accuracy: 0.4705
# Training Time: 179.3601 seconds, Evaluation Time: 0.4129 seconds
#
# Running model 34/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0015, 'lr': 5e-05, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 180.1840, Test MAE: 217.9983
# Train Directional Accuracy: 0.4689, Test Directional Accuracy: 0.4714
# Training Time: 179.6068 seconds, Evaluation Time: 0.4226 seconds
#
# Running model 35/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0015, 'lr': 5e-05, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 150.7306, Test MAE: 150.1696
# Train Directional Accuracy: 0.4674, Test Directional Accuracy: 0.4697
# Training Time: 180.1384 seconds, Evaluation Time: 0.4165 seconds
#
# Running model 36/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0015, 'lr': 5e-05, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 214.1228, Test MAE: 303.3019
# Train Directional Accuracy: 0.4679, Test Directional Accuracy: 0.4708
# Training Time: 178.7372 seconds, Evaluation Time: 0.4039 seconds
#
# Total time taken: 7000.862381219864 seconds
# Press Enter to stop the beep sound...
# Beep sound stopped.

# %%
target_column = 'log_diff'

# Define feature combination
features = ['diff_log_high', 'diff_log_low', 'log_high', 'log_low', 'log_close', 'log_diff', 'volume',
       'quote_vol', 'count', 'buy_base', 'buy_quote', 'high_p', 'low_p', 'close_p']

# %%
# Start total timer
start = time.time()

# Calculate total number of models
total_models = len(list(itertools.product(*parameter_space.values())))

# Initialize model counter
model_counter = 1

# Grid search
for params in itertools.product(*parameter_space.values()):
    param_dict = dict(zip(parameter_space.keys(), params))
    print(f"Running model {model_counter}/{total_models} with parameters: {param_dict}\n")
    
    # Run with fixed epochs
    print('Results:\n')
    train_and_evaluate(df, target_column=target_column, feature_columns=features, params=param_dict, file_prefix='results1.8', use_early_stopping=False, plot_loss=False)
    
    # Increment model counter
    model_counter += 1

# Calculate total time
end = time.time()
total_time = end - start

# Print the total time taken
print(f"Total time taken: {total_time} seconds")
# Out:
# Running model 1/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0005, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0048, Test MAE: 0.0032
# Train Directional Accuracy: 0.5511, Test Directional Accuracy: 0.5539
# Training Time: 187.7161 seconds, Evaluation Time: 0.4174 seconds
#
# Running model 2/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0005, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 0.0046, Test MAE: 0.0030
# Train Directional Accuracy: 0.5482, Test Directional Accuracy: 0.5598
# Training Time: 186.7915 seconds, Evaluation Time: 0.4119 seconds
#
# Running model 3/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0005, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0049, Test MAE: 0.0034
# Train Directional Accuracy: 0.5439, Test Directional Accuracy: 0.5527
# Training Time: 180.2153 seconds, Evaluation Time: 0.4169 seconds
#
# Running model 4/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0005, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 0.0047, Test MAE: 0.0030
# Train Directional Accuracy: 0.5511, Test Directional Accuracy: 0.5562
# Training Time: 180.2305 seconds, Evaluation Time: 0.4293 seconds
#
# Running model 5/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0005, 'lr': 0.00015, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0046, Test MAE: 0.0030
# Train Directional Accuracy: 0.5448, Test Directional Accuracy: 0.5185
# Training Time: 179.2494 seconds, Evaluation Time: 0.4249 seconds
#
# Running model 6/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0005, 'lr': 0.00015, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 0.0049, Test MAE: 0.0035
# Train Directional Accuracy: 0.5574, Test Directional Accuracy: 0.5575
# Training Time: 179.9753 seconds, Evaluation Time: 0.4414 seconds
#
# Running model 7/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0005, 'lr': 0.00015, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0050, Test MAE: 0.0034
# Train Directional Accuracy: 0.5424, Test Directional Accuracy: 0.5213
# Training Time: 180.3798 seconds, Evaluation Time: 0.4069 seconds
#
# Running model 8/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0005, 'lr': 0.00015, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 0.0046, Test MAE: 0.0030
# Train Directional Accuracy: 0.5569, Test Directional Accuracy: 0.5701
# Training Time: 180.8134 seconds, Evaluation Time: 0.4018 seconds
#
# Running model 9/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0005, 'lr': 5e-05, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0048, Test MAE: 0.0032
# Train Directional Accuracy: 0.5660, Test Directional Accuracy: 0.5678
# Training Time: 179.6987 seconds, Evaluation Time: 0.4200 seconds
#
# Running model 10/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0005, 'lr': 5e-05, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 0.0047, Test MAE: 0.0031
# Train Directional Accuracy: 0.5801, Test Directional Accuracy: 0.5792
# Training Time: 179.9125 seconds, Evaluation Time: 0.4343 seconds
#
# Running model 11/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0005, 'lr': 5e-05, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0047, Test MAE: 0.0031
# Train Directional Accuracy: 0.5557, Test Directional Accuracy: 0.5641
# Training Time: 180.6006 seconds, Evaluation Time: 0.4134 seconds
#
# Running model 12/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.0005, 'lr': 5e-05, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 0.0047, Test MAE: 0.0030
# Train Directional Accuracy: 0.5590, Test Directional Accuracy: 0.5561
# Training Time: 181.3943 seconds, Evaluation Time: 0.4163 seconds
#
# Running model 13/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0047, Test MAE: 0.0031
# Train Directional Accuracy: 0.5500, Test Directional Accuracy: 0.5565
# Training Time: 179.9614 seconds, Evaluation Time: 0.4103 seconds
#
# Running model 14/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 0.0046, Test MAE: 0.0030
# Train Directional Accuracy: 0.5490, Test Directional Accuracy: 0.5501
# Training Time: 180.4230 seconds, Evaluation Time: 0.4074 seconds
#
# Running model 15/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0047, Test MAE: 0.0031
# Train Directional Accuracy: 0.5406, Test Directional Accuracy: 0.5427
# Training Time: 180.4792 seconds, Evaluation Time: 0.4188 seconds
#
# Running model 16/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 0.0047, Test MAE: 0.0031
# Train Directional Accuracy: 0.5458, Test Directional Accuracy: 0.5529
# Training Time: 180.5044 seconds, Evaluation Time: 0.4184 seconds
#
# Running model 17/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.00015, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.0046, Test MAE: 0.0031
# Train Directional Accuracy: 0.5507, Test Directional Accuracy: 0.5350
# Training Time: 178.7708 seconds, Evaluation Time: 0.4233 seconds
#
# Running model 18/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.00015, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
#
# Results:
#
# Results: Train MAE: 0.0046, Test MAE: 0.0030
# Train Directional Accuracy: 0.5574, Test Directional Accuracy: 0.5568
# Training Time: 180.1396 seconds, Evaluation Time: 0.4103 seconds
#
# Running model 19/36 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 190, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.00015, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train MAE: 0.