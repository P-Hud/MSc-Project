# %%
# Data Manipulation and Preparation
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import csv
from random import randint, uniform, choice
import itertools

# PyTorch
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# Evaluation metrics and visualisation
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Ensure GPU usage
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

import time
# Out:
# Using device: cuda

# %%
# Load cleaned dataset
spot_df = pd.read_csv('eth_1h_cleaned.csv', parse_dates=['open_time'])

spot_simple_features = ['open', 'high', 'low', 'close', 'volume']

simple_spot_df = spot_df[spot_simple_features].copy()

# %%
pd.set_option('display.float_format', '{:.6f}'.format)

# %%
# Function to create sequences
def create_sequences(data, target, window_size):
    sequences = []
    labels = []
    for i in range(len(data) - window_size):
        seq = data[i:i + window_size]
        label = target[i + window_size]
        sequences.append(seq)
        labels.append(label)
    return np.array(sequences), np.array(labels)

# LSTM Model
class LSTMModel(nn.Module):
    def __init__(self, input_dim, lstm_dim, dense_dim, output_dim, num_layers=1, dropout=0.0):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_dim, lstm_dim, num_layers=num_layers, batch_first=True, dropout=(dropout if num_layers > 1 else 0))
        self.fc1 = nn.Linear(lstm_dim, dense_dim)
        self.fc2 = nn.Linear(dense_dim, output_dim)
    
    def forward(self, x):
        x, _ = self.lstm(x)
        x = x[:, -1, :] 
        x = self.fc1(x)
        x = torch.relu(x)
        x = self.fc2(x)
        return x

def train_and_evaluate(window_size=10, lstm_dim=50, dense_dim=50, num_layers=1, dropout=0.0, lr=0.001, batch_size=64, num_epochs=1000, optimizer_type='Adam', patience=10):
    # Clear CUDA cache
    torch.cuda.empty_cache()
    
    # Prepare data
    X = simple_spot_df.values
    y = simple_spot_df['close'].values.reshape(-1, 1)  # Reshape y to match scaler's expected input

    scaler_X = MinMaxScaler()
    X_scaled = scaler_X.fit_transform(X)

    scaler_y = MinMaxScaler()
    y_scaled = scaler_y.fit_transform(y)

    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, shuffle=False)
    X_train_seq, y_train_seq = create_sequences(X_train, y_train, window_size)
    X_test_seq, y_test_seq = create_sequences(X_test, y_test, window_size)

    X_train_tensor = torch.tensor(X_train_seq, dtype=torch.float32).to(device)
    X_test_tensor = torch.tensor(X_test_seq, dtype=torch.float32).to(device)
    y_train_tensor = torch.tensor(y_train_seq, dtype=torch.float32).view(-1, 1).to(device)
    y_test_tensor = torch.tensor(y_test_seq, dtype=torch.float32).view(-1, 1).to(device)

    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

    train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

    # Model parameters
    input_dim = X_train_tensor.shape[2]
    output_dim = 1

    model = LSTMModel(input_dim, lstm_dim, dense_dim, output_dim, num_layers, dropout).to(device)

    # Define loss
    criterion = nn.MSELoss()
    
    # Select optimizer
    if optimizer_type == 'Adam':
        optimizer = optim.Adam(model.parameters(), lr=lr)
    elif optimizer_type == 'SGD':
        optimizer = optim.SGD(model.parameters(), lr=lr)
    elif optimizer_type == 'RMSprop':
        optimizer = optim.RMSprop(model.parameters(), lr=lr)
    else:
        raise ValueError("Unsupported optimizer type")

    # Training loop
    best_loss = float('inf')
    patience_counter = 0
    start_time = time.time()
    
    for epoch in range(num_epochs):
        model.train()
        for inputs, labels in train_loader:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for inputs, labels in test_loader:
                outputs = model(inputs)
                val_loss += criterion(outputs, labels).item()
        
        val_loss /= len(test_loader)
        
        if val_loss < best_loss:
            best_loss = val_loss
            patience_counter = 0
            torch.save(model.state_dict(), 'best_model.pth')
        else:
            patience_counter += 1
            if patience_counter >= patience:
                break

    training_time = time.time() - start_time

    model.load_state_dict(torch.load('best_model.pth'))

    # Evaluate the model
    model.eval()
    evaluation_start_time = time.time()
    with torch.no_grad():
        train_predictions = model(X_train_tensor).cpu().numpy()
        test_predictions = model(X_test_tensor).cpu().numpy()

        # Inverse transform predictions and actual values
        train_predictions_inverse = scaler_y.inverse_transform(train_predictions)
        test_predictions_inverse = scaler_y.inverse_transform(test_predictions)
        y_train_inverse = scaler_y.inverse_transform(y_train_seq)
        y_test_inverse = scaler_y.inverse_transform(y_test_seq)

        train_mse = mean_squared_error(y_train_inverse, train_predictions_inverse)
        test_mse = mean_squared_error(y_test_inverse, test_predictions_inverse)
        train_mae = mean_absolute_error(y_train_inverse, train_predictions_inverse)
        test_mae = mean_absolute_error(y_test_inverse, test_predictions_inverse)
        train_rmse = np.sqrt(train_mse)
        test_rmse = np.sqrt(test_mse)
        train_r2 = r2_score(y_train_inverse, train_predictions_inverse)
        test_r2 = r2_score(y_test_inverse, test_predictions_inverse)
        
        # Calculate accuracy-like metric with tighter threshold
        def calculate_accuracy(y_true, y_pred, percentage=0.01):
            range_y = y_true.max() - y_true.min()
            threshold = percentage * range_y
            diff = np.abs(y_true - y_pred)
            accuracy = np.mean(diff < threshold)
            return accuracy

        train_acc = calculate_accuracy(y_train_inverse, train_predictions_inverse)
        test_acc = calculate_accuracy(y_test_inverse, test_predictions_inverse)

    evaluation_time = time.time() - evaluation_start_time

    result = {
        "window_size": window_size,
        "lstm_dim": lstm_dim,
        "num_layers": num_layers,
        "dense_dim": dense_dim,
        "dropout": dropout,
        "lr": lr,
        "batch_size": batch_size,
        "num_epochs": num_epochs,
        "optimizer_type": optimizer_type,
        "train_mse": train_mse,
        "test_mse": test_mse,
        "train_mae": train_mae,
        "test_mae": test_mae,
        "train_rmse": train_rmse,
        "test_rmse": test_rmse,
        "train_r2": train_r2,
        "test_r2": test_r2,
        "train_acc": train_acc,
        "test_acc": test_acc,
        "training_time": training_time,
        "evaluation_time": evaluation_time,
        "patience": patience  # Add patience to the result
    }

    # Save result to a CSV file
    with open('results_ETH_param2.csv', 'a', newline='') as f:
        writer = csv.DictWriter(f, fieldnames=result.keys())
        if f.tell() == 0:
            writer.writeheader()  # Write header only if file is empty
        writer.writerow(result)

    # Print summary of the results
    print(f"Finished model with parameters: {param_dict}")
    print(f"Results: Train MSE: {train_mse:.4f}, Test MSE: {test_mse:.4f}, Train MAE: {train_mae:.4f}, Test MAE: {test_mae:.4f}")
    print(f"Train RMSE: {train_rmse:.4f}, Test RMSE: {test_rmse:.4f}, Train R2: {train_r2:.4f}, Test R2: {test_r2:.4f}")
    print(f"Train Accuracy: {train_acc:.4f}, Test Accuracy: {test_acc:.4f}")
    print(f"Training Time: {training_time:.4f} seconds, Evaluation Time: {evaluation_time:.4f} seconds\n")

    return result

# %%
# Parameter space definition
parameter_space = {
    'window_size': [24, 36],
    'lstm_dim': [48, 64, 96],
    'dense_dim': [96, 120],
    'num_layers': [1],
    'dropout': [0.005, 0.01, 0.02],
    'lr': [0.001, 0.002],
    'batch_size': [64],
    'optimizer_type': ['Adam'],
    'patience': [17, 20, 23]
}

# Grid search
for params in itertools.product(*parameter_space.values()):
    param_dict = dict(zip(parameter_space.keys(), params))
    print(f"Running model with parameters: {param_dict}")
    train_and_evaluate(**param_dict)
# Out:
# Running model with parameters: {'window_size': 24, 'lstm_dim': 48, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.005, 'lr': 0.001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 17}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 48, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.005, 'lr': 0.001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 17}
# Results: Train MSE: 398.2741, Test MSE: 236.0528, Train MAE: 11.3053, Test MAE: 8.7807
# Train RMSE: 19.9568, Test RMSE: 15.3640, Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9628, Test Accuracy: 0.9273
# Training Time: 50.4593 seconds, Evaluation Time: 0.0751 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 48, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.005, 'lr': 0.001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 20}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 48, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.005, 'lr': 0.001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 20}
# Results: Train MSE: 377.7670, Test MSE: 230.9642, Train MAE: 10.6179, Test MAE: 8.6594
# Train RMSE: 19.4362, Test RMSE: 15.1975, Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9644, Test Accuracy: 0.9289
# Training Time: 87.7239 seconds, Evaluation Time: 0.1646 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 48, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.005, 'lr': 0.001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 23}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 48, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.005, 'lr': 0.001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 23}
# Results: Train MSE: 384.2394, Test MSE: 231.6997, Train MAE: 11.3411, Test MAE: 8.6975
# Train RMSE: 19.6020, Test RMSE: 15.2217, Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9646, Test Accuracy: 0.9290
# Training Time: 83.8964 seconds, Evaluation Time: 0.1556 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 48, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.005, 'lr': 0.002, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 17}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 48, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.005, 'lr': 0.002, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 17}
# Results: Train MSE: 388.1061, Test MSE: 234.3642, Train MAE: 10.7824, Test MAE: 8.7341
# Train RMSE: 19.7004, Test RMSE: 15.3090, Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9637, Test Accuracy: 0.9277
# Training Time: 38.9108 seconds, Evaluation Time: 0.0816 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 48, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.005, 'lr': 0.002, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 20}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 48, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.005, 'lr': 0.002, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 20}
# Results: Train MSE: 385.5662, Test MSE: 232.9279, Train MAE: 11.0917, Test MAE: 8.7479
# Train RMSE: 19.6358, Test RMSE: 15.2620, Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9635, Test Accuracy: 0.9276
# Training Time: 52.5400 seconds, Evaluation Time: 0.0687 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 48, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.005, 'lr': 0.002, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 23}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 48, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.005, 'lr': 0.002, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 23}
# Results: Train MSE: 402.2952, Test MSE: 231.9753, Train MAE: 12.3900, Test MAE: 8.7080
# Train RMSE: 20.0573, Test RMSE: 15.2307, Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9640, Test Accuracy: 0.9270
# Training Time: 51.5959 seconds, Evaluation Time: 0.1341 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 48, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 17}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 48, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 17}
# Results: Train MSE: 386.8405, Test MSE: 234.0649, Train MAE: 11.4047, Test MAE: 8.7637
# Train RMSE: 19.6683, Test RMSE: 15.2992, Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9640, Test Accuracy: 0.9272
# Training Time: 58.7675 seconds, Evaluation Time: 0.1572 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 48, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 20}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 48, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 20}
# Results: Train MSE: 382.5348, Test MSE: 231.7641, Train MAE: 11.3067, Test MAE: 8.6882
# Train RMSE: 19.5585, Test RMSE: 15.2238, Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9643, Test Accuracy: 0.9281
# Training Time: 81.2100 seconds, Evaluation Time: 0.0741 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 48, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 23}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 48, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 23}
# Results: Train MSE: 383.7687, Test MSE: 234.0154, Train MAE: 11.2143, Test MAE: 8.8732
# Train RMSE: 19.5900, Test RMSE: 15.2976, Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9638, Test Accuracy: 0.9262
# Training Time: 70.0649 seconds, Evaluation Time: 0.0760 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 48, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.002, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 17}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 48, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.002, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 17}
# Results: Train MSE: 426.1965, Test MSE: 248.2407, Train MAE: 12.5755, Test MAE: 9.0957
# Train RMSE: 20.6445, Test RMSE: 15.7557, Train R2: 0.9997, Test R2: 0.9994
# Train Accuracy: 0.9614, Test Accuracy: 0.9237
# Training Time: 28.3362 seconds, Evaluation Time: 0.0751 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 48, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.002, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 20}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 48, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.002, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 20}
# Results: Train MSE: 389.7684, Test MSE: 233.4932, Train MAE: 11.2734, Test MAE: 8.8142
# Train RMSE: 19.7426, Test RMSE: 15.2805, Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9638, Test Accuracy: 0.9277
# Training Time: 52.9631 seconds, Evaluation Time: 0.0756 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 48, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.002, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 23}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 48, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.002, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 23}
# Results: Train MSE:
Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9638, Test Accuracy: 0.9274
# Training Time: 42.1565 seconds, Evaluation Time: 0.2122 seconds
#
# Running model with parameters: {'window_size': 36, 'lstm_dim': 96, 'dense_dim': 120, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.002, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 23}
# Finished model with parameters: {'window_size': 36, 'lstm_dim': 96, 'dense_dim': 120, 'num_layers': 1, 'dropout': 0.01, 'lr': 0.002, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 23}
# Results: Train MSE: 383.3145, Test MSE: 232.7760, Train MAE: 10.6229, Test MAE: 8.6863
# Train RMSE: 19.5784, Test RMSE: 15.2570, Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9638, Test Accuracy: 0.9270
# Training Time: 48.0207 seconds, Evaluation Time: 0.1972 seconds
#
# Running model with parameters: {'window_size': 36, 'lstm_dim': 96, 'dense_dim': 120, 'num_layers': 1, 'dropout': 0.02, 'lr': 0.001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 17}
# Finished model with parameters: {'window_size': 36, 'lstm_dim': 96, 'dense_dim': 120, 'num_layers': 1, 'dropout': 0.02, 'lr': 0.001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 17}
# Results: Train MSE: 387.4158, Test MSE: 234.8311, Train MAE: 11.0160, Test MAE: 8.8205
# Train RMSE: 19.6829, Test RMSE: 15.3242, Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9638, Test Accuracy: 0.9264
# Training Time: 43.3351 seconds, Evaluation Time: 0.1917 seconds
#
# Running model with parameters: {'window_size': 36, 'lstm_dim': 96, 'dense_dim': 120, 'num_layers': 1, 'dropout': 0.02, 'lr': 0.001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 20}
# Finished model with parameters: {'window_size': 36, 'lstm_dim': 96, 'dense_dim': 120, 'num_layers': 1, 'dropout': 0.02, 'lr': 0.001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 20}
# Results: Train MSE: 384.8617, Test MSE: 232.7435, Train MAE: 11.2421, Test MAE: 8.6990
# Train RMSE: 19.6179, Test RMSE: 15.2559, Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9638, Test Accuracy: 0.9277
# Training Time: 63.1756 seconds, Evaluation Time: 0.2663 seconds
#
# Running model with parameters: {'window_size': 36, 'lstm_dim': 96, 'dense_dim': 120, 'num_layers': 1, 'dropout': 0.02, 'lr': 0.001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 23}
# Finished model with parameters: {'window_size': 36, 'lstm_dim': 96, 'dense_dim': 120, 'num_layers': 1, 'dropout': 0.02, 'lr': 0.001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 23}
# Results: Train MSE: 382.3307, Test MSE: 233.3627, Train MAE: 10.7134, Test MAE: 8.7636
# Train RMSE: 19.5533, Test RMSE: 15.2762, Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9640, Test Accuracy: 0.9282
# Training Time: 57.5977 seconds, Evaluation Time: 0.2082 seconds
#
# Running model with parameters: {'window_size': 36, 'lstm_dim': 96, 'dense_dim': 120, 'num_layers': 1, 'dropout': 0.02, 'lr': 0.002, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 17}
# Finished model with parameters: {'window_size': 36, 'lstm_dim': 96, 'dense_dim': 120, 'num_layers': 1, 'dropout': 0.02, 'lr': 0.002, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 17}
# Results: Train MSE: 391.7587, Test MSE: 234.0477, Train MAE: 11.4640, Test MAE: 8.8140
# Train RMSE: 19.7929, Test RMSE: 15.2986, Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9633, Test Accuracy: 0.9273
# Training Time: 37.0508 seconds, Evaluation Time: 0.2022 seconds
#
# Running model with parameters: {'window_size': 36, 'lstm_dim': 96, 'dense_dim': 120, 'num_layers': 1, 'dropout': 0.02, 'lr': 0.002, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 20}
# Finished model with parameters: {'window_size': 36, 'lstm_dim': 96, 'dense_dim': 120, 'num_layers': 1, 'dropout': 0.02, 'lr': 0.002, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 20}
# Results: Train MSE: 391.7710, Test MSE: 233.2325, Train MAE: 11.8082, Test MAE: 8.7549
# Train RMSE: 19.7932, Test RMSE: 15.2720, Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9641, Test Accuracy: 0.9286
# Training Time: 47.1668 seconds, Evaluation Time: 0.2247 seconds
#
# Running model with parameters: {'window_size': 36, 'lstm_dim': 96, 'dense_dim': 120, 'num_layers': 1, 'dropout': 0.02, 'lr': 0.002, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 23}
# Finished model with parameters: {'window_size': 36, 'lstm_dim': 96, 'dense_dim': 120, 'num_layers': 1, 'dropout': 0.02, 'lr': 0.002, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 23}
# Results: Train MSE: 388.5015, Test MSE: 235.9283, Train MAE: 10.9896, Test MAE: 8.8801
# Train RMSE: 19.7104, Test RMSE: 15.3600, Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9633, Test Accuracy: 0.9249
# Training Time: 43.4050 seconds, Evaluation Time: 0.2042 seconds

# %%
# Function to create sequences
def create_sequences(data, target, window_size):
    sequences = []
    labels = []
    for i in range(len(data) - window_size):
        seq = data[i:i + window_size]
        label = target[i + window_size]
        sequences.append(seq)
        labels.append(label)
    return np.array(sequences), np.array(labels)

class LSTMModel(nn.Module):
    def __init__(self, input_dim, lstm_dim, dense_dim, output_dim, num_layers=1, dropout=0.0, activation_function=nn.ReLU):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_dim, lstm_dim, num_layers=num_layers, batch_first=True, dropout=(dropout if num_layers > 1 else 0))
        self.fc1 = nn.Linear(lstm_dim, dense_dim)
        self.activation = activation_function()
        self.fc2 = nn.Linear(dense_dim, output_dim)
    
    def forward(self, x):
        x, _ = self.lstm(x)
        x = x[:, -1, :] 
        x = self.fc1(x)
        x = self.activation(x)
        x = self.fc2(x)
        return x


def train_and_evaluate(window_size=10, lstm_dim=50, dense_dim=50, num_layers=1, dropout=0.0, lr=0.001, batch_size=64, num_epochs=1000, optimizer_type='Adam', patience=10, activation_function=nn.ReLU):
    # Clear CUDA cache
    torch.cuda.empty_cache()
    
    # Prepare data
    X = simple_spot_df.values
    y = simple_spot_df['close'].values.reshape(-1, 1)  # Reshape y to match scaler's expected input

    scaler_X = MinMaxScaler()
    X_scaled = scaler_X.fit_transform(X)

    scaler_y = MinMaxScaler()
    y_scaled = scaler_y.fit_transform(y)

    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, shuffle=False)
    X_train_seq, y_train_seq = create_sequences(X_train, y_train, window_size)
    X_test_seq, y_test_seq = create_sequences(X_test, y_test, window_size)

    X_train_tensor = torch.tensor(X_train_seq, dtype=torch.float32).to(device)
    X_test_tensor = torch.tensor(X_test_seq, dtype=torch.float32).to(device)
    y_train_tensor = torch.tensor(y_train_seq, dtype=torch.float32).view(-1, 1).to(device)
    y_test_tensor = torch.tensor(y_test_seq, dtype=torch.float32).view(-1, 1).to(device)

    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

    train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

    # Model parameters
    input_dim = X_train_tensor.shape[2]
    output_dim = 1

    model = LSTMModel(input_dim, lstm_dim, dense_dim, output_dim, num_layers, dropout, activation_function).to(device)

    # Define loss
    criterion = nn.MSELoss()
    
    # Select optimizer
    if optimizer_type == 'Adam':
        optimizer = optim.Adam(model.parameters(), lr=lr)
    elif optimizer_type == 'RMSprop':
        optimizer = optim.RMSprop(model.parameters(), lr=lr)
    elif optimizer_type == 'SGD':
        optimizer = optim.SGD(model.parameters(), lr=lr)
    elif optimizer_type == 'SGD with Momentum':
        optimizer = optim.SGD(model.parameters(), lr=lr, momentum=0.9)
    elif optimizer_type == 'AdamW':
        optimizer = optim.AdamW(model.parameters(), lr=lr)
    else:
        raise ValueError("Unsupported optimizer type")

    # Training loop
    best_loss = float('inf')
    patience_counter = 0
    start_time = time.time()
    
    for epoch in range(num_epochs):
        model.train()
        for inputs, labels in train_loader:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for inputs, labels in test_loader:
                outputs = model(inputs)
                val_loss += criterion(outputs, labels).item()
        
        val_loss /= len(test_loader)
        
        if val_loss < best_loss:
            best_loss = val_loss
            patience_counter = 0
            torch.save(model.state_dict(), 'best_model.pth')
        else:
            patience_counter += 1
            if patience_counter >= patience:
                break

    training_time = time.time() - start_time

    model.load_state_dict(torch.load('best_model.pth'))

    # Evaluate the model
    model.eval()
    evaluation_start_time = time.time()
    with torch.no_grad():
        train_predictions = model(X_train_tensor).cpu().numpy()
        test_predictions = model(X_test_tensor).cpu().numpy()

        # Inverse transform predictions and actual values
        train_predictions_inverse = scaler_y.inverse_transform(train_predictions)
        test_predictions_inverse = scaler_y.inverse_transform(test_predictions)
        y_train_inverse = scaler_y.inverse_transform(y_train_seq)
        y_test_inverse = scaler_y.inverse_transform(y_test_seq)

        train_mse = mean_squared_error(y_train_inverse, train_predictions_inverse)
        test_mse = mean_squared_error(y_test_inverse, test_predictions_inverse)
        train_mae = mean_absolute_error(y_train_inverse, train_predictions_inverse)
        test_mae = mean_absolute_error(y_test_inverse, test_predictions_inverse)
        train_rmse = np.sqrt(train_mse)
        test_rmse = np.sqrt(test_mse)
        train_r2 = r2_score(y_train_inverse, train_predictions_inverse)
        test_r2 = r2_score(y_test_inverse, test_predictions_inverse)
        
        # Calculate accuracy-like metric with tighter threshold
        def calculate_accuracy(y_true, y_pred, percentage=0.01):
            range_y = y_true.max() - y_true.min()
            threshold = percentage * range_y
            diff = np.abs(y_true - y_pred)
            accuracy = np.mean(diff < threshold)
            return accuracy

        train_acc = calculate_accuracy(y_train_inverse, train_predictions_inverse)
        test_acc = calculate_accuracy(y_test_inverse, test_predictions_inverse)

    evaluation_time = time.time() - evaluation_start_time

    result = {
        "window_size": window_size,
        "lstm_dim": lstm_dim,
        "num_layers": num_layers,
        "dense_dim": dense_dim,
        "dropout": dropout,
        "lr": lr,
        "batch_size": batch_size,
        "num_epochs": num_epochs,
        "optimizer_type": optimizer_type,
        "activation_function": activation_function.__name__,
        "train_mse": train_mse,
        "test_mse": test_mse,
        "train_mae": train_mae,
        "test_mae": test_mae,
        "train_rmse": train_rmse,
        "test_rmse": test_rmse,
        "train_r2": train_r2,
        "test_r2": test_r2,
        "train_acc": train_acc,
        "test_acc": test_acc,
        "training_time": training_time,
        "evaluation_time": evaluation_time,
        "patience": patience  # Add patience to the result
    }

    # Save result to a CSV file
    with open('results_ETH_param3.csv', 'a', newline='') as f:
        writer = csv.DictWriter(f, fieldnames=result.keys())
        if f.tell() == 0:
            writer.writeheader()  # Write header only if file is empty
        writer.writerow(result)

    # Print summary of the results
    print(f"Finished model with parameters: {param_dict}")
    print(f"Results: Train MSE: {train_mse:.4f}, Test MSE: {test_mse:.4f}, Train MAE: {train_mae:.4f}, Test MAE: {test_mae:.4f}")
    print(f"Train RMSE: {train_rmse:.4f}, Test RMSE: {test_rmse:.4f}, Train R2: {train_r2:.4f}, Test R2: {test_r2:.4f}")
    print(f"Train Accuracy: {train_acc:.4f}, Test Accuracy: {test_acc:.4f}")
    print(f"Training Time: {training_time:.4f} seconds, Evaluation Time: {evaluation_time:.4f} seconds\n")

    return result

# %%
# Add activation functions to the parameter space
parameter_space = {
    'window_size': [24],
    'lstm_dim': [64, 96, 128],
    'dense_dim': [96],
    'num_layers': [1, 2],
    'dropout': [0.0, 0.01],
    'lr': [0.001, 0.0005, 0.0001],
    'batch_size': [64],
    'optimizer_type': ['Adam', 'AdamW'],
    'patience': [25],
    'activation_function': [nn.ReLU, nn.LeakyReLU, nn.Tanh]
}

# %%
import winsound

def play_beep():
    duration = 1000
    freq = 440 
    winsound.Beep(freq, duration)

# %%
# Grid search
for params in itertools.product(*parameter_space.values()):
    param_dict = dict(zip(parameter_space.keys(), params))
    print(f"Running model with parameters: {param_dict}")
    train_and_evaluate(**param_dict)

play_beep()
# Out:
# Running model with parameters: {'window_size': 24, 'lstm_dim': 64, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 25, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 64, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 25, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 419.9398, Test MSE: 235.2473, Train MAE: 13.2084, Test MAE: 8.8490
# Train RMSE: 20.4924, Test RMSE: 15.3378, Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9637, Test Accuracy: 0.9278
# Training Time: 57.0810 seconds, Evaluation Time: 0.0996 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 64, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 25, 'activation_function': <class 'torch.nn.modules.activation.LeakyReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 64, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 25, 'activation_function': <class 'torch.nn.modules.activation.LeakyReLU'>}
# Results: Train MSE: 426.8271, Test MSE: 236.4127, Train MAE: 13.5144, Test MAE: 8.8713
# Train RMSE: 20.6598, Test RMSE: 15.3757, Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9633, Test Accuracy: 0.9261
# Training Time: 56.0149 seconds, Evaluation Time: 0.0971 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 64, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 25, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 64, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 25, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 381.4590, Test MSE: 232.6946, Train MAE: 10.7678, Test MAE: 8.7129
# Train RMSE: 19.5310, Test RMSE: 15.2543, Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9644, Test Accuracy: 0.9276
# Training Time: 62.1410 seconds, Evaluation Time: 0.1016 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 64, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.001, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 25, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 64, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.001, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 25, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE:
Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9642, Test Accuracy: 0.9295
# Training Time: 111.6476 seconds, Evaluation Time: 0.2282 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 2, 'dropout': 0.01, 'lr': 0.0005, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 25, 'activation_function': <class 'torch.nn.modules.activation.LeakyReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 2, 'dropout': 0.01, 'lr': 0.0005, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 25, 'activation_function': <class 'torch.nn.modules.activation.LeakyReLU'>}
# Results: Train MSE: 439.5124, Test MSE: 247.9316, Train MAE: 12.3858, Test MAE: 8.9150
# Train RMSE: 20.9646, Test RMSE: 15.7458, Train R2: 0.9997, Test R2: 0.9994
# Train Accuracy: 0.9588, Test Accuracy: 0.9248
# Training Time: 48.8177 seconds, Evaluation Time: 0.2112 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 2, 'dropout': 0.01, 'lr': 0.0005, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 25, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 2, 'dropout': 0.01, 'lr': 0.0005, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 25, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 384.1442, Test MSE: 233.2529, Train MAE: 10.8883, Test MAE: 8.7357
# Train RMSE: 19.5996, Test RMSE: 15.2726, Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9639, Test Accuracy: 0.9288
# Training Time: 96.3536 seconds, Evaluation Time: 0.2097 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 2, 'dropout': 0.01, 'lr': 0.0005, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 25, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 2, 'dropout': 0.01, 'lr': 0.0005, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 25, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 385.3575, Test MSE: 237.4925, Train MAE: 10.8843, Test MAE: 8.9630
# Train RMSE: 19.6305, Test RMSE: 15.4108, Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9638, Test Accuracy: 0.9270
# Training Time: 91.8496 seconds, Evaluation Time: 0.2244 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 2, 'dropout': 0.01, 'lr': 0.0005, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 25, 'activation_function': <class 'torch.nn.modules.activation.LeakyReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 2, 'dropout': 0.01, 'lr': 0.0005, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 25, 'activation_function': <class 'torch.nn.modules.activation.LeakyReLU'>}
# Results: Train MSE: 389.8027, Test MSE: 236.8954, Train MAE: 10.9310, Test MAE: 8.7686
# Train RMSE: 19.7434, Test RMSE: 15.3914, Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9637, Test Accuracy: 0.9266
# Training Time: 69.8117 seconds, Evaluation Time: 0.2223 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 2, 'dropout': 0.01, 'lr': 0.0005, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 25, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 2, 'dropout': 0.01, 'lr': 0.0005, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 25, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 399.8660, Test MSE: 235.3403, Train MAE: 12.1849, Test MAE: 8.7694
# Train RMSE: 19.9967, Test RMSE: 15.3408, Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9637, Test Accuracy: 0.9280
# Training Time: 74.3003 seconds, Evaluation Time: 0.2132 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 2, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 25, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 2, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 25, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 381.9674, Test MSE: 233.2634, Train MAE: 10.7427, Test MAE: 8.7442
# Train RMSE: 19.5440, Test RMSE: 15.2730, Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9640, Test Accuracy: 0.9281
# Training Time: 222.9434 seconds, Evaluation Time: 0.2153 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 2, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 25, 'activation_function': <class 'torch.nn.modules.activation.LeakyReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 2, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 25, 'activation_function': <class 'torch.nn.modules.activation.LeakyReLU'>}
# Results: Train MSE: 398.7346, Test MSE: 239.4718, Train MAE: 11.2115, Test MAE: 8.9113
# Train RMSE: 19.9683, Test RMSE: 15.4749, Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9627, Test Accuracy: 0.9265
# Training Time: 119.4215 seconds, Evaluation Time: 0.2122 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 2, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 25, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 2, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 25, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 387.9952, Test MSE: 232.0413, Train MAE: 11.5328, Test MAE: 8.7194
# Train RMSE: 19.6976, Test RMSE: 15.2329, Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9642, Test Accuracy: 0.9285
# Training Time: 200.6405 seconds, Evaluation Time: 0.2222 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 2, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 25, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 2, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 25, 'activation_function': <class 'torch.nn.modules.activation.ReLU'>}
# Results: Train MSE: 398.1420, Test MSE: 235.6054, Train MAE: 12.0242, Test MAE: 8.7649
# Train RMSE: 19.9535, Test RMSE: 15.3494, Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9639, Test Accuracy: 0.9264
# Training Time: 187.5314 seconds, Evaluation Time: 0.2342 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 2, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 25, 'activation_function': <class 'torch.nn.modules.activation.LeakyReLU'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 2, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 25, 'activation_function': <class 'torch.nn.modules.activation.LeakyReLU'>}
# Results: Train MSE: 401.0362, Test MSE: 240.5950, Train MAE: 11.2370, Test MAE: 8.8737
# Train RMSE: 20.0259, Test RMSE: 15.5111, Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9623, Test Accuracy: 0.9260
# Training Time: 147.6736 seconds, Evaluation Time: 0.2107 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 2, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 25, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 128, 'dense_dim': 96, 'num_layers': 2, 'dropout': 0.01, 'lr': 0.0001, 'batch_size': 64, 'optimizer_type': 'AdamW', 'patience': 25, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 383.5326, Test MSE: 232.9290, Train MAE: 10.8734, Test MAE: 8.6909
# Train RMSE: 19.5840, Test RMSE: 15.2620, Train R2: 0.9997, Test R2: 0.9995
# Train Accuracy: 0.9636, Test Accuracy: 0.9273
# Training Time: 179.9205 seconds, Evaluation Time: 0.2123 seconds
