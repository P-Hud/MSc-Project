# %%
# Data Manipulation and Preparation
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# PyTorch
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# Evaluation metrics and visualisation
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error

# Ensure GPU usage
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

import itertools
import time
import csv
import json
from IPython.display import Audio, display
import winsound
from threading import Thread
import os
import random
# Out:
# Using device: cuda

# %%
# Load cleaned dataset
df = pd.read_csv('dataframes/BTC_4h_wDiffs.csv')
df1 = pd.read_csv('dataframes/BTC_30min_wDiffs.csv')

# Convert to datetime 
df['open_time'] = pd.to_datetime(df['open_time'])
df['close_time'] = pd.to_datetime(df['close_time'])
df1['open_time'] = pd.to_datetime(df1['open_time'])
df1['close_time'] = pd.to_datetime(df1['close_time'])

# %%
price_features = ['close', 'high', 'low', 'volume', 'quote_vol', 'count', 'buy_base', 'buy_quote']
diff_features = ['close_diff', 'high_diff', 'low_diff']

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_dim, lstm_dim, dense_dim, output_dim, output_window_size, num_layers=1, dropout=0.0, activation_function=nn.ReLU):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_dim, lstm_dim, num_layers=num_layers, batch_first=True, dropout=(dropout if num_layers > 1 else 0))
        self.fc1 = nn.Linear(lstm_dim, dense_dim)
        self.activation = activation_function()
        self.fc2 = nn.Linear(dense_dim, output_dim * output_window_size)
        self.output_window_size = output_window_size

    def forward(self, x):
        x, _ = self.lstm(x)
        x = x[:, -1, :]
        x = self.fc1(x)
        x = self.activation(x)
        x = self.fc2(x)
        return x.view(-1, self.output_window_size, 1)

def create_sequences(data, target, input_window_size, output_window_size):
    sequences = []
    labels = []
    for i in range(len(data) - input_window_size - output_window_size + 1):
        seq = data[i:i + input_window_size]
        label = target[i + input_window_size:i + input_window_size + output_window_size]
        sequences.append(seq)
        labels.append(label)
    return np.array(sequences), np.array(labels)

def prepare_data(df, target_column, input_window_size, output_window_size, feature_columns):
    X = df[feature_columns].values
    y = df[target_column].values.reshape(-1, 1)
    
    scaler_X = MinMaxScaler()
    X_scaled = scaler_X.fit_transform(X)

    scaler_y = MinMaxScaler()
    y_scaled = scaler_y.fit_transform(y)

    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, shuffle=False)
    X_train_seq, y_train_seq = create_sequences(X_train, y_train, input_window_size, output_window_size)
    X_test_seq, y_test_seq = create_sequences(X_test, y_test, input_window_size, output_window_size)

    return X_train_seq, X_test_seq, y_train_seq, y_test_seq, scaler_y

def plot_and_save_loss(training_loss, validation_loss, file_prefix, model_counter, start_epoch=3):
    plt.figure(figsize=(10, 6))
    plt.plot(range(start_epoch, len(training_loss)), training_loss[start_epoch:], label='Training Loss')
    plt.plot(range(start_epoch, len(validation_loss)), validation_loss[start_epoch:], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title(f'Model {model_counter} - Training and Validation Loss Over Epochs')
    plt.legend()
    plt.savefig(f'{file_prefix}_loss_plot_model_{model_counter}.png')
    plt.close()

    loss_df = pd.DataFrame({
        "Epoch": range(len(training_loss)),
        "Training Loss": training_loss,
        "Validation Loss": validation_loss
    })
    loss_file_path = f'{file_prefix}_losses_model_{model_counter}.csv'
    loss_df.to_csv(loss_file_path, index=False)

def save_predictions(y_train, y_train_pred, y_test, y_test_pred, model_counter, file_prefix):
    train_df = pd.DataFrame({"Actual": y_train.flatten(), f"Model_{model_counter}": y_train_pred.flatten()})
    test_df = pd.DataFrame({"Actual": y_test.flatten(), f"Model_{model_counter}": y_test_pred.flatten()})

    train_file_path = f"{file_prefix}_train_predictions_model_{model_counter}.csv"
    test_file_path = f"{file_prefix}_test_predictions_model_{model_counter}.csv"
    train_df.to_csv(train_file_path, index=False)
    test_df.to_csv(test_file_path, index=False)

# %%
def train_and_evaluate(df, target_column, feature_columns, params, model_counter, file_prefix='results', use_early_stopping=False, plot_loss=False):
    result = {}
    try:
        window_size = params['window_size']
        output_window_size = params['output_window_size']
        lstm_dim = params['lstm_dim']
        dense_dim = params['dense_dim']
        num_layers = params['num_layers']
        dropout = params['dropout']
        lr = params['lr']
        batch_size = params['batch_size']
        num_epochs = params['num_epochs']
        optimizer_type = params['optimizer_type']
        patience = params['patience']
        activation_function = params['activation_function']

        X_train_seq, X_test_seq, y_train_seq, y_test_seq, scaler_y = prepare_data(df, target_column, window_size, output_window_size, feature_columns)

        X_train_tensor = torch.tensor(X_train_seq, dtype=torch.float32).to(device)
        X_test_tensor = torch.tensor(X_test_seq, dtype=torch.float32).to(device)
        y_train_tensor = torch.tensor(y_train_seq, dtype=torch.float32).to(device)
        y_test_tensor = torch.tensor(y_test_seq, dtype=torch.float32).to(device)

        train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
        test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
        train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
        test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

        input_dim = X_train_tensor.shape[2]
        output_dim = 1

        model = LSTMModel(input_dim, lstm_dim, dense_dim, output_dim, output_window_size, num_layers, dropout, activation_function).to(device)

        criterion = nn.MSELoss()
        optimizer = getattr(optim, optimizer_type)(model.parameters(), lr=lr)

        best_loss = float('inf')
        patience_counter = 0
        start_time = time.time()

        training_losses = []
        validation_losses = []

        for epoch in range(num_epochs):
            model.train()
            epoch_train_loss = 0
            for inputs, labels in train_loader:
                optimizer.zero_grad()
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()
                epoch_train_loss += loss.item()

            epoch_train_loss /= len(train_loader)
            training_losses.append(epoch_train_loss)

            model.eval()
            val_loss = 0
            with torch.no_grad():
                for inputs, labels in test_loader:
                    outputs = model(inputs)
                    val_loss += criterion(outputs, labels).item()

            val_loss /= len(test_loader)
            validation_losses.append(val_loss)

            if use_early_stopping:
                if val_loss < best_loss:
                    best_loss = val_loss
                    patience_counter = 0
                else:
                    patience_counter += 1
                    if patience_counter >= patience:
                        print(f"Early stopping triggered at epoch {epoch}")
                        break

        training_time = time.time() - start_time

        model.eval()
        evaluation_start_time = time.time()
        with torch.no_grad():
            train_predictions = model(X_train_tensor).cpu().numpy()
            test_predictions = model(X_test_tensor).cpu().numpy()

            train_predictions_inverse = scaler_y.inverse_transform(train_predictions.reshape(-1, output_window_size))
            test_predictions_inverse = scaler_y.inverse_transform(test_predictions.reshape(-1, output_window_size))
            y_train_inverse = scaler_y.inverse_transform(y_train_seq.reshape(-1, output_window_size))
            y_test_inverse = scaler_y.inverse_transform(y_test_seq.reshape(-1, output_window_size))

            # Compute metrics for each step in the prediction window
            train_mse = np.mean([mean_squared_error(y_train_inverse[:, i], train_predictions_inverse[:, i]) for i in range(output_window_size)])
            test_mse = np.mean([mean_squared_error(y_test_inverse[:, i], test_predictions_inverse[:, i]) for i in range(output_window_size)])
            train_mae = np.mean([mean_absolute_error(y_train_inverse[:, i], train_predictions_inverse[:, i]) for i in range(output_window_size)])
            test_mae = np.mean([mean_absolute_error(y_test_inverse[:, i], test_predictions_inverse[:, i]) for i in range(output_window_size)])
            train_rmse = np.sqrt(train_mse)
            test_rmse = np.sqrt(test_mse)
            train_r2 = np.mean([r2_score(y_train_inverse[:, i], train_predictions_inverse[:, i]) for i in range(output_window_size)])
            test_r2 = np.mean([r2_score(y_test_inverse[:, i], test_predictions_inverse[:, i]) for i in range(output_window_size)])

            train_mape = np.mean([mean_absolute_percentage_error(y_train_inverse[:, i], train_predictions_inverse[:, i]) * 100 for i in range(output_window_size)])
            test_mape = np.mean([mean_absolute_percentage_error(y_test_inverse[:, i], test_predictions_inverse[:, i]) * 100 for i in range(output_window_size)])

            train_directional_acc = np.mean([np.mean(np.sign(y_train_inverse[1:, i] - y_train_inverse[:-1, i]) == np.sign(train_predictions_inverse[1:, i] - train_predictions_inverse[:-1, i])) for i in range(output_window_size)])
            test_directional_acc = np.mean([np.mean(np.sign(y_test_inverse[1:, i] - y_test_inverse[:-1, i]) == np.sign(test_predictions_inverse[1:, i] - test_predictions_inverse[:-1, i])) for i in range(output_window_size)])

        evaluation_time = time.time() - evaluation_start_time

        result = {
            "window_size": window_size,
            "output_window_size": output_window_size,
            "lstm_dim": lstm_dim,
            "num_layers": num_layers,
            "dense_dim": dense_dim,
            "dropout": dropout,
            "lr": lr,
            "batch_size": batch_size,
            "num_epochs": num_epochs,
            "optimizer_type": optimizer_type,
            "train_mse": train_mse,
            "test_mse": test_mse,
            "train_mae": train_mae,
            "test_mae": test_mae,
            "train_rmse": train_rmse,
            "test_rmse": test_rmse,
            "train_r2": train_r2,
            "test_r2": test_r2,
            "train_mape": train_mape,
            "test_mape": test_mape,
            "train_directional_acc": train_directional_acc,
            "test_directional_acc": test_directional_acc,
            "training_time": training_time,
            "evaluation_time": evaluation_time,
            "patience": patience,
            "activation_function": activation_function.__name__
        }

        with open(f'{file_prefix}_{target_column}.csv', 'a', newline='') as f:
            writer = csv.DictWriter(f, fieldnames=result.keys())
            if f.tell() == 0:
                writer.writeheader()
            writer.writerow(result)

        save_predictions(y_train_inverse, train_predictions_inverse, y_test_inverse, test_predictions_inverse, model_counter, file_prefix)

        if plot_loss:
            plot_and_save_loss(training_losses, validation_losses, file_prefix, model_counter)

        print(f"Results: Train MAE: {train_mae:.4f}, Test MAE: {test_mae:.4f}")
        print(f"Train Directional Accuracy: {train_directional_acc:.4f}, Test Directional Accuracy: {test_directional_acc:.4f}")
        print(f"Training Time: {training_time:.4f} seconds, Evaluation Time: {evaluation_time:.4f} seconds\n")

    except Exception as e:
        print(f"An error occurred: {e}")
        result = {
            "window_size": window_size,
            "output_window_size": output_window_size,
            "lstm_dim": lstm_dim,
            "num_layers": num_layers,
            "dense_dim": dense_dim,
            "dropout": dropout,
            "lr": lr,
            "batch_size": batch_size,
            "num_epochs": num_epochs,
            "optimizer_type": optimizer_type,
            "error": str(e)
        }
    finally:
        torch.cuda.empty_cache()

    return result

# %%
parameter_space = {
    'window_size': [6],
    'output_window_size': [6],
    'lstm_dim': [50, 80, 110, 140],
    'dense_dim': [50, 80, 110, 140],
    'num_layers': [1],
    'dropout': [0.0],
    'lr': [0.0001, 0.0002, 0.00005],
    'num_epochs': [50, 80, 110, 140, 170, 200],
    'batch_size': [32, 64, 96],
    'optimizer_type': ['Adam'],
    'patience': [24],
    'activation_function': [nn.Tanh]
}

# %%
# Random search implementation
target_column = 'close_diff'
features = price_features + diff_features
file_prefix='LSTM_4h_future_randomsearch'

start = time.time()

# Set seed for reproducibility
random.seed(42)

# Generate random sample of parameter combinations
parameter_combinations = list(itertools.product(*parameter_space.values()))
random.shuffle(parameter_combinations)
random_sample = parameter_combinations[:100]

model_counter = 1

for params in random_sample:
    param_dict = dict(zip(parameter_space.keys(), params))
    print(f"Running model {model_counter}/{100} with parameters: {param_dict}\n")
    
    train_and_evaluate(df, target_column=target_column, feature_columns=features, params=param_dict, model_counter=model_counter, file_prefix=file_prefix, use_early_stopping=False, plot_loss=False)
    
    model_counter += 1

end = time.time()
total_time = end - start

print(f"Total time taken: {total_time} seconds")
# Out:
# Running model 1/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 140, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 170, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.1206, Test MAE: 112.8936
# Train Directional Accuracy: 0.5439, Test Directional Accuracy: 0.5095
# Training Time: 64.3928 seconds, Evaluation Time: 0.1711 seconds
#
# Running model 2/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 50, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 50, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 92.8965, Test MAE: 83.2393
# Train Directional Accuracy: 0.4730, Test Directional Accuracy: 0.4824
# Training Time: 17.3577 seconds, Evaluation Time: 0.0145 seconds
#
# Running model 3/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 80, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 140, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.1562, Test MAE: 90.3627
# Train Directional Accuracy: 0.5461, Test Directional Accuracy: 0.5273
# Training Time: 50.2909 seconds, Evaluation Time: 0.0205 seconds
#
# Running model 4/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 140, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 80, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 94.0714, Test MAE: 90.3957
# Train Directional Accuracy: 0.5367, Test Directional Accuracy: 0.5241
# Training Time: 30.3722 seconds, Evaluation Time: 0.2026 seconds
#
# Running model 5/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 170, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 94.3291, Test MAE: 91.1130
# Train Directional Accuracy: 0.5427, Test Directional Accuracy: 0.5310
# Training Time: 61.5851 seconds, Evaluation Time: 0.0270 seconds
#
# Running model 6/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 170, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.0175, Test MAE: 88.2147
# Train Directional Accuracy: 0.5464, Test Directional Accuracy: 0.5219
# Training Time: 34.2412 seconds, Evaluation Time: 0.0320 seconds
#
# Running model 7/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 50, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 110, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 95.2702, Test MAE: 91.3798
# Train Directional Accuracy: 0.5467, Test Directional Accuracy: 0.5253
# Training Time: 40.8881 seconds, Evaluation Time: 0.0215 seconds
#
# Running model 8/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 92.3801, Test MAE: 89.9178
# Train Directional Accuracy: 0.5494, Test Directional Accuracy: 0.5212
# Training Time: 74.9589 seconds, Evaluation Time: 0.0300 seconds
#
# Running model 9/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 50, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 50, 'batch_size': 96, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 94.3229, Test MAE: 84.6637
# Train Directional Accuracy: 0.4699, Test Directional Accuracy: 0.4827
# Training Time: 7.1397 seconds, Evaluation Time: 0.0300 seconds
#
# Running model 10/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 80, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 80, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.4385, Test MAE: 86.0662
# Train Directional Accuracy: 0.4755, Test Directional Accuracy: 0.4840
# Training Time: 16.3727 seconds, Evaluation Time: 0.0320 seconds
#
# Running model 11/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 50, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 140, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.3812, Test MAE: 87.4569
# Train Directional Accuracy: 0.5093, Test Directional Accuracy: 0.5001
# Training Time: 52.1370 seconds, Evaluation Time: 0.0205 seconds
#
# Running model 12/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 140, 'batch_size': 96, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.9030, Test MAE: 88.0343
# Train Directional Accuracy: 0.4804, Test Directional Accuracy: 0.4810
# Training Time: 20.3029 seconds, Evaluation Time: 0.0275 seconds
#
# Running model 13/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 140, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 140, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.4354, Test MAE: 87.1223
# Train Directional Accuracy: 0.4981, Test Directional Accuracy: 0.4927
# Training Time: 27.7354 seconds, Evaluation Time: 0.2027 seconds
#
# Running model 14/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 140, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 200, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 94.9608, Test MAE: 120.6317
# Train Directional Accuracy: 0.5452, Test Directional Accuracy: 0.5130
# Training Time: 73.9792 seconds, Evaluation Time: 0.1787 seconds
#
# Running model 15/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 140, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 94.1228, Test MAE: 93.2839
# Train Directional Accuracy: 0.5347, Test Directional Accuracy: 0.5217
# Training Time: 26.5578 seconds, Evaluation Time: 0.0285 seconds
#
# Running model 16/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 200, 'batch_size': 96, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 92.9583, Test MAE: 85.0206
# Train Directional Accuracy: 0.5084, Test Directional Accuracy: 0.5084
# Training Time: 27.7600 seconds, Evaluation Time: 0.0255 seconds
#
# Running model 17/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 50, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 170, 'batch_size': 96, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 92.7362, Test MAE: 89.7954
# Train Directional Accuracy: 0.5432, Test Directional Accuracy: 0.5323
# Training Time: 23.2099 seconds, Evaluation Time: 0.0190 seconds
#
# Running model 18/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 50, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 80, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.5445, Test MAE: 90.9469
# Train Directional Accuracy: 0.5429, Test Directional Accuracy: 0.5282
# Training Time: 28.1017 seconds, Evaluation Time: 0.0290 seconds
#
# Running model 19/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 80, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 140, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.7057, Test MAE: 98.4234
# Train Directional Accuracy: 0.5495, Test Directional Accuracy: 0.5249
# Training Time: 28.4663 seconds, Evaluation Time: 0.0205 seconds
#
# Running model 20/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 80, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 50, 'batch_size': 96, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.0883, Test MAE: 85.6553
# Train Directional Accuracy: 0.4828, Test Directional Accuracy: 0.4990
# Training Time: 7.1140 seconds, Evaluation Time: 0.0355 seconds
#
# Running model 21/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 80, 'batch_size': 96, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.8683, Test MAE: 84.3752
# Train Directional Accuracy: 0.4725, Test Directional Accuracy: 0.4869
# Training Time: 11.4955 seconds, Evaluation Time: 0.0260 seconds
#
# Running model 22/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 140, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 92.7436, Test MAE: 88.8176
# Train Directional Accuracy: 0.5083, Test Directional Accuracy: 0.5019
# Training Time: 27.9708 seconds, Evaluation Time: 0.0285 seconds
#
# Running model 23/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 80, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 200, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 94.6699, Test MAE: 108.8588
# Train Directional Accuracy: 0.5467, Test Directional Accuracy: 0.5150
# Training Time: 73.3683 seconds, Evaluation Time: 0.0210 seconds
#
# Running model 24/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 50, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 170, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 92.7157, Test MAE: 85.4165
# Train Directional Accuracy: 0.5074, Test Directional Accuracy: 0.5099
# Training Time: 34.2278 seconds, Evaluation Time: 0.0160 seconds
#
# Running model 25/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 80, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 200, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.5190, Test MAE: 86.8167
# Train Directional Accuracy: 0.5417, Test Directional Accuracy: 0.5341
# Training Time: 72.7356 seconds, Evaluation Time: 0.0210 seconds
#
# Running model 26/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 140, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.6911, Test MAE: 96.0954
# Train Directional Accuracy: 0.5485, Test Directional Accuracy: 0.5231
# Training Time: 50.4380 seconds, Evaluation Time: 0.0255 seconds
#
# Running model 27/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 80, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 110, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.7825, Test MAE: 85.4126
# Train Directional Accuracy: 0.5338, Test Directional Accuracy: 0.5245
# Training Time: 21.5619 seconds, Evaluation Time: 0.0195 seconds
#
# Running model 28/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 50, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 50, 'batch_size': 96, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.9284, Test MAE: 85.4134
# Train Directional Accuracy: 0.4652, Test Directional Accuracy: 0.4740
# Training Time: 7.0057 seconds, Evaluation Time: 0.0180 seconds
#
# Running model 29/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 140, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 200, 'batch_size': 96, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.2829, Test MAE: 88.9366
# Train Directional Accuracy: 0.5300, Test Directional Accuracy: 0.5221
# Training Time: 28.6064 seconds, Evaluation Time: 0.1036 seconds
#
# Running model 30/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 140, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 50, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 95.4286, Test MAE: 90.5724
# Train Directional Accuracy: 0.5411, Test Directional Accuracy: 0.5375
# Training Time: 18.8273 seconds, Evaluation Time: 0.0886 seconds
#
# Running model 31/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 50, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 94.1612, Test MAE: 86.8742
# Train Directional Accuracy: 0.5422, Test Directional Accuracy: 0.5265
# Training Time: 17.5257 seconds, Evaluation Time: 0.0300 seconds
#
# Running model 32/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 80, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.6095, Test MAE: 85.3875
# Train Directional Accuracy: 0.4854, Test Directional Accuracy: 0.4841
# Training Time: 28.7057 seconds, Evaluation Time: 0.0245 seconds
#
# Running model 33/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 80, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 94.0232, Test MAE: 85.6274
# Train Directional Accuracy: 0.4746, Test Directional Accuracy: 0.4890
# Training Time: 16.0514 seconds, Evaluation Time: 0.0270 seconds
#
# Running model 34/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 80, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 94.0839, Test MAE: 91.0914
# Train Directional Accuracy: 0.5004, Test Directional Accuracy: 0.5006
# Training Time: 28.9928 seconds, Evaluation Time: 0.0260 seconds
#
# Running model 35/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 80, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 200, 'batch_size': 96, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.2505, Test MAE: 89.0511
# Train Directional Accuracy: 0.5117, Test Directional Accuracy: 0.5035
# Training Time: 28.1524 seconds, Evaluation Time: 0.0210 seconds
#
# Running model 36/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 80, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 170, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 92.6134, Test MAE: 85.9222
# Train Directional Accuracy: 0.5392, Test Directional Accuracy: 0.5255
# Training Time: 60.4540 seconds, Evaluation Time: 0.0225 seconds
#
# Running model 37/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 50, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 140, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 92.9690, Test MAE: 90.3416
# Train Directional Accuracy: 0.5335, Test Directional Accuracy: 0.5150
# Training Time: 27.0626 seconds, Evaluation Time: 0.0165 seconds
#
# Running model 38/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 110, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 94.0854, Test MAE: 93.5766
# Train Directional Accuracy: 0.5433, Test Directional Accuracy: 0.5134
# Training Time: 39.6966 seconds, Evaluation Time: 0.0286 seconds
#
# Running model 39/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 140, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 50, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 97.1722, Test MAE: 85.5037
# Train Directional Accuracy: 0.4809, Test Directional Accuracy: 0.4824
# Training Time: 18.9738 seconds, Evaluation Time: 0.1011 seconds
#
# Running model 40/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 140, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 50, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 97.5546, Test MAE: 89.2750
# Train Directional Accuracy: 0.5315, Test Directional Accuracy: 0.5191
# Training Time: 18.7418 seconds, Evaluation Time: 0.1791 seconds
#
# Running model 41/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 200, 'batch_size': 96, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.0038, Test MAE: 93.7860
# Train Directional Accuracy: 0.5486, Test Directional Accuracy: 0.5207
# Training Time: 28.3784 seconds, Evaluation Time: 0.0561 seconds
#
# Running model 42/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 80, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.8195, Test MAE: 85.3214
# Train Directional Accuracy: 0.4890, Test Directional Accuracy: 0.4880
# Training Time: 15.5993 seconds, Evaluation Time: 0.0245 seconds
#
# Running model 43/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 140, 'batch_size': 96, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.8688, Test MAE: 90.8428
# Train Directional Accuracy: 0.5367, Test Directional Accuracy: 0.5316
# Training Time: 19.8692 seconds, Evaluation Time: 0.0330 seconds
#
# Running model 44/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 80, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 170, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.4176, Test MAE: 90.0379
# Train Directional Accuracy: 0.5116, Test Directional Accuracy: 0.5079
# Training Time: 60.4409 seconds, Evaluation Time: 0.0245 seconds
#
# Running model 45/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 50, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 200, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 92.8476, Test MAE: 85.9854
# Train Directional Accuracy: 0.5378, Test Directional Accuracy: 0.5213
# Training Time: 71.6484 seconds, Evaluation Time: 0.0160 seconds
#
# Running model 46/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 80, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 110, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.4684, Test MAE: 88.2690
# Train Directional Accuracy: 0.5433, Test Directional Accuracy: 0.5296
# Training Time: 39.6153 seconds, Evaluation Time: 0.0205 seconds
#
# Running model 47/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 50, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 200, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 94.2019, Test MAE: 88.8709
# Train Directional Accuracy: 0.5456, Test Directional Accuracy: 0.5144
# Training Time: 71.9012 seconds, Evaluation Time: 0.0170 seconds
#
# Running model 48/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 80, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 140, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.7223, Test MAE: 89.9504
# Train Directional Accuracy: 0.4949, Test Directional Accuracy: 0.4940
# Training Time: 28.4090 seconds, Evaluation Time: 0.0200 seconds
#
# Running model 49/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 50, 'batch_size': 96, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 94.1487, Test MAE: 86.5495
# Train Directional Accuracy: 0.4758, Test Directional Accuracy: 0.4931
# Training Time: 7.2225 seconds, Evaluation Time: 0.0280 seconds
#
# Running model 50/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 80, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 110, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.7251, Test MAE: 88.6592
# Train Directional Accuracy: 0.5082, Test Directional Accuracy: 0.5091
# Training Time: 40.6173 seconds, Evaluation Time: 0.0205 seconds
#
# Running model 51/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 140, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 170, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 92.7949, Test MAE: 90.9595
# Train Directional Accuracy: 0.5472, Test Directional Accuracy: 0.5203
# Training Time: 67.5790 seconds, Evaluation Time: 0.1501 seconds
#
# Running model 52/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 140, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 50, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 94.2011, Test MAE: 85.6347
# Train Directional Accuracy: 0.4686, Test Directional Accuracy: 0.4739
# Training Time: 10.6251 seconds, Evaluation Time: 0.1636 seconds
#
# Running model 53/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 50, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 80, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 94.1424, Test MAE: 83.6640
# Train Directional Accuracy: 0.4893, Test Directional Accuracy: 0.5002
# Training Time: 16.3657 seconds, Evaluation Time: 0.0220 seconds
#
# Running model 54/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 140, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 94.9793, Test MAE: 87.2639
# Train Directional Accuracy: 0.5412, Test Directional Accuracy: 0.5315
# Training Time: 52.4682 seconds, Evaluation Time: 0.0280 seconds
#
# Running model 55/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 80, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 80, 'batch_size': 96, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.2798, Test MAE: 89.4649
# Train Directional Accuracy: 0.4976, Test Directional Accuracy: 0.5069
# Training Time: 12.3545 seconds, Evaluation Time: 0.0255 seconds
#
# Running model 56/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 140, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 50, 'batch_size': 96, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 94.2421, Test MAE: 83.3108
# Train Directional Accuracy: 0.4741, Test Directional Accuracy: 0.4830
# Training Time: 7.7098 seconds, Evaluation Time: 0.0986 seconds
#
# Running model 57/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 140, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 140, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 95.2792, Test MAE: 90.1434
# Train Directional Accuracy: 0.5475, Test Directional Accuracy: 0.5195
# Training Time: 29.7095 seconds, Evaluation Time: 0.1711 seconds
#
# Running model 58/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 92.6947, Test MAE: 90.4501
# Train Directional Accuracy: 0.5398, Test Directional Accuracy: 0.5291
# Training Time: 40.4597 seconds, Evaluation Time: 0.0310 seconds
#
# Running model 59/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 80, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 110, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 98.6932, Test MAE: 88.7346
# Train Directional Accuracy: 0.5464, Test Directional Accuracy: 0.5197
# Training Time: 40.5443 seconds, Evaluation Time: 0.0225 seconds
#
# Running model 60/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 94.0538, Test MAE: 98.2277
# Train Directional Accuracy: 0.5491, Test Directional Accuracy: 0.5189
# Training Time: 73.9433 seconds, Evaluation Time: 0.0250 seconds
#
# Running model 61/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 80, 'batch_size': 96, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.8875, Test MAE: 83.7711
# Train Directional Accuracy: 0.4731, Test Directional Accuracy: 0.4769
# Training Time: 11.4401 seconds, Evaluation Time: 0.0260 seconds
#
# Running model 62/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 170, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 94.3803, Test MAE: 92.6868
# Train Directional Accuracy: 0.5459, Test Directional Accuracy: 0.5174
# Training Time: 33.7655 seconds, Evaluation Time: 0.0265 seconds
#
# Running model 63/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 140, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 170, 'batch_size': 96, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.1947, Test MAE: 87.3974
# Train Directional Accuracy: 0.5172, Test Directional Accuracy: 0.5095
# Training Time: 25.0812 seconds, Evaluation Time: 0.1566 seconds
#
# Running model 64/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 140, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 110, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.3603, Test MAE: 89.7022
# Train Directional Accuracy: 0.5250, Test Directional Accuracy: 0.5119
# Training Time: 41.6547 seconds, Evaluation Time: 0.1486 seconds
#
# Running model 65/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 80, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 140, 'batch_size': 96, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 95.0972, Test MAE: 94.3962
# Train Directional Accuracy: 0.5450, Test Directional Accuracy: 0.5363
# Training Time: 20.4078 seconds, Evaluation Time: 0.0370 seconds
#
# Running model 66/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 110, 'batch_size': 96, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 92.8984, Test MAE: 84.4435
# Train Directional Accuracy: 0.4755, Test Directional Accuracy: 0.4839
# Training Time: 15.9217 seconds, Evaluation Time: 0.0250 seconds
#
# Running model 67/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 200, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 95.4952, Test MAE: 98.9643
# Train Directional Accuracy: 0.5467, Test Directional Accuracy: 0.5225
# Training Time: 73.3479 seconds, Evaluation Time: 0.0260 seconds
#
# Running model 68/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 80, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 110, 'batch_size': 96, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.3663, Test MAE: 86.6436
# Train Directional Accuracy: 0.5373, Test Directional Accuracy: 0.5252
# Training Time: 16.2671 seconds, Evaluation Time: 0.0325 seconds
#
# Running model 69/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 170, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.8202, Test MAE: 93.5817
# Train Directional Accuracy: 0.5455, Test Directional Accuracy: 0.5330
# Training Time: 61.7925 seconds, Evaluation Time: 0.0285 seconds
#
# Running model 70/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 80, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 50, 'batch_size': 96, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 95.1031, Test MAE: 88.5817
# Train Directional Accuracy: 0.4852, Test Directional Accuracy: 0.4971
# Training Time: 7.5395 seconds, Evaluation Time: 0.0340 seconds
#
# Running model 71/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 140, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 50, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.7975, Test MAE: 86.6671
# Train Directional Accuracy: 0.4735, Test Directional Accuracy: 0.4806
# Training Time: 10.4520 seconds, Evaluation Time: 0.1577 seconds
#
# Running model 72/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 80, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 170, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 95.4278, Test MAE: 94.4781
# Train Directional Accuracy: 0.5457, Test Directional Accuracy: 0.5230
# Training Time: 34.3472 seconds, Evaluation Time: 0.0260 seconds
#
# Running model 73/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 140, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 170, 'batch_size': 96, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 92.8233, Test MAE: 88.9331
# Train Directional Accuracy: 0.5124, Test Directional Accuracy: 0.5093
# Training Time: 25.5222 seconds, Evaluation Time: 0.1116 seconds
#
# Running model 74/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 50, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 110, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 94.4828, Test MAE: 89.6667
# Train Directional Accuracy: 0.5495, Test Directional Accuracy: 0.5217
# Training Time: 40.0495 seconds, Evaluation Time: 0.0210 seconds
#
# Running model 75/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 140, 'batch_size': 96, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 92.6664, Test MAE: 90.3659
# Train Directional Accuracy: 0.5245, Test Directional Accuracy: 0.5158
# Training Time: 20.3226 seconds, Evaluation Time: 0.0270 seconds
#
# Running model 76/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 170, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 94.7590, Test MAE: 112.2482
# Train Directional Accuracy: 0.5460, Test Directional Accuracy: 0.5102
# Training Time: 61.7833 seconds, Evaluation Time: 0.0265 seconds
#
# Running model 77/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 110, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.0659, Test MAE: 86.4222
# Train Directional Accuracy: 0.5206, Test Directional Accuracy: 0.5099
# Training Time: 40.3445 seconds, Evaluation Time: 0.0285 seconds
#
# Running model 78/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 50, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 50, 'batch_size': 96, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.6426, Test MAE: 86.3977
# Train Directional Accuracy: 0.4697, Test Directional Accuracy: 0.4782
# Training Time: 7.3582 seconds, Evaluation Time: 0.0240 seconds
#
# Running model 79/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 80, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 110, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 92.0694, Test MAE: 90.3311
# Train Directional Accuracy: 0.5463, Test Directional Accuracy: 0.5273
# Training Time: 40.0795 seconds, Evaluation Time: 0.0300 seconds
#
# Running model 80/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 140, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 80, 'batch_size': 96, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 94.8773, Test MAE: 92.8743
# Train Directional Accuracy: 0.5043, Test Directional Accuracy: 0.5037
# Training Time: 11.9933 seconds, Evaluation Time: 0.1496 seconds
#
# Running model 81/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 140, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 80, 'batch_size': 96, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.3184, Test MAE: 85.0668
# Train Directional Accuracy: 0.5103, Test Directional Accuracy: 0.5097
# Training Time: 11.7468 seconds, Evaluation Time: 0.1601 seconds
#
# Running model 82/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 80, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 50, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 94.8187, Test MAE: 87.3859
# Train Directional Accuracy: 0.4821, Test Directional Accuracy: 0.4871
# Training Time: 9.3700 seconds, Evaluation Time: 0.0215 seconds
#
# Running model 83/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 140, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 94.8708, Test MAE: 101.9752
# Train Directional Accuracy: 0.5502, Test Directional Accuracy: 0.5235
# Training Time: 76.8370 seconds, Evaluation Time: 0.1561 seconds
#
# Running model 84/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 140, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 140, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 95.2426, Test MAE: 93.3589
# Train Directional Accuracy: 0.5476, Test Directional Accuracy: 0.5280
# Training Time: 53.8500 seconds, Evaluation Time: 0.1526 seconds
#
# Running model 85/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 140, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 110, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 96.6927, Test MAE: 85.1880
# Train Directional Accuracy: 0.5295, Test Directional Accuracy: 0.5142
# Training Time: 22.6339 seconds, Evaluation Time: 0.1646 seconds
#
# Running model 86/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 80, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 50, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.8393, Test MAE: 85.7075
# Train Directional Accuracy: 0.5028, Test Directional Accuracy: 0.4992
# Training Time: 18.1534 seconds, Evaluation Time: 0.0265 seconds
#
# Running model 87/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 50, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 80, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 92.9352, Test MAE: 83.5235
# Train Directional Accuracy: 0.4816, Test Directional Accuracy: 0.4916
# Training Time: 16.1049 seconds, Evaluation Time: 0.0325 seconds
#
# Running model 88/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 50, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 170, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.1901, Test MAE: 98.2039
# Train Directional Accuracy: 0.5478, Test Directional Accuracy: 0.5187
# Training Time: 34.7042 seconds, Evaluation Time: 0.0220 seconds
#
# Running model 89/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 140, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 80, 'batch_size': 96, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 94.3875, Test MAE: 88.9552
# Train Directional Accuracy: 0.4722, Test Directional Accuracy: 0.4786
# Training Time: 12.2378 seconds, Evaluation Time: 0.1516 seconds
#
# Running model 90/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 50, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 95.5598, Test MAE: 91.6752
# Train Directional Accuracy: 0.4752, Test Directional Accuracy: 0.4828
# Training Time: 9.7237 seconds, Evaluation Time: 0.0250 seconds
#
# Running model 91/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 140, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 50, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 95.2385, Test MAE: 90.5889
# Train Directional Accuracy: 0.4785, Test Directional Accuracy: 0.4888
# Training Time: 10.6104 seconds, Evaluation Time: 0.1571 seconds
#
# Running model 92/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 80, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 170, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.1004, Test MAE: 90.8917
# Train Directional Accuracy: 0.5479, Test Directional Accuracy: 0.5237
# Training Time: 34.0720 seconds, Evaluation Time: 0.0256 seconds
#
# Running model 93/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 140, 'batch_size': 96, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 92.4660, Test MAE: 86.1985
# Train Directional Accuracy: 0.5223, Test Directional Accuracy: 0.5122
# Training Time: 20.1959 seconds, Evaluation Time: 0.0290 seconds
#
# Running model 94/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 80, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 110, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.5412, Test MAE: 88.0363
# Train Directional Accuracy: 0.4991, Test Directional Accuracy: 0.4943
# Training Time: 22.5833 seconds, Evaluation Time: 0.0275 seconds
#
# Running model 95/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 50, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 110, 'batch_size': 96, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.9079, Test MAE: 85.3620
# Train Directional Accuracy: 0.4755, Test Directional Accuracy: 0.4779
# Training Time: 15.9667 seconds, Evaluation Time: 0.0250 seconds
#
# Running model 96/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 140, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 96.8223, Test MAE: 97.5754
# Train Directional Accuracy: 0.5499, Test Directional Accuracy: 0.5253
# Training Time: 41.6295 seconds, Evaluation Time: 0.1481 seconds
#
# Running model 97/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 110, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0002, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 93.7014, Test MAE: 89.3262
# Train Directional Accuracy: 0.5481, Test Directional Accuracy: 0.5183
# Training Time: 39.5417 seconds, Evaluation Time: 0.0280 seconds
#
# Running model 98/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 140, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 170, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 94.9015, Test MAE: 86.8489
# Train Directional Accuracy: 0.5399, Test Directional Accuracy: 0.5223
# Training Time: 35.5321 seconds, Evaluation Time: 0.1586 seconds
#
# Running model 99/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 140, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 50, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 96.6314, Test MAE: 87.8591
# Train Directional Accuracy: 0.5037, Test Directional Accuracy: 0.5034
# Training Time: 18.8589 seconds, Evaluation Time: 0.1576 seconds
#
# Running model 100/100 with parameters: {'window_size': 6, 'output_window_size': 6, 'lstm_dim': 140, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 200, 'batch_size': 32, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 100.4717, Test MAE: 101.6494
# Train Directional Accuracy: 0.5477, Test Directional Accuracy: 0.5254
# Training Time: 77.4467 seconds, Evaluation Time: 0.1596 seconds
#
# Total time taken: 3273.0019092559814 seconds

# %%
parameter_space = {
    'window_size': [48],
    'output_window_size': [48],
    'lstm_dim': [30, 50, 80, 110, 140],
    'dense_dim': [30, 50, 80, 110, 140],
    'num_layers': [1],
    'dropout': [0.0],
    'lr': [0.0001, 0.00005],
    'num_epochs': [50, 80, 110, 140, 170, 200],
    'batch_size': [10, 20, 30, 40],
    'optimizer_type': ['Adam'],
    'patience': [24],
    'activation_function': [nn.Tanh]
}

# %%
# Random search implementation
target_column = 'close_diff'
features = price_features + diff_features
file_prefix='LSTM_30min_future_randomsearch(1)'

start = time.time()

# Set seed for reproducibility
random.seed(42)

# Generate random sample of parameter combinations
parameter_combinations = list(itertools.product(*parameter_space.values()))
random.shuffle(parameter_combinations)
random_sample = parameter_combinations[:150]

model_counter = 1

for params in random_sample:
    param_dict = dict(zip(parameter_space.keys(), params))
    print(f"Running model {model_counter}/{150} with parameters: {param_dict}\n")
    
    train_and_evaluate(df1, target_column=target_column, feature_columns=features, params=param_dict, model_counter=model_counter, file_prefix=file_prefix, use_early_stopping=False, plot_loss=False)
    
    model_counter += 1

end = time.time()
total_time = end - start

print(f"Total time taken: {total_time} seconds")
# Out:
# Running model 1/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 50, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 80, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.5832, Test MAE: 29.6457
# Train Directional Accuracy: 0.5031, Test Directional Accuracy: 0.5031
# Training Time: 186.8269 seconds, Evaluation Time: 0.4246 seconds
#
# Running model 2/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 110, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 50, 'batch_size': 20, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.6761, Test MAE: 29.9787
# Train Directional Accuracy: 0.5022, Test Directional Accuracy: 0.5018
# Training Time: 211.2080 seconds, Evaluation Time: 0.6974 seconds
#
# Running model 3/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 80, 'dense_dim': 30, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 110, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.6702, Test MAE: 30.0062
# Train Directional Accuracy: 0.5034, Test Directional Accuracy: 0.5014
# Training Time: 253.9378 seconds, Evaluation Time: 0.5022 seconds
#
# Running model 4/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 50, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 170, 'batch_size': 30, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.4093, Test MAE: 29.9392
# Train Directional Accuracy: 0.5035, Test Directional Accuracy: 0.5038
# Training Time: 506.4038 seconds, Evaluation Time: 0.4144 seconds
#
# Running model 5/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 110, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.8513, Test MAE: 31.9044
# Train Directional Accuracy: 0.5036, Test Directional Accuracy: 0.5021
# Training Time: 443.2720 seconds, Evaluation Time: 0.6369 seconds
#
# Running model 6/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 30, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 110, 'batch_size': 20, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.5644, Test MAE: 29.8893
# Train Directional Accuracy: 0.5036, Test Directional Accuracy: 0.5046
# Training Time: 488.1680 seconds, Evaluation Time: 0.3152 seconds
#
# Running model 7/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 110, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 140, 'batch_size': 30, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.5775, Test MAE: 30.5433
# Train Directional Accuracy: 0.5029, Test Directional Accuracy: 0.5026
# Training Time: 407.1156 seconds, Evaluation Time: 0.7332 seconds
#
# Running model 8/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 80, 'dense_dim': 30, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 50, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.9814, Test MAE: 30.0073
# Train Directional Accuracy: 0.5022, Test Directional Accuracy: 0.5024
# Training Time: 417.8164 seconds, Evaluation Time: 0.5268 seconds
#
# Running model 9/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 50, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 140, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.2991, Test MAE: 29.4917
# Train Directional Accuracy: 0.5030, Test Directional Accuracy: 0.5024
# Training Time: 329.9734 seconds, Evaluation Time: 0.3637 seconds
#
# Running model 10/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 50, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 170, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.6733, Test MAE: 34.5682
# Train Directional Accuracy: 0.5053, Test Directional Accuracy: 0.5048
# Training Time: 1449.0279 seconds, Evaluation Time: 0.4661 seconds
#
# Running model 11/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 140, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 140, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.1675, Test MAE: 31.5822
# Train Directional Accuracy: 0.5046, Test Directional Accuracy: 0.5030
# Training Time: 1802.8689 seconds, Evaluation Time: 5.8897 seconds
#
# Running model 12/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 50, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 140, 'batch_size': 20, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.5188, Test MAE: 39.4083
# Train Directional Accuracy: 0.5033, Test Directional Accuracy: 0.5006
# Training Time: 585.3729 seconds, Evaluation Time: 0.4011 seconds
#
# Running model 13/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 30, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 170, 'batch_size': 30, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.3635, Test MAE: 29.6733
# Train Directional Accuracy: 0.5028, Test Directional Accuracy: 0.5025
# Training Time: 504.9791 seconds, Evaluation Time: 0.3945 seconds
#
# Running model 14/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 140, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 110, 'batch_size': 30, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.7162, Test MAE: 29.9623
# Train Directional Accuracy: 0.5032, Test Directional Accuracy: 0.5030
# Training Time: 492.2830 seconds, Evaluation Time: 4.9716 seconds
#
# Running model 15/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 110, 'dense_dim': 30, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 50, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 36.4770, Test MAE: 31.1455
# Train Directional Accuracy: 0.5020, Test Directional Accuracy: 0.5025
# Training Time: 111.2409 seconds, Evaluation Time: 0.6942 seconds
#
# Running model 16/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 110, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 80, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.5730, Test MAE: 30.9664
# Train Directional Accuracy: 0.5030, Test Directional Accuracy: 0.5018
# Training Time: 635.9553 seconds, Evaluation Time: 0.7327 seconds
#
# Running model 17/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 50, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 170, 'batch_size': 30, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.4400, Test MAE: 30.8248
# Train Directional Accuracy: 0.5024, Test Directional Accuracy: 0.5018
# Training Time: 492.6416 seconds, Evaluation Time: 0.4110 seconds
#
# Running model 18/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 30, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 80, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.5487, Test MAE: 31.6945
# Train Directional Accuracy: 0.5026, Test Directional Accuracy: 0.5020
# Training Time: 634.8800 seconds, Evaluation Time: 0.3845 seconds
#
# Running model 19/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 110, 'dense_dim': 30, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 170, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 35.3251, Test MAE: 31.0448
# Train Directional Accuracy: 0.5002, Test Directional Accuracy: 0.5005
# Training Time: 1338.1096 seconds, Evaluation Time: 0.6253 seconds
#
# Running model 20/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 30, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 140, 'batch_size': 20, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.3888, Test MAE: 30.2236
# Train Directional Accuracy: 0.5024, Test Directional Accuracy: 0.5017
# Training Time: 593.6871 seconds, Evaluation Time: 0.3953 seconds
#
# Running model 21/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 140, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 80, 'batch_size': 30, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.6545, Test MAE: 29.7008
# Train Directional Accuracy: 0.5033, Test Directional Accuracy: 0.5033
# Training Time: 355.0802 seconds, Evaluation Time: 4.2863 seconds
#
# Running model 22/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 30, 'dense_dim': 30, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 110, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.6528, Test MAE: 29.8568
# Train Directional Accuracy: 0.5029, Test Directional Accuracy: 0.5044
# Training Time: 246.6364 seconds, Evaluation Time: 0.3642 seconds
#
# Running model 23/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 110, 'dense_dim': 30, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 170, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.7544, Test MAE: 29.9758
# Train Directional Accuracy: 0.5030, Test Directional Accuracy: 0.5037
# Training Time: 377.5467 seconds, Evaluation Time: 0.6376 seconds
#
# Running model 24/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 50, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 50, 'batch_size': 20, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.8906, Test MAE: 29.7566
# Train Directional Accuracy: 0.5028, Test Directional Accuracy: 0.5025
# Training Time: 210.9258 seconds, Evaluation Time: 0.4019 seconds
#
# Running model 25/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 50, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 50, 'batch_size': 20, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.7398, Test MAE: 30.0123
# Train Directional Accuracy: 0.5032, Test Directional Accuracy: 0.5025
# Training Time: 211.1240 seconds, Evaluation Time: 0.4064 seconds
#
# Running model 26/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 140, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 110, 'batch_size': 30, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.4131, Test MAE: 29.8643
# Train Directional Accuracy: 0.5026, Test Directional Accuracy: 0.5029
# Training Time: 485.6057 seconds, Evaluation Time: 3.2994 seconds
#
# Running model 27/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 80, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 200, 'batch_size': 30, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.5690, Test MAE: 30.4761
# Train Directional Accuracy: 0.5023, Test Directional Accuracy: 0.5014
# Training Time: 583.0301 seconds, Evaluation Time: 0.5714 seconds
#
# Running model 28/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 110, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 110, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.2597, Test MAE: 34.2142
# Train Directional Accuracy: 0.5039, Test Directional Accuracy: 0.5028
# Training Time: 870.3898 seconds, Evaluation Time: 0.6129 seconds
#
# Running model 29/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 140, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 200, 'batch_size': 30, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.6752, Test MAE: 29.8714
# Train Directional Accuracy: 0.5031, Test Directional Accuracy: 0.5033
# Training Time: 883.5660 seconds, Evaluation Time: 2.8664 seconds
#
# Running model 30/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 30, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 170, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.5657, Test MAE: 29.5738
# Train Directional Accuracy: 0.5030, Test Directional Accuracy: 0.5032
# Training Time: 380.9300 seconds, Evaluation Time: 0.3250 seconds
#
# Running model 31/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 110, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 50, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.6706, Test MAE: 30.1696
# Train Directional Accuracy: 0.5024, Test Directional Accuracy: 0.5033
# Training Time: 112.1073 seconds, Evaluation Time: 0.6264 seconds
#
# Running model 32/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 30, 'dense_dim': 30, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 110, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.4936, Test MAE: 29.5389
# Train Directional Accuracy: 0.5024, Test Directional Accuracy: 0.5027
# Training Time: 877.1491 seconds, Evaluation Time: 0.3996 seconds
#
# Running model 33/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 50, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 110, 'batch_size': 30, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.3667, Test MAE: 29.5557
# Train Directional Accuracy: 0.5030, Test Directional Accuracy: 0.5021
# Training Time: 321.0982 seconds, Evaluation Time: 0.4157 seconds
#
# Running model 34/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 80, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 20, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.1707, Test MAE: 33.8410
# Train Directional Accuracy: 0.5044, Test Directional Accuracy: 0.5020
# Training Time: 845.0869 seconds, Evaluation Time: 0.5333 seconds
#
# Running model 35/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 30, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 110, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.5578, Test MAE: 29.5723
# Train Directional Accuracy: 0.5027, Test Directional Accuracy: 0.5030
# Training Time: 246.7298 seconds, Evaluation Time: 0.3934 seconds
#
# Running model 36/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 110, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.2231, Test MAE: 32.7685
# Train Directional Accuracy: 0.5042, Test Directional Accuracy: 0.5053
# Training Time: 874.4351 seconds, Evaluation Time: 0.6260 seconds
#
# Running model 37/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 140, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 50, 'batch_size': 30, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.7313, Test MAE: 29.6546
# Train Directional Accuracy: 0.5030, Test Directional Accuracy: 0.5026
# Training Time: 222.7847 seconds, Evaluation Time: 4.4178 seconds
#
# Running model 38/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 80, 'dense_dim': 30, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 140, 'batch_size': 30, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.6338, Test MAE: 29.8775
# Train Directional Accuracy: 0.5019, Test Directional Accuracy: 0.5020
# Training Time: 411.3605 seconds, Evaluation Time: 0.5687 seconds
#
# Running model 39/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 30, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 200, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.3898, Test MAE: 29.5628
# Train Directional Accuracy: 0.5033, Test Directional Accuracy: 0.5030
# Training Time: 450.6904 seconds, Evaluation Time: 0.3260 seconds
#
# Running model 40/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 110, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 200, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.4167, Test MAE: 33.1861
# Train Directional Accuracy: 0.5042, Test Directional Accuracy: 0.5040
# Training Time: 1572.8586 seconds, Evaluation Time: 0.6444 seconds
#
# Running model 41/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 140, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 110, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.6240, Test MAE: 32.1088
# Train Directional Accuracy: 0.5045, Test Directional Accuracy: 0.5024
# Training Time: 1411.2750 seconds, Evaluation Time: 9.2784 seconds
#
# Running model 42/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 80, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 110, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.5484, Test MAE: 33.1270
# Train Directional Accuracy: 0.5032, Test Directional Accuracy: 0.5020
# Training Time: 903.9141 seconds, Evaluation Time: 0.4921 seconds
#
# Running model 43/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 140, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 140, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.1586, Test MAE: 32.9505
# Train Directional Accuracy: 0.5036, Test Directional Accuracy: 0.5017
# Training Time: 1867.3373 seconds, Evaluation Time: 5.2771 seconds
#
# Running model 44/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 140, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 50, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 35.1392, Test MAE: 30.0704
# Train Directional Accuracy: 0.5026, Test Directional Accuracy: 0.5031
# Training Time: 663.9839 seconds, Evaluation Time: 3.5640 seconds
#
# Running model 45/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 50, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 170, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.3148, Test MAE: 30.5147
# Train Directional Accuracy: 0.5025, Test Directional Accuracy: 0.5019
# Training Time: 1393.0687 seconds, Evaluation Time: 0.4011 seconds
#
# Running model 46/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 140, 'batch_size': 20, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.2840, Test MAE: 29.9577
# Train Directional Accuracy: 0.5033, Test Directional Accuracy: 0.5034
# Training Time: 591.5449 seconds, Evaluation Time: 0.8317 seconds
#
# Running model 47/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 110, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 20, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.0632, Test MAE: 32.2152
# Train Directional Accuracy: 0.5054, Test Directional Accuracy: 0.5028
# Training Time: 853.5036 seconds, Evaluation Time: 0.7108 seconds
#
# Running model 48/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 110, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.5139, Test MAE: 31.5792
# Train Directional Accuracy: 0.5035, Test Directional Accuracy: 0.5033
# Training Time: 455.5410 seconds, Evaluation Time: 0.7602 seconds
#
# Running model 49/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 50, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 110, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.7903, Test MAE: 30.7357
# Train Directional Accuracy: 0.5026, Test Directional Accuracy: 0.5029
# Training Time: 255.7083 seconds, Evaluation Time: 0.4894 seconds
#
# Running model 50/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 110, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 50, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.7969, Test MAE: 29.7890
# Train Directional Accuracy: 0.5019, Test Directional Accuracy: 0.5019
# Training Time: 113.5178 seconds, Evaluation Time: 0.7153 seconds
#
# Running model 51/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 140, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 140, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.6013, Test MAE: 31.5445
# Train Directional Accuracy: 0.5020, Test Directional Accuracy: 0.5007
# Training Time: 1807.5190 seconds, Evaluation Time: 5.0692 seconds
#
# Running model 52/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 80, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 170, 'batch_size': 20, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.3814, Test MAE: 30.6920
# Train Directional Accuracy: 0.5034, Test Directional Accuracy: 0.5028
# Training Time: 716.5253 seconds, Evaluation Time: 0.5560 seconds
#
# Running model 53/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 80, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 50, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.3346, Test MAE: 29.6655
# Train Directional Accuracy: 0.5025, Test Directional Accuracy: 0.5013
# Training Time: 411.6540 seconds, Evaluation Time: 0.5471 seconds
#
# Running model 54/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 50, 'dense_dim': 30, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 20, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.7042, Test MAE: 30.7037
# Train Directional Accuracy: 0.5031, Test Directional Accuracy: 0.5027
# Training Time: 842.7367 seconds, Evaluation Time: 0.4242 seconds
#
# Running model 55/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 50, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 50, 'batch_size': 30, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.7055, Test MAE: 29.7391
# Train Directional Accuracy: 0.5017, Test Directional Accuracy: 0.5029
# Training Time: 146.0158 seconds, Evaluation Time: 0.4302 seconds
#
# Running model 56/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 30, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 110, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.6952, Test MAE: 36.2197
# Train Directional Accuracy: 0.5026, Test Directional Accuracy: 0.5010
# Training Time: 887.2101 seconds, Evaluation Time: 0.3997 seconds
#
# Running model 57/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 80, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 170, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.3744, Test MAE: 29.6735
# Train Directional Accuracy: 0.5032, Test Directional Accuracy: 0.5033
# Training Time: 386.6101 seconds, Evaluation Time: 0.5530 seconds
#
# Running model 58/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 30, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 50, 'batch_size': 20, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.2861, Test MAE: 29.4051
# Train Directional Accuracy: 0.5021, Test Directional Accuracy: 0.5037
# Training Time: 210.4977 seconds, Evaluation Time: 0.3988 seconds
#
# Running model 59/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 30, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 50, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.6110, Test MAE: 29.8483
# Train Directional Accuracy: 0.5007, Test Directional Accuracy: 0.5011
# Training Time: 397.8531 seconds, Evaluation Time: 0.4006 seconds
#
# Running model 60/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 110, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 80, 'batch_size': 30, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.2602, Test MAE: 29.3715
# Train Directional Accuracy: 0.5034, Test Directional Accuracy: 0.5033
# Training Time: 231.2363 seconds, Evaluation Time: 0.6488 seconds
#
# Running model 61/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 80, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 80, 'batch_size': 20, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.5547, Test MAE: 29.5469
# Train Directional Accuracy: 0.5032, Test Directional Accuracy: 0.5029
# Training Time: 336.3522 seconds, Evaluation Time: 0.5609 seconds
#
# Running model 62/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 110, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 140, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.5842, Test MAE: 30.1158
# Train Directional Accuracy: 0.5014, Test Directional Accuracy: 0.5014
# Training Time: 311.0535 seconds, Evaluation Time: 0.6822 seconds
#
# Running model 63/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 140, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 170, 'batch_size': 20, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.4687, Test MAE: 29.8256
# Train Directional Accuracy: 0.5030, Test Directional Accuracy: 0.5030
# Training Time: 1109.0504 seconds, Evaluation Time: 2.6457 seconds
#
# Running model 64/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 80, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 50, 'batch_size': 30, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.6450, Test MAE: 29.5641
# Train Directional Accuracy: 0.5000, Test Directional Accuracy: 0.4992
# Training Time: 149.0418 seconds, Evaluation Time: 0.5470 seconds
#
# Running model 65/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 140, 'dense_dim': 30, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 80, 'batch_size': 20, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.7656, Test MAE: 29.5915
# Train Directional Accuracy: 0.4999, Test Directional Accuracy: 0.4998
# Training Time: 518.7363 seconds, Evaluation Time: 2.2211 seconds
#
# Running model 66/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 30, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 140, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.4276, Test MAE: 29.4734
# Train Directional Accuracy: 0.5031, Test Directional Accuracy: 0.5036
# Training Time: 314.7759 seconds, Evaluation Time: 0.3959 seconds
#
# Running model 67/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 140, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 50, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.7861, Test MAE: 29.6855
# Train Directional Accuracy: 0.5027, Test Directional Accuracy: 0.5021
# Training Time: 166.9827 seconds, Evaluation Time: 2.3051 seconds
#
# Running model 68/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 30, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 110, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.2297, Test MAE: 30.7972
# Train Directional Accuracy: 0.5028, Test Directional Accuracy: 0.5013
# Training Time: 873.4052 seconds, Evaluation Time: 0.3622 seconds
#
# Running model 69/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 30, 'dense_dim': 30, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 140, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.4358, Test MAE: 30.8024
# Train Directional Accuracy: 0.5033, Test Directional Accuracy: 0.5033
# Training Time: 1112.9445 seconds, Evaluation Time: 0.3618 seconds
#
# Running model 70/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 50, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 200, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.5888, Test MAE: 32.2831
# Train Directional Accuracy: 0.5031, Test Directional Accuracy: 0.5020
# Training Time: 1600.2702 seconds, Evaluation Time: 0.4544 seconds
#
# Running model 71/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 110, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 140, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.4160, Test MAE: 29.9828
# Train Directional Accuracy: 0.5019, Test Directional Accuracy: 0.5017
# Training Time: 311.4870 seconds, Evaluation Time: 0.6391 seconds
#
# Running model 72/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 110, 'dense_dim': 30, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 140, 'batch_size': 20, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.9121, Test MAE: 29.7695
# Train Directional Accuracy: 0.4998, Test Directional Accuracy: 0.4998
# Training Time: 580.9143 seconds, Evaluation Time: 0.6376 seconds
#
# Running model 73/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 30, 'dense_dim': 30, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 80, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.8585, Test MAE: 30.3266
# Train Directional Accuracy: 0.5026, Test Directional Accuracy: 0.5027
# Training Time: 637.3316 seconds, Evaluation Time: 0.3851 seconds
#
# Running model 74/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 80, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 170, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.4061, Test MAE: 29.7835
# Train Directional Accuracy: 0.5038, Test Directional Accuracy: 0.5042
# Training Time: 384.0392 seconds, Evaluation Time: 0.5706 seconds
#
# Running model 75/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 140, 'dense_dim': 30, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 170, 'batch_size': 30, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.4159, Test MAE: 29.3799
# Train Directional Accuracy: 0.4999, Test Directional Accuracy: 0.5006
# Training Time: 750.4396 seconds, Evaluation Time: 3.7148 seconds
#
# Running model 76/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 30, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.1495, Test MAE: 39.3770
# Train Directional Accuracy: 0.5049, Test Directional Accuracy: 0.5017
# Training Time: 1599.7722 seconds, Evaluation Time: 0.3861 seconds
#
# Running model 77/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 50, 'dense_dim': 30, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 140, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.6585, Test MAE: 29.7213
# Train Directional Accuracy: 0.5017, Test Directional Accuracy: 0.5028
# Training Time: 1116.9611 seconds, Evaluation Time: 0.4647 seconds
#
# Running model 78/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 140, 'dense_dim': 30, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 140, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.7362, Test MAE: 29.6317
# Train Directional Accuracy: 0.4933, Test Directional Accuracy: 0.4985
# Training Time: 1749.2326 seconds, Evaluation Time: 3.7844 seconds
#
# Running model 79/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 140, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 80, 'batch_size': 30, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.4503, Test MAE: 29.6834
# Train Directional Accuracy: 0.5032, Test Directional Accuracy: 0.5028
# Training Time: 349.8604 seconds, Evaluation Time: 2.8343 seconds
#
# Running model 80/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 140, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.3425, Test MAE: 32.0855
# Train Directional Accuracy: 0.5041, Test Directional Accuracy: 0.5031
# Training Time: 672.3054 seconds, Evaluation Time: 2.6991 seconds
#
# Running model 81/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 80, 'dense_dim': 30, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 50, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.6432, Test MAE: 29.6047
# Train Directional Accuracy: 0.5006, Test Directional Accuracy: 0.5000
# Training Time: 113.0388 seconds, Evaluation Time: 0.5586 seconds
#
# Running model 82/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 30, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.5185, Test MAE: 30.4431
# Train Directional Accuracy: 0.5033, Test Directional Accuracy: 0.5030
# Training Time: 452.5348 seconds, Evaluation Time: 0.3866 seconds
#
# Running model 83/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 80, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 110, 'batch_size': 30, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.6209, Test MAE: 30.2474
# Train Directional Accuracy: 0.5033, Test Directional Accuracy: 0.5033
# Training Time: 319.9186 seconds, Evaluation Time: 0.5626 seconds
#
# Running model 84/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 80, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 140, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.3509, Test MAE: 37.1305
# Train Directional Accuracy: 0.5047, Test Directional Accuracy: 0.4999
# Training Time: 1135.7573 seconds, Evaluation Time: 0.5764 seconds
#
# Running model 85/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 80, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 170, 'batch_size': 20, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.4273, Test MAE: 29.8631
# Train Directional Accuracy: 0.5024, Test Directional Accuracy: 0.5023
# Training Time: 709.2331 seconds, Evaluation Time: 0.5615 seconds
#
# Running model 86/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 50, 'dense_dim': 30, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 140, 'batch_size': 20, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.4846, Test MAE: 29.5980
# Train Directional Accuracy: 0.5013, Test Directional Accuracy: 0.5017
# Training Time: 590.2176 seconds, Evaluation Time: 0.4233 seconds
#
# Running model 87/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 140, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 50, 'batch_size': 30, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 35.2071, Test MAE: 30.6601
# Train Directional Accuracy: 0.5038, Test Directional Accuracy: 0.5032
# Training Time: 221.5200 seconds, Evaluation Time: 3.8361 seconds
#
# Running model 88/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 110, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 80, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.8548, Test MAE: 30.5132
# Train Directional Accuracy: 0.5024, Test Directional Accuracy: 0.5013
# Training Time: 631.8250 seconds, Evaluation Time: 0.6506 seconds
#
# Running model 89/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 110, 'dense_dim': 30, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 80, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.4963, Test MAE: 29.4600
# Train Directional Accuracy: 0.5017, Test Directional Accuracy: 0.5011
# Training Time: 177.3412 seconds, Evaluation Time: 0.6504 seconds
#
# Running model 90/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 110, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 140, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.3143, Test MAE: 30.7253
# Train Directional Accuracy: 0.5036, Test Directional Accuracy: 0.5017
# Training Time: 1101.1286 seconds, Evaluation Time: 0.6464 seconds
#
# Running model 91/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 50, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 110, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.6709, Test MAE: 29.8331
# Train Directional Accuracy: 0.5033, Test Directional Accuracy: 0.5032
# Training Time: 248.3266 seconds, Evaluation Time: 0.4190 seconds
#
# Running model 92/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 50, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 80, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.7594, Test MAE: 30.1179
# Train Directional Accuracy: 0.5030, Test Directional Accuracy: 0.5040
# Training Time: 186.1117 seconds, Evaluation Time: 0.5195 seconds
#
# Running model 93/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 110, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 170, 'batch_size': 30, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.2539, Test MAE: 31.7522
# Train Directional Accuracy: 0.5035, Test Directional Accuracy: 0.5022
# Training Time: 495.4333 seconds, Evaluation Time: 0.6806 seconds
#
# Running model 94/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 80, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 80, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.8669, Test MAE: 29.8634
# Train Directional Accuracy: 0.5033, Test Directional Accuracy: 0.5037
# Training Time: 648.4951 seconds, Evaluation Time: 0.5734 seconds
#
# Running model 95/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 50, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 110, 'batch_size': 30, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.6919, Test MAE: 29.8247
# Train Directional Accuracy: 0.5030, Test Directional Accuracy: 0.5031
# Training Time: 319.3298 seconds, Evaluation Time: 0.4282 seconds
#
# Running model 96/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 30, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 170, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.3773, Test MAE: 29.5397
# Train Directional Accuracy: 0.5035, Test Directional Accuracy: 0.5039
# Training Time: 380.9145 seconds, Evaluation Time: 0.3965 seconds
#
# Running model 97/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 110, 'dense_dim': 30, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 110, 'batch_size': 20, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 35.1605, Test MAE: 30.1195
# Train Directional Accuracy: 0.5021, Test Directional Accuracy: 0.5019
# Training Time: 462.3524 seconds, Evaluation Time: 0.6449 seconds
#
# ...
#
# Results: Train MAE: 34.4379, Test MAE: 29.9943
# Train Directional Accuracy: 0.5029, Test Directional Accuracy: 0.5021
# Training Time: 497.0707 seconds, Evaluation Time: 0.5556 seconds
#
# Running model 111/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 80, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 140, 'batch_size': 20, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.4979, Test MAE: 37.0123
# Train Directional Accuracy: 0.5039, Test Directional Accuracy: 0.5048
# Training Time: 588.3096 seconds, Evaluation Time: 0.5620 seconds
#
# Running model 112/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 140, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 110, 'batch_size': 30, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.5877, Test MAE: 31.2195
# Train Directional Accuracy: 0.5034, Test Directional Accuracy: 0.5011
# Training Time: 484.4024 seconds, Evaluation Time: 4.6500 seconds
#
# Running model 113/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 80, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 140, 'batch_size': 30, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.3537, Test MAE: 29.6442
# Train Directional Accuracy: 0.5031, Test Directional Accuracy: 0.5024
# Training Time: 406.3891 seconds, Evaluation Time: 0.5209 seconds
#
# Running model 114/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 80, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 110, 'batch_size': 30, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.6332, Test MAE: 29.7015
# Train Directional Accuracy: 0.5030, Test Directional Accuracy: 0.5034
# Training Time: 318.7381 seconds, Evaluation Time: 0.5283 seconds
#
# Running model 115/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 110, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 170, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.5799, Test MAE: 31.6937
# Train Directional Accuracy: 0.5036, Test Directional Accuracy: 0.5027
# Training Time: 1337.2735 seconds, Evaluation Time: 0.6810 seconds
#
# Running model 116/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 50, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 110, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.8264, Test MAE: 29.7951
# Train Directional Accuracy: 0.5037, Test Directional Accuracy: 0.5034
# Training Time: 251.5868 seconds, Evaluation Time: 0.4686 seconds
#
# Running model 117/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 30, 'dense_dim': 30, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 170, 'batch_size': 20, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.5565, Test MAE: 30.8278
# Train Directional Accuracy: 0.5025, Test Directional Accuracy: 0.5017
# Training Time: 714.4073 seconds, Evaluation Time: 0.3911 seconds
#
# Running model 118/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 80, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 80, 'batch_size': 30, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.5364, Test MAE: 29.7383
# Train Directional Accuracy: 0.5028, Test Directional Accuracy: 0.5030
# Training Time: 235.7117 seconds, Evaluation Time: 0.6100 seconds
#
# Running model 119/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 80, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.3108, Test MAE: 31.4118
# Train Directional Accuracy: 0.5042, Test Directional Accuracy: 0.5053
# Training Time: 456.6182 seconds, Evaluation Time: 0.5607 seconds
#
# Running model 120/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 110, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.3782, Test MAE: 30.2666
# Train Directional Accuracy: 0.5021, Test Directional Accuracy: 0.5010
# Training Time: 864.5049 seconds, Evaluation Time: 0.6512 seconds
#
# Running model 121/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 50, 'dense_dim': 30, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 170, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.3027, Test MAE: 30.0865
# Train Directional Accuracy: 0.5018, Test Directional Accuracy: 0.4999
# Training Time: 1359.4295 seconds, Evaluation Time: 0.4393 seconds
#
# Running model 122/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 30, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 20, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.2695, Test MAE: 43.8640
# Train Directional Accuracy: 0.5029, Test Directional Accuracy: 0.5009
# Training Time: 844.1724 seconds, Evaluation Time: 0.3163 seconds
#
# Running model 123/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 110, 'dense_dim': 30, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 170, 'batch_size': 30, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.8551, Test MAE: 30.0499
# Train Directional Accuracy: 0.5017, Test Directional Accuracy: 0.5014
# Training Time: 488.9442 seconds, Evaluation Time: 0.6924 seconds
#
# Running model 124/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 30, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 50, 'batch_size': 20, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.5624, Test MAE: 29.5946
# Train Directional Accuracy: 0.5029, Test Directional Accuracy: 0.5023
# Training Time: 209.8322 seconds, Evaluation Time: 0.3665 seconds
#
# Running model 125/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 110, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 50, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 35.2901, Test MAE: 30.7670
# Train Directional Accuracy: 0.5019, Test Directional Accuracy: 0.5022
# Training Time: 111.8519 seconds, Evaluation Time: 0.6515 seconds
#
# Running model 126/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 110, 'dense_dim': 50, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 80, 'batch_size': 20, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.9506, Test MAE: 30.2086
# Train Directional Accuracy: 0.5025, Test Directional Accuracy: 0.5018
# Training Time: 334.9817 seconds, Evaluation Time: 0.6652 seconds
#
# Running model 127/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 50, 'dense_dim': 30, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 200, 'batch_size': 30, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.4444, Test MAE: 29.9092
# Train Directional Accuracy: 0.5030, Test Directional Accuracy: 0.5038
# Training Time: 577.8441 seconds, Evaluation Time: 0.4572 seconds
#
# Running model 128/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 110, 'dense_dim': 140, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 80, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.3770, Test MAE: 32.4014
# Train Directional Accuracy: 0.5034, Test Directional Accuracy: 0.5037
# Training Time: 629.3051 seconds, Evaluation Time: 0.6555 seconds
#
# Running model 129/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 140, 'dense_dim': 110, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 170, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.3638, Test MAE: 32.2260
# Train Directional Accuracy: 0.5035, Test Directional Accuracy: 0.5050
# Training Time: 2124.6427 seconds, Evaluation Time: 7.8297 seconds
#
# Running model 130/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 80, 'dense_dim': 30, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 140, 'batch_size': 40, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 35.0285, Test MAE: 30.3234
# Train Directional Accuracy: 0.5014, Test Directional Accuracy: 0.5014
# Training Time: 320.1362 seconds, Evaluation Time: 0.5460 seconds
#
# Running model 131/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 50, 'dense_dim': 30, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 170, 'batch_size': 30, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.4708, Test MAE: 29.7367
# Train Directional Accuracy: 0.5017, Test Directional Accuracy: 0.5017
# Training Time: 492.0868 seconds, Evaluation Time: 0.4931 seconds
#
# Running model 132/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 140, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 80, 'batch_size': 20, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results: Train MAE: 34.7616, Test MAE: 30.0276
# Train Directional Accuracy: 0.5032, Test Directional Accuracy: 0.5041
# Training Time: 520.9057 seconds, Evaluation Time: 6.3907 seconds
#
# Running model 133/150 with parameters: {'window_size': 48, 'output_window_size': 48, 'lstm_dim': 140, 'dense_dim': 80, 'num_layers': 1, 'dropout': 0.0, 'lr': 5e-05, 'num_epochs': 80, 'batch_size': 10, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 22
#      19     param_dict = dict(zip(parameter_space.keys(), params))
#      20     print(f"Running model {model_counter}/{150} with parameters: {param_dict}\n")
# ---> 22     train_and_evaluate(df1, target_column=target_column, feature_columns=features, params=param_dict, model_counter=model_counter, file_prefix=file_prefix, use_early_stopping=False, plot_loss=False)
#      24     model_counter += 1
#      26 end = time.time()
#
# Cell In[5], line 52, in train_and_evaluate(df, target_column, feature_columns, params, model_counter, file_prefix, use_early_stopping, plot_loss)
#      50     loss = criterion(outputs, labels)
#      51     loss.backward()
# ---> 52     optimizer.step()
#      53     epoch_train_loss += loss.item()
#      55 epoch_train_loss /= len(train_loader)
#
# File ~\anaconda3\envs\torch\Lib\site-packages\torch\optim\optimizer.py:385, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     380         else:
#     381             raise RuntimeError(
#     382                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     383             )
# --> 385 out = func(*args, **kwargs)
#     386 self._optimizer_step_code()
#     388 # call optimizer step post hooks
#
# File ~\anaconda3\envs\torch\Lib\site-packages\torch\optim\optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File ~\anaconda3\envs\torch\Lib\site-packages\torch\optim\adam.py:166, in Adam.step(self, closure)
#     155     beta1, beta2 = group['betas']
#     157     has_complex = self._init_group(
#     158         group,
#     159         params_with_grad,
#    (...)
#     163         max_exp_avg_sqs,
#     164         state_steps)
# --> 166     adam(
#     167         params_with_grad,
#     168         grads,
#     169         exp_avgs,
#     170         exp_avg_sqs,
#     171         max_exp_avg_sqs,
#     172         state_steps,
#     173         amsgrad=group['amsgrad'],
#     174         has_complex=has_complex,
#     175         beta1=beta1,
#     176         beta2=beta2,
#     177         lr=group['lr'],
#     178         weight_decay=group['weight_decay'],
#     179         eps=group['eps'],
#     180         maximize=group['maximize'],
#     181         foreach=group['foreach'],
#     182         capturable=group['capturable'],
#     183         differentiable=group['differentiable'],
#     184         fused=group['fused'],
#     185         grad_scale=getattr(self, "grad_scale", None),
#     186         found_inf=getattr(self, "found_inf", None),
#     187     )
#     189 return loss
#
# File ~\anaconda3\envs\torch\Lib\site-packages\torch\optim\adam.py:316, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     313 else:
#     314     func = _single_tensor_adam
# --> 316 func(params,
#     317      grads,
#     318      exp_avgs,
#     319      exp_avg_sqs,
#     320      max_exp_avg_sqs,
#     321      state_steps,
#     322      amsgrad=amsgrad,
#     323      has_complex=has_complex,
#     324      beta1=beta1,
#     325      beta2=beta2,
#     326      lr=lr,
#     327      weight_decay=weight_decay,
#     328      eps=eps,
#     329      maximize=maximize,
#     330      capturable=capturable,
#     331      differentiable=differentiable,
#     332      grad_scale=grad_scale,
#     333      found_inf=found_inf)
#
# File ~\anaconda3\envs\torch\Lib\site-packages\torch\optim\adam.py:508, in _multi_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     503 # Update steps
#     504 # If steps are on CPU, foreach will fall back to the slow path, which is a for-loop calling t.add(1) over
#     505 # and over. 1 will then be wrapped into a Tensor over and over again, which is slower than if we just
#     506 # wrapped it once now. The alpha is required to assure we go to the right overload.
#     507 if device_state_steps[0].is_cpu:
# --> 508     torch._foreach_add_(device_state_steps, torch.tensor(1.0, device='cpu'), alpha=1.0)
#     509 else:
#     510     torch._foreach_add_(device_state_steps, 1)
#
# KeyboardInterrupt:
