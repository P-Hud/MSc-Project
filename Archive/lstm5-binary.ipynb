# %%
# Data Manipulation and Preparation
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# PyTorch
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# Evaluation metrics and visualisation
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (mean_squared_error, mean_absolute_error, r2_score, 
                             mean_absolute_percentage_error, confusion_matrix, 
                             accuracy_score, precision_score, recall_score, f1_score)

# Ensure GPU usage
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

import itertools
import time
import csv
# Out:
# Using device: cuda

# %%
# Load cleaned dataset
df = pd.read_csv('BTC_1h_w_Diffs.csv', parse_dates=['open_time'])

# Convert to datetime 
df['open_time'] = pd.to_datetime(df['open_time'])
df['close_time'] = pd.to_datetime(df['close_time'])

# %%
df.columns
# Out:
# Index(['open_time', 'open', 'high', 'low', 'close', 'volume', 'close_time',
#        'quote_vol', 'count', 'buy_base', 'buy_quote', 'open_p', 'high_p',
#        'low_p', 'close_p', 'log_open', 'log_high', 'log_low', 'log_close',
#        'diff', 'log_diff', 'direction', 'direction_log', 'diff_open',
#        'diff_high', 'diff_low', 'diff_close', 'diff_log_open', 'diff_log_high',
#        'diff_log_low', 'diff_log_close'],
#       dtype='object')

# %%
# Helper functions
def create_sequences(data, target, window_size):
    sequences = []
    labels = []
    for i in range(len(data) - window_size):
        seq = data[i:i + window_size]
        label = target[i + window_size]
        sequences.append(seq)
        labels.append(label)
    return np.array(sequences), np.array(labels)

def prepare_data(df, target_column, window_size, feature_columns, binary_target=False, gamma=0.001):
    X = df[feature_columns].values
    y = df[target_column].values.reshape(-1, 1)
    
    if binary_target:
        # Convert to binary classification target
        y = np.where((y[1:] / y[:-1] - 1) > gamma, 1, 0)
        y = np.append([0], y) 

    scaler_X = MinMaxScaler()
    X_scaled = scaler_X.fit_transform(X)

    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, shuffle=False)
    X_train_seq, y_train_seq = create_sequences(X_train, y_train, window_size)
    X_test_seq, y_test_seq = create_sequences(X_test, y_test, window_size)

    return X_train_seq, X_test_seq, y_train_seq, y_test_seq

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_dim, lstm_dim, dense_dim, output_dim, num_layers=1, dropout=0.0, activation_function=nn.Tanh):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_dim, lstm_dim, num_layers=num_layers, batch_first=True, dropout=(dropout if num_layers > 1 else 0))
        self.fc1 = nn.Linear(lstm_dim, dense_dim)
        self.activation = activation_function()
        self.fc2 = nn.Linear(dense_dim, output_dim)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x, _ = self.lstm(x)
        x = x[:, -1, :]
        x = self.activation(self.fc1(x))
        x = self.sigmoid(self.fc2(x))
        return x

# %%
def train_and_evaluate(df, target_column, feature_columns, params, file_prefix='results', binary_target=False, gamma=0.001, use_early_stopping=True, plot_loss=False):
    result = {} 
    try:
        # Extract parameters
        window_size = params['window_size']
        lstm_dim = params['lstm_dim']
        dense_dim = params['dense_dim']
        num_layers = params['num_layers']
        dropout = params['dropout']
        lr = params['lr']
        batch_size = params['batch_size']
        num_epochs = params['num_epochs']
        optimizer_type = params['optimizer_type']
        patience = params['patience']
        activation_function = params['activation_function']

        # Clear CUDA cache
        torch.cuda.empty_cache()

        # Prepare data
        X_train_seq, X_test_seq, y_train_seq, y_test_seq = prepare_data(df, target_column, window_size, feature_columns, binary_target, gamma)

        # Convert to PyTorch tensors
        X_train_tensor = torch.tensor(X_train_seq, dtype=torch.float32).to(device)
        X_test_tensor = torch.tensor(X_test_seq, dtype=torch.float32).to(device)
        y_train_tensor = torch.tensor(y_train_seq, dtype=torch.float32).view(-1, 1).to(device)
        y_test_tensor = torch.tensor(y_test_seq, dtype=torch.float32).view(-1, 1).to(device)

        # Create data loaders
        train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
        test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
        train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
        test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

        # Model parameters
        input_dim = X_train_tensor.shape[2]
        output_dim = 1

        model = LSTMModel(input_dim, lstm_dim, dense_dim, output_dim, num_layers, dropout, activation_function).to(device)

        # Define loss and optimizer
        criterion = nn.BCELoss()  # Binary cross-entropy loss for probabilities
        optimizer = getattr(optim, optimizer_type)(model.parameters(), lr=lr)

        # Training loop
        best_loss = float('inf')
        patience_counter = 0
        start_time = time.time()

        training_losses = []
        validation_losses = []

        for epoch in range(num_epochs):
            model.train()
            epoch_train_loss = 0
            for inputs, labels in train_loader:
                optimizer.zero_grad()
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()
                epoch_train_loss += loss.item()

            epoch_train_loss /= len(train_loader)
            training_losses.append(epoch_train_loss)

            model.eval()
            val_loss = 0
            with torch.no_grad():
                for inputs, labels in test_loader:
                    outputs = model(inputs)
                    val_loss += criterion(outputs, labels).item()

            val_loss /= len(test_loader)
            validation_losses.append(val_loss)

        training_time = time.time() - start_time

        # Evaluate the model
        model.eval()
        evaluation_start_time = time.time()
        with torch.no_grad():
            train_predictions = model(X_train_tensor).cpu().numpy()
            test_predictions = model(X_test_tensor).cpu().numpy()

            # Convert probabilities to binary predictions
            train_predictions_binary = (train_predictions > 0.5).astype(int)
            test_predictions_binary = (test_predictions > 0.5).astype(int)

            # Calculate binary classification metrics
            train_acc, train_prec, train_rec, train_f1, train_spec, train_sens = calculate_metrics(y_train_seq, train_predictions_binary)
            test_acc, test_prec, test_rec, test_f1, test_spec, test_sens = calculate_metrics(y_test_seq, test_predictions_binary)

        evaluation_time = time.time() - evaluation_start_time

        result = {
            "window_size": window_size,
            "lstm_dim": lstm_dim,
            "num_layers": num_layers,
            "dense_dim": dense_dim,
            "dropout": dropout,
            "lr": lr,
            "batch_size": batch_size,
            "num_epochs": num_epochs,
            "optimizer_type": optimizer_type,
            "train_acc": train_acc,
            "test_acc": test_acc,
            "train_prec": train_prec,
            "test_prec": test_prec,
            "train_rec": train_rec,
            "test_rec": test_rec,
            "train_f1": train_f1,
            "test_f1": test_f1,
            "train_spec": train_spec,
            "test_spec": test_spec,
            "train_sens": train_sens,
            "test_sens": test_sens,
            "training_time": training_time,
            "evaluation_time": evaluation_time,
            "patience": patience
        }

        # Save result to a CSV file
        with open(f'{file_prefix}_{target_column}.csv', 'a', newline='') as f:
            writer = csv.DictWriter(f, fieldnames=result.keys())
            if f.tell() == 0:
                writer.writeheader()  # Write header only if file is empty
            writer.writerow(result)

        # Print summary of the results
        print(f"Results: Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}")
        print(f"Train Prec: {train_prec:.4f}, Test Prec: {test_prec:.4f}")
        print(f"Train Rec: {train_rec:.4f}, Test Rec: {test_rec:.4f}")
        print(f"Train F1: {train_f1:.4f}, Test F1: {test_f1:.4f}")
        print(f"Train Spec: {train_spec:.4f}, Test Spec: {test_spec:.4f}")
        print(f"Train Sens: {train_sens:.4f}, Test Sens: {test_sens:.4f}")
        print(f"Training Time: {training_time:.4f} seconds, Evaluation Time: {evaluation_time:.4f} seconds\n")

        # Plot loss over epochs if specified
        if plot_loss:
            plot_loss_over_epochs(training_losses, validation_losses, f'{file_prefix}_{target_column}', start_epoch=3)

    except Exception as e:
        print(f"An error occurred: {e}")

        result = {
            "window_size": window_size,
            "lstm_dim": lstm_dim,
            "num_layers": num_layers,
            "dense_dim": dense_dim,
            "dropout": dropout,
            "lr": lr,
            "batch_size": batch_size,
            "num_epochs": num_epochs,
            "optimizer_type": optimizer_type,
            "error": str(e)
        }

    return result

# %%
# Define parameter space
parameter_space = {
    'window_size': [24],
    'lstm_dim': [60, 150, 200],
    'dense_dim': [60, 128, 200],
    'num_layers': [1],
    'dropout': [0.0, 0.001],
    'lr': [0.0001],
    'num_epochs': [100, 150, 200],
    'batch_size': [64],
    'optimizer_type': ['Adam'],
    'patience': [24],
    'activation_function': [nn.Tanh]
}

# Define target column
target_column = 'close'

# Define feature combination
features = ['high', 'low', 'close', 'volume',
       'quote_vol', 'count', 'buy_base', 'buy_quote', 'high_p', 'low_p', 'close_p']

# %%
# Start total timer
start = time.time()

# Calculate total number of models
total_models = len(list(itertools.product(*parameter_space.values())))

# Initialize model counter
model_counter = 1

# Grid search
for params in itertools.product(*parameter_space.values()):
    param_dict = dict(zip(parameter_space.keys(), params))
    print(f"Running model {model_counter}/{total_models} with parameters: {param_dict}\n")
    
    # Run with fixed epochs
    print('Results:\n')
    train_and_evaluate(df, target_column=target_column, feature_columns=features, params=param_dict, file_prefix='results2.0', binary_target=True, gamma=0.001, use_early_stopping=False, plot_loss=True)
    
    # Increment model counter
    model_counter += 1

# Calculate total time
end = time.time()
total_time = end - start

# Print the total time taken
print(f"Total time taken: {total_time} seconds")
# Out:
# Running model 1/54 with parameters: {'window_size': 24, 'lstm_dim': 60, 'dense_dim': 60, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5966, Test Acc: 0.6423
# Train Prec: 0.4913, Test Prec: 0.4000
# Train Rec: 0.0208, Test Rec: 0.0022
# Train F1: 0.0399, Test F1: 0.0044
# Train Spec: 0.9855, Test Spec: 0.9981
# Train Sens: 0.0208, Test Sens: 0.0022
# Training Time: 111.4903 seconds, Evaluation Time: 0.1251 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 2/54 with parameters: {'window_size': 24, 'lstm_dim': 60, 'dense_dim': 60, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5969, Test Acc: 0.6423
# Train Prec: 0.5009, Test Prec: 0.4211
# Train Rec: 0.0236, Test Rec: 0.0030
# Train F1: 0.0451, Test F1: 0.0059
# Train Spec: 0.9841, Test Spec: 0.9977
# Train Sens: 0.0236, Test Sens: 0.0030
# Training Time: 167.2365 seconds, Evaluation Time: 0.1211 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 3/54 with parameters: {'window_size': 24, 'lstm_dim': 60, 'dense_dim': 60, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5968, Test Acc: 0.6427
# Train Prec: 0.4969, Test Prec: 0.5000
# Train Rec: 0.0200, Test Rec: 0.0030
# Train F1: 0.0384, Test F1: 0.0059
# Train Spec: 0.9864, Test Spec: 0.9984
# Train Sens: 0.0200, Test Sens: 0.0030
# Training Time: 221.1245 seconds, Evaluation Time: 0.1026 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 4/54 with parameters: {'window_size': 24, 'lstm_dim': 60, 'dense_dim': 60, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5968, Test Acc: 0.6426
# Train Prec: 0.4981, Test Prec: 0.4762
# Train Rec: 0.0219, Test Rec: 0.0037
# Train F1: 0.0420, Test F1: 0.0073
# Train Spec: 0.9851, Test Spec: 0.9977
# Train Sens: 0.0219, Test Sens: 0.0037
# Training Time: 109.3331 seconds, Evaluation Time: 0.1131 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 5/54 with parameters: {'window_size': 24, 'lstm_dim': 60, 'dense_dim': 60, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5969, Test Acc: 0.6427
# Train Prec: 0.5018, Test Prec: 0.5000
# Train Rec: 0.0223, Test Rec: 0.0055
# Train F1: 0.0427, Test F1: 0.0110
# Train Spec: 0.9850, Test Spec: 0.9969
# Train Sens: 0.0223, Test Sens: 0.0055
# Training Time: 163.3464 seconds, Evaluation Time: 0.1141 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 6/54 with parameters: {'window_size': 24, 'lstm_dim': 60, 'dense_dim': 60, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5963, Test Acc: 0.6427
# Train Prec: 0.4861, Test Prec: 0.5000
# Train Rec: 0.0257, Test Rec: 0.0022
# Train F1: 0.0488, Test F1: 0.0044
# Train Spec: 0.9817, Test Spec: 0.9988
# Train Sens: 0.0257, Test Sens: 0.0022
# Training Time: 221.6865 seconds, Evaluation Time: 0.1106 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 7/54 with parameters: {'window_size': 24, 'lstm_dim': 60, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5972, Test Acc: 0.6419
# Train Prec: 0.5068, Test Prec: 0.3333
# Train Rec: 0.0273, Test Rec: 0.0022
# Train F1: 0.0518, Test F1: 0.0044
# Train Spec: 0.9820, Test Spec: 0.9975
# Train Sens: 0.0273, Test Sens: 0.0022
# Training Time: 108.7160 seconds, Evaluation Time: 0.1156 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 8/54 with parameters: {'window_size': 24, 'lstm_dim': 60, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5973, Test Acc: 0.6427
# Train Prec: 0.5147, Test Prec: 0.5000
# Train Rec: 0.0186, Test Rec: 0.0033
# Train F1: 0.0360, Test F1: 0.0066
# Train Spec: 0.9881, Test Spec: 0.9981
# Train Sens: 0.0186, Test Sens: 0.0033
# Training Time: 158.3727 seconds, Evaluation Time: 0.1196 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 9/54 with parameters: {'window_size': 24, 'lstm_dim': 60, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5974, Test Acc: 0.6424
# Train Prec: 0.5273, Test Prec: 0.4000
# Train Rec: 0.0134, Test Rec: 0.0015
# Train F1: 0.0262, Test F1: 0.0029
# Train Spec: 0.9919, Test Spec: 0.9988
# Train Sens: 0.0134, Test Sens: 0.0015
# Training Time: 211.7284 seconds, Evaluation Time: 0.1151 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 10/54 with parameters: {'window_size': 24, 'lstm_dim': 60, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5972, Test Acc: 0.6426
# Train Prec: 0.5134, Test Prec: 0.4545
# Train Rec: 0.0172, Test Rec: 0.0018
# Train F1: 0.0332, Test F1: 0.0037
# Train Spec: 0.9890, Test Spec: 0.9988
# Train Sens: 0.0172, Test Sens: 0.0018
# Training Time: 105.1166 seconds, Evaluation Time: 0.1476 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 11/54 with parameters: {'window_size': 24, 'lstm_dim': 60, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5975, Test Acc: 0.6426
# Train Prec: 0.5184, Test Prec: 0.4667
# Train Rec: 0.0218, Test Rec: 0.0026
# Train F1: 0.0419, Test F1: 0.0052
# Train Spec: 0.9863, Test Spec: 0.9984
# Train Sens: 0.0218, Test Sens: 0.0026
# Training Time: 153.2264 seconds, Evaluation Time: 0.2252 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 12/54 with parameters: {'window_size': 24, 'lstm_dim': 60, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5974, Test Acc: 0.6428
# Train Prec: 0.5188, Test Prec: 0.6000
# Train Rec: 0.0169, Test Rec: 0.0011
# Train F1: 0.0328, Test F1: 0.0022
# Train Spec: 0.9894, Test Spec: 0.9996
# Train Sens: 0.0169, Test Sens: 0.0011
# Training Time: 203.8564 seconds, Evaluation Time: 0.2131 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 13/54 with parameters: {'window_size': 24, 'lstm_dim': 60, 'dense_dim': 200, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5962, Test Acc: 0.6424
# Train Prec: 0.4848, Test Prec: 0.4375
# Train Rec: 0.0260, Test Rec: 0.0026
# Train F1: 0.0494, Test F1: 0.0051
# Train Spec: 0.9813, Test Spec: 0.9981
# Train Sens: 0.0260, Test Sens: 0.0026
# Training Time: 102.2639 seconds, Evaluation Time: 0.2097 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 14/54 with parameters: {'window_size': 24, 'lstm_dim': 60, 'dense_dim': 200, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5974, Test Acc: 0.6426
# Train Prec: 0.5180, Test Prec: 0.4667
# Train Rec: 0.0200, Test Rec: 0.0026
# Train F1: 0.0386, Test F1: 0.0052
# Train Spec: 0.9874, Test Spec: 0.9984
# Train Sens: 0.0200, Test Sens: 0.0026
# Training Time: 153.8565 seconds, Evaluation Time: 0.1371 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 15/54 with parameters: {'window_size': 24, 'lstm_dim': 60, 'dense_dim': 200, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5975, Test Acc: 0.6420
# Train Prec: 0.5397, Test Prec: 0.3333
# Train Rec: 0.0105, Test Rec: 0.0018
# Train F1: 0.0207, Test F1: 0.0037
# Train Spec: 0.9939, Test Spec: 0.9979
# Train Sens: 0.0105, Test Sens: 0.0018
# Training Time: 206.9705 seconds, Evaluation Time: 0.1156 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 16/54 with parameters: {'window_size': 24, 'lstm_dim': 60, 'dense_dim': 200, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5971, Test Acc: 0.6424
# Train Prec: 0.5083, Test Prec: 0.3750
# Train Rec: 0.0150, Test Rec: 0.0011
# Train F1: 0.0291, Test F1: 0.0022
# Train Spec: 0.9902, Test Spec: 0.9990
# Train Sens: 0.0150, Test Sens: 0.0011
# Training Time: 106.4332 seconds, Evaluation Time: 0.1261 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 17/54 with parameters: {'window_size': 24, 'lstm_dim': 60, 'dense_dim': 200, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5968, Test Acc: 0.6423
# Train Prec: 0.4969, Test Prec: 0.4286
# Train Rec: 0.0195, Test Rec: 0.0033
# Train F1: 0.0375, Test F1: 0.0066
# Train Spec: 0.9867, Test Spec: 0.9975
# Train Sens: 0.0195, Test Sens: 0.0033
# Training Time: 161.0313 seconds, Evaluation Time: 0.1247 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 18/54 with parameters: {'window_size': 24, 'lstm_dim': 60, 'dense_dim': 200, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5968, Test Acc: 0.6426
# Train Prec: 0.4975, Test Prec: 0.4762
# Train Rec: 0.0240, Test Rec: 0.0037
# Train F1: 0.0457, Test F1: 0.0073
# Train Spec: 0.9837, Test Spec: 0.9977
# Train Sens: 0.0240, Test Sens: 0.0037
# Training Time: 219.9958 seconds, Evaluation Time: 0.1316 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 19/54 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 60, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5964, Test Acc: 0.6426
# Train Prec: 0.4878, Test Prec: 0.4667
# Train Rec: 0.0246, Test Rec: 0.0026
# Train F1: 0.0469, Test F1: 0.0052
# Train Spec: 0.9825, Test Spec: 0.9984
# Train Sens: 0.0246, Test Sens: 0.0026
# Training Time: 131.1517 seconds, Evaluation Time: 0.4431 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 20/54 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 60, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5971, Test Acc: 0.6423
# Train Prec: 0.5093, Test Prec: 0.2857
# Train Rec: 0.0156, Test Rec: 0.0007
# Train F1: 0.0303, Test F1: 0.0015
# Train Spec: 0.9898, Test Spec: 0.9990
# Train Sens: 0.0156, Test Sens: 0.0007
# Training Time: 208.8830 seconds, Evaluation Time: 0.4931 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 21/54 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 60, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5964, Test Acc: 0.6426
# Train Prec: 0.4888, Test Prec: 0.4783
# Train Rec: 0.0232, Test Rec: 0.0041
# Train F1: 0.0443, Test F1: 0.0081
# Train Spec: 0.9836, Test Spec: 0.9975
# Train Sens: 0.0232, Test Sens: 0.0041
# Training Time: 271.0728 seconds, Evaluation Time: 0.4898 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 22/54 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 60, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5963, Test Acc: 0.6426
# Train Prec: 0.4846, Test Prec: 0.4706
# Train Rec: 0.0231, Test Rec: 0.0030
# Train F1: 0.0442, Test F1: 0.0059
# Train Spec: 0.9834, Test Spec: 0.9981
# Train Sens: 0.0231, Test Sens: 0.0030
# Training Time: 135.3944 seconds, Evaluation Time: 0.4694 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 23/54 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 60, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5966, Test Acc: 0.6424
# Train Prec: 0.4962, Test Prec: 0.4500
# Train Rec: 0.0375, Test Rec: 0.0033
# Train F1: 0.0697, Test F1: 0.0066
# Train Spec: 0.9743, Test Spec: 0.9977
# Train Sens: 0.0375, Test Sens: 0.0033
# Training Time: 202.3716 seconds, Evaluation Time: 0.4474 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 24/54 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 60, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5973, Test Acc: 0.6422
# Train Prec: 0.5108, Test Prec: 0.4524
# Train Rec: 0.0272, Test Rec: 0.0070
# Train F1: 0.0516, Test F1: 0.0138
# Train Spec: 0.9824, Test Spec: 0.9953
# Train Sens: 0.0272, Test Sens: 0.0070
# Training Time: 267.9873 seconds, Evaluation Time: 0.4524 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 25/54 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5973, Test Acc: 0.6428
# Train Prec: 0.5145, Test Prec: 0.5333
# Train Rec: 0.0189, Test Rec: 0.0030
# Train F1: 0.0364, Test F1: 0.0059
# Train Spec: 0.9880, Test Spec: 0.9986
# Train Sens: 0.0189, Test Sens: 0.0030
# Training Time: 134.8113 seconds, Evaluation Time: 0.4589 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 26/54 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5974, Test Acc: 0.6424
# Train Prec: 0.5221, Test Prec: 0.4545
# Train Rec: 0.0164, Test Rec: 0.0037
# Train F1: 0.0319, Test F1: 0.0073
# Train Spec: 0.9898, Test Spec: 0.9975
# Train Sens: 0.0164, Test Sens: 0.0037
# Training Time: 201.3639 seconds, Evaluation Time: 0.4545 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 27/54 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5973, Test Acc: 0.6426
# Train Prec: 0.5085, Test Prec: 0.4898
# Train Rec: 0.0319, Test Rec: 0.0089
# Train F1: 0.0600, Test F1: 0.0174
# Train Spec: 0.9792, Test Spec: 0.9949
# Train Sens: 0.0319, Test Sens: 0.0089
# Training Time: 268.6712 seconds, Evaluation Time: 0.4548 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 28/54 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5967, Test Acc: 0.6426
# Train Prec: 0.4942, Test Prec: 0.4706
# Train Rec: 0.0209, Test Rec: 0.0030
# Train F1: 0.0402, Test F1: 0.0059
# Train Spec: 0.9855, Test Spec: 0.9981
# Train Sens: 0.0209, Test Sens: 0.0030
# Training Time: 133.7007 seconds, Evaluation Time: 0.4529 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 29/54 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5971, Test Acc: 0.6423
# Train Prec: 0.5053, Test Prec: 0.4400
# Train Rec: 0.0273, Test Rec: 0.0041
# Train F1: 0.0518, Test F1: 0.0081
# Train Spec: 0.9819, Test Spec: 0.9971
# Train Sens: 0.0273, Test Sens: 0.0041
# Training Time: 204.5111 seconds, Evaluation Time: 0.5080 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 30/54 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5974, Test Acc: 0.6420
# Train Prec: 0.5262, Test Prec: 0.3529
# Train Rec: 0.0140, Test Rec: 0.0022
# Train F1: 0.0272, Test F1: 0.0044
# Train Spec: 0.9915, Test Spec: 0.9977
# Train Sens: 0.0140, Test Sens: 0.0022
# Training Time: 274.6223 seconds, Evaluation Time: 0.4905 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 31/54 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 200, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5972, Test Acc: 0.6422
# Train Prec: 0.5071, Test Prec: 0.4231
# Train Rec: 0.0263, Test Rec: 0.0041
# Train F1: 0.0501, Test F1: 0.0081
# Train Spec: 0.9827, Test Spec: 0.9969
# Train Sens: 0.0263, Test Sens: 0.0041
# Training Time: 144.8411 seconds, Evaluation Time: 0.4965 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 32/54 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 200, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5969, Test Acc: 0.6419
# Train Prec: 0.5000, Test Prec: 0.3846
# Train Rec: 0.0312, Test Rec: 0.0037
# Train F1: 0.0588, Test F1: 0.0073
# Train Spec: 0.9789, Test Spec: 0.9967
# Train Sens: 0.0312, Test Sens: 0.0037
# Training Time: 217.3833 seconds, Evaluation Time: 0.5043 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 33/54 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 200, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5971, Test Acc: 0.6412
# Train Prec: 0.5034, Test Prec: 0.4225
# Train Rec: 0.0420, Test Rec: 0.0111
# Train F1: 0.0776, Test F1: 0.0216
# Train Spec: 0.9720, Test Spec: 0.9916
# Train Sens: 0.0420, Test Sens: 0.0111
# Training Time: 290.1808 seconds, Evaluation Time: 0.5117 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 34/54 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 200, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5966, Test Acc: 0.6426
# Train Prec: 0.4948, Test Prec: 0.4783
# Train Rec: 0.0274, Test Rec: 0.0041
# Train F1: 0.0519, Test F1: 0.0081
# Train Spec: 0.9811, Test Spec: 0.9975
# Train Sens: 0.0274, Test Sens: 0.0041
# Training Time: 142.2163 seconds, Evaluation Time: 0.4646 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 35/54 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 200, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5970, Test Acc: 0.6420
# Train Prec: 0.5040, Test Prec: 0.3529
# Train Rec: 0.0206, Test Rec: 0.0022
# Train F1: 0.0396, Test F1: 0.0044
# Train Spec: 0.9863, Test Spec: 0.9977
# Train Sens: 0.0206, Test Sens: 0.0022
# Training Time: 203.1582 seconds, Evaluation Time: 0.4594 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 36/54 with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 200, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5971, Test Acc: 0.6416
# Train Prec: 0.5075, Test Prec: 0.4091
# Train Rec: 0.0222, Test Rec: 0.0067
# Train F1: 0.0426, Test F1: 0.0131
# Train Spec: 0.9854, Test Spec: 0.9947
# Train Sens: 0.0222, Test Sens: 0.0067
# Training Time: 275.9201 seconds, Evaluation Time: 0.4760 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 37/54 with parameters: {'window_size': 24, 'lstm_dim': 200, 'dense_dim': 60, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5972, Test Acc: 0.6424
# Train Prec: 0.5123, Test Prec: 0.4444
# Train Rec: 0.0170, Test Rec: 0.0030
# Train F1: 0.0329, Test F1: 0.0059
# Train Spec: 0.9891, Test Spec: 0.9979
# Train Sens: 0.0170, Test Sens: 0.0030
# Training Time: 163.0113 seconds, Evaluation Time: 0.1106 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 38/54 with parameters: {'window_size': 24, 'lstm_dim': 200, 'dense_dim': 60, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5961, Test Acc: 0.6430
# Train Prec: 0.4859, Test Prec: 0.5238
# Train Rec: 0.0325, Test Rec: 0.0081
# Train F1: 0.0609, Test F1: 0.0160
# Train Spec: 0.9768, Test Spec: 0.9959
# Train Sens: 0.0325, Test Sens: 0.0081
# Training Time: 239.1002 seconds, Evaluation Time: 0.1116 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 39/54 with parameters: {'window_size': 24, 'lstm_dim': 200, 'dense_dim': 60, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5983, Test Acc: 0.6422
# Train Prec: 0.5435, Test Prec: 0.4583
# Train Rec: 0.0225, Test Rec: 0.0081
# Train F1: 0.0432, Test F1: 0.0160
# Train Spec: 0.9872, Test Spec: 0.9947
# Train Sens: 0.0225, Test Sens: 0.0081
# Training Time: 321.0862 seconds, Evaluation Time: 0.1101 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 40/54 with parameters: {'window_size': 24, 'lstm_dim': 200, 'dense_dim': 60, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5970, Test Acc: 0.6422
# Train Prec: 0.5058, Test Prec: 0.3571
# Train Rec: 0.0142, Test Rec: 0.0018
# Train F1: 0.0277, Test F1: 0.0037
# Train Spec: 0.9906, Test Spec: 0.9981
# Train Sens: 0.0142, Test Sens: 0.0018
# Training Time: 161.7324 seconds, Evaluation Time: 0.1171 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 41/54 with parameters: {'window_size': 24, 'lstm_dim': 200, 'dense_dim': 60, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5972, Test Acc: 0.6423
# Train Prec: 0.5086, Test Prec: 0.4211
# Train Rec: 0.0266, Test Rec: 0.0030
# Train F1: 0.0505, Test F1: 0.0059
# Train Spec: 0.9827, Test Spec: 0.9977
# Train Sens: 0.0266, Test Sens: 0.0030
# Training Time: 241.4292 seconds, Evaluation Time: 0.1091 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 42/54 with parameters: {'window_size': 24, 'lstm_dim': 200, 'dense_dim': 60, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5975, Test Acc: 0.6414
# Train Prec: 0.5110, Test Prec: 0.4375
# Train Rec: 0.0360, Test Rec: 0.0129
# Train F1: 0.0672, Test F1: 0.0252
# Train Spec: 0.9767, Test Spec: 0.9907
# Train Sens: 0.0360, Test Sens: 0.0129
# Training Time: 316.9687 seconds, Evaluation Time: 0.1206 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 43/54 with parameters: {'window_size': 24, 'lstm_dim': 200, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5970, Test Acc: 0.6422
# Train Prec: 0.5020, Test Prec: 0.4333
# Train Rec: 0.0315, Test Rec: 0.0048
# Train F1: 0.0593, Test F1: 0.0095
# Train Spec: 0.9789, Test Spec: 0.9965
# Train Sens: 0.0315, Test Sens: 0.0048
# Training Time: 158.4926 seconds, Evaluation Time: 0.1091 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 44/54 with parameters: {'window_size': 24, 'lstm_dim': 200, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5973, Test Acc: 0.6424
# Train Prec: 0.5096, Test Prec: 0.4844
# Train Rec: 0.0304, Test Rec: 0.0115
# Train F1: 0.0574, Test F1: 0.0224
# Train Spec: 0.9802, Test Spec: 0.9932
# Train Sens: 0.0304, Test Sens: 0.0115
# Training Time: 232.6685 seconds, Evaluation Time: 0.1161 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 45/54 with parameters: {'window_size': 24, 'lstm_dim': 200, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5976, Test Acc: 0.6418
# Train Prec: 0.5125, Test Prec: 0.4286
# Train Rec: 0.0370, Test Rec: 0.0078
# Train F1: 0.0690, Test F1: 0.0153
# Train Spec: 0.9762, Test Spec: 0.9942
# Train Sens: 0.0370, Test Sens: 0.0078
# Training Time: 303.7925 seconds, Evaluation Time: 0.1221 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 46/54 with parameters: {'window_size': 24, 'lstm_dim': 200, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5967, Test Acc: 0.6426
# Train Prec: 0.4965, Test Prec: 0.4667
# Train Rec: 0.0287, Test Rec: 0.0026
# Train F1: 0.0543, Test F1: 0.0052
# Train Spec: 0.9803, Test Spec: 0.9984
# Train Sens: 0.0287, Test Sens: 0.0026
# Training Time: 148.2389 seconds, Evaluation Time: 0.1106 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 47/54 with parameters: {'window_size': 24, 'lstm_dim': 200, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5976, Test Acc: 0.6426
# Train Prec: 0.5162, Test Prec: 0.4815
# Train Rec: 0.0273, Test Rec: 0.0048
# Train F1: 0.0519, Test F1: 0.0095
# Train Spec: 0.9827, Test Spec: 0.9971
# Train Sens: 0.0273, Test Sens: 0.0048
# Training Time: 226.8625 seconds, Evaluation Time: 0.1101 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 48/54 with parameters: {'window_size': 24, 'lstm_dim': 200, 'dense_dim': 128, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5983, Test Acc: 0.6419
# Train Prec: 0.5335, Test Prec: 0.4651
# Train Rec: 0.0280, Test Rec: 0.0148
# Train F1: 0.0532, Test F1: 0.0287
# Train Spec: 0.9835, Test Spec: 0.9905
# Train Sens: 0.0280, Test Sens: 0.0148
# Training Time: 312.6560 seconds, Evaluation Time: 0.1101 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 49/54 with parameters: {'window_size': 24, 'lstm_dim': 200, 'dense_dim': 200, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5970, Test Acc: 0.6423
# Train Prec: 0.5025, Test Prec: 0.4211
# Train Rec: 0.0247, Test Rec: 0.0030
# Train F1: 0.0471, Test F1: 0.0059
# Train Spec: 0.9835, Test Spec: 0.9977
# Train Sens: 0.0247, Test Sens: 0.0030
# Training Time: 158.0459 seconds, Evaluation Time: 0.1101 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 50/54 with parameters: {'window_size': 24, 'lstm_dim': 200, 'dense_dim': 200, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5972, Test Acc: 0.6414
# Train Prec: 0.5092, Test Prec: 0.3438
# Train Rec: 0.0227, Test Rec: 0.0041
# Train F1: 0.0434, Test F1: 0.0080
# Train Spec: 0.9853, Test Spec: 0.9957
# Train Sens: 0.0227, Test Sens: 0.0041
# Training Time: 235.9788 seconds, Evaluation Time: 0.1126 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 51/54 with parameters: {'window_size': 24, 'lstm_dim': 200, 'dense_dim': 200, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5977, Test Acc: 0.6423
# Train Prec: 0.5206, Test Prec: 0.4651
# Train Rec: 0.0268, Test Rec: 0.0074
# Train F1: 0.0510, Test F1: 0.0146
# Train Spec: 0.9833, Test Spec: 0.9953
# Train Sens: 0.0268, Test Sens: 0.0074
# Training Time: 321.5600 seconds, Evaluation Time: 0.1111 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 52/54 with parameters: {'window_size': 24, 'lstm_dim': 200, 'dense_dim': 200, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5967, Test Acc: 0.6422
# Train Prec: 0.4963, Test Prec: 0.4231
# Train Rec: 0.0273, Test Rec: 0.0041
# Train F1: 0.0518, Test F1: 0.0081
# Train Spec: 0.9813, Test Spec: 0.9969
# Train Sens: 0.0273, Test Sens: 0.0041
# Training Time: 159.4927 seconds, Evaluation Time: 0.1161 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 53/54 with parameters: {'window_size': 24, 'lstm_dim': 200, 'dense_dim': 200, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5974, Test Acc: 0.6426
# Train Prec: 0.5169, Test Prec: 0.4783
# Train Rec: 0.0200, Test Rec: 0.0041
# Train F1: 0.0386, Test F1: 0.0081
# Train Spec: 0.9874, Test Spec: 0.9975
# Train Sens: 0.0200, Test Sens: 0.0041
# Training Time: 245.6532 seconds, Evaluation Time: 0.1152 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Running model 54/54 with parameters: {'window_size': 24, 'lstm_dim': 200, 'dense_dim': 200, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 200, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results:
#
# Results: Train Acc: 0.5976, Test Acc: 0.6426
# Train Prec: 0.5181, Test Prec: 0.4918
# Train Rec: 0.0270, Test Rec: 0.0111
# Train F1: 0.0513, Test F1: 0.0217
# Train Spec: 0.9830, Test Spec: 0.9936
# Train Sens: 0.0270, Test Sens: 0.0111
# Training Time: 335.8379 seconds, Evaluation Time: 0.1212 seconds
#
# An error occurred: name 'plot_loss_over_epochs' is not defined
# Total time taken: 10893.366600751877 seconds
