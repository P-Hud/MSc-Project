# %%
# Data Manipulation and Preparation
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# PyTorch
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# Evaluation metrics and visualisation
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Ensure GPU usage
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

import itertools
import time
import csv
import json
from IPython.display import Audio, display
import winsound
from threading import Thread
# Out:
# Using device: cuda

# %%
# Load cleaned dataset
df = pd.read_csv('BTC_1h_Complete_NoTA.csv', parse_dates=['open_time'])

# %%
# Convert to datetime 
df['open_time'] = pd.to_datetime(df['open_time'])
df['close_time'] = pd.to_datetime(df['close_time'])

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100


def directional_accuracy(y_true, y_pred):
    return np.mean(np.sign(y_true[1:] - y_true[:-1]) == np.sign(y_pred[1:] - y_pred[:-1]))


def plot_loss_over_epochs(training_loss, validation_loss, file_prefix, start_epoch=3):
    plt.figure(figsize=(10, 6))
    plt.plot(range(start_epoch, len(training_loss)), training_loss[start_epoch:], label='Training Loss')
    plt.plot(range(start_epoch, len(validation_loss)), validation_loss[start_epoch:], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss Over Epochs')
    plt.legend()
    plt.show()

# %%
def create_sequences(data, target, window_size):
    sequences = []
    labels = []
    for i in range(len(data) - window_size):
        seq = data[i:i + window_size]
        label = target[i + window_size]
        sequences.append(seq)
        labels.append(label)
    return np.array(sequences), np.array(labels)

def prepare_data(df, target_column, window_size, feature_columns):
    X = df[feature_columns].values
    y = df[target_column].values.reshape(-1, 1)

    scaler_X = MinMaxScaler()
    X_scaled = scaler_X.fit_transform(X)

    scaler_y = MinMaxScaler()
    y_scaled = scaler_y.fit_transform(y)

    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, shuffle=False)
    X_train_seq, y_train_seq = create_sequences(X_train, y_train, window_size)
    X_test_seq, y_test_seq = create_sequences(X_test, y_test, window_size)

    return X_train_seq, X_test_seq, y_train_seq, y_test_seq, scaler_y

class LSTMModel(nn.Module):
    def __init__(self, input_dim, lstm_dim, dense_dim, output_dim, num_layers=1, dropout=0.0):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_dim, lstm_dim, num_layers=num_layers, batch_first=True, dropout=(dropout if num_layers > 1 else 0))
        self.fc1 = nn.Linear(lstm_dim, dense_dim)
        self.activation = nn.Tanh()
        self.fc2 = nn.Linear(dense_dim, output_dim)

    def forward(self, x):
        x, _ = self.lstm(x)
        x = x[:, -1, :]
        x = self.fc1(x)
        x = self.activation(x)
        x = self.fc2(x)
        return x

# %%
def train_and_evaluate(df, target_column, feature_columns, params, file_prefix='results', use_early_stopping=True, plot_loss=False):
    # Extract parameters
    window_size = params['window_size']
    lstm_dim = params['lstm_dim']
    dense_dim = params['dense_dim']
    num_layers = params['num_layers']
    dropout = params['dropout']
    lr = params['lr']
    batch_size = params['batch_size']
    num_epochs = params['num_epochs']
    optimizer_type = params['optimizer_type']
    patience = params['patience']

    # Clear CUDA cache
    torch.cuda.empty_cache()

    # Prepare data
    X_train_seq, X_test_seq, y_train_seq, y_test_seq, scaler_y = prepare_data(df, target_column, window_size, feature_columns)

    # Convert to PyTorch tensors
    X_train_tensor = torch.tensor(X_train_seq, dtype=torch.float32).to(device)
    X_test_tensor = torch.tensor(X_test_seq, dtype=torch.float32).to(device)
    y_train_tensor = torch.tensor(y_train_seq, dtype=torch.float32).view(-1, 1).to(device)
    y_test_tensor = torch.tensor(y_test_seq, dtype=torch.float32).view(-1, 1).to(device)

    # Create data loaders
    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
    train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

    # Model parameters
    input_dim = X_train_tensor.shape[2]
    output_dim = 1

    model = LSTMModel(input_dim, lstm_dim, dense_dim, output_dim, num_layers, dropout).to(device)

    # Define loss and optimizer
    criterion = nn.MSELoss()
    optimizer = getattr(optim, optimizer_type)(model.parameters(), lr=lr)

    # Training loop
    best_loss = float('inf')
    patience_counter = 0
    start_time = time.time()

    training_losses = []
    validation_losses = []

    for epoch in range(num_epochs):
        model.train()
        epoch_train_loss = 0
        for inputs, labels in train_loader:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_train_loss += loss.item()

        epoch_train_loss /= len(train_loader)
        training_losses.append(epoch_train_loss)

        model.eval()
        val_loss = 0
        with torch.no_grad():
            for inputs, labels in test_loader:
                outputs = model(inputs)
                val_loss += criterion(outputs, labels).item()

        val_loss /= len(test_loader)
        validation_losses.append(val_loss)

        if use_early_stopping:
            if val_loss < best_loss:
                best_loss = val_loss
                patience_counter = 0
                torch.save(model.state_dict(), f'{file_prefix}_{target_column}_best_model.pth')
            else:
                patience_counter += 1
                if patience_counter >= patience:
                    break

    training_time = time.time() - start_time

    # Save the final model if early stopping was not used or not triggered
    if not use_early_stopping or patience_counter < patience:
        torch.save(model.state_dict(), f'{file_prefix}_{target_column}_final_model.pth')

    # Evaluate the model
    model.eval()
    evaluation_start_time = time.time()
    with torch.no_grad():
        train_predictions = model(X_train_tensor).cpu().numpy()
        test_predictions = model(X_test_tensor).cpu().numpy()

        # Inverse transform predictions and actual values
        y_train_seq = y_train_seq.reshape(-1, 1)
        y_test_seq = y_test_seq.reshape(-1, 1)
        train_predictions_inverse = scaler_y.inverse_transform(train_predictions)
        test_predictions_inverse = scaler_y.inverse_transform(test_predictions)
        y_train_inverse = scaler_y.inverse_transform(y_train_seq)
        y_test_inverse = scaler_y.inverse_transform(y_test_seq)

        train_mse = mean_squared_error(y_train_inverse, train_predictions_inverse)
        test_mse = mean_squared_error(y_test_inverse, test_predictions_inverse)
        train_mae = mean_absolute_error(y_train_inverse, train_predictions_inverse)
        test_mae = mean_absolute_error(y_test_inverse, test_predictions_inverse)
        train_rmse = np.sqrt(train_mse)
        test_rmse = np.sqrt(test_mse)
        train_r2 = r2_score(y_train_inverse, train_predictions_inverse)
        test_r2 = r2_score(y_test_inverse, test_predictions_inverse)

        train_mape = np.mean(np.abs((y_train_inverse - train_predictions_inverse) / y_train_inverse)) * 100
        test_mape = np.mean(np.abs((y_test_inverse - test_predictions_inverse) / y_test_inverse)) * 100

        train_directional_acc = np.mean(np.sign(y_train_inverse[1:] - y_train_inverse[:-1]) == np.sign(train_predictions_inverse[1:] - train_predictions_inverse[:-1]))
        test_directional_acc = np.mean(np.sign(y_test_inverse[1:] - y_test_inverse[:-1]) == np.sign(test_predictions_inverse[1:] - test_predictions_inverse[:-1]))

    evaluation_time = time.time() - evaluation_start_time

    result = {
        "window_size": window_size,
        "lstm_dim": lstm_dim,
        "num_layers": num_layers,
        "dense_dim": dense_dim,
        "dropout": dropout,
        "lr": lr,
        "batch_size": batch_size,
        "num_epochs": num_epochs,
        "optimizer_type": optimizer_type,
        "train_mse": train_mse,
        "test_mse": test_mse,
        "train_mae": train_mae,
        "test_mae": test_mae,
        "train_rmse": train_rmse,
        "test_rmse": test_rmse,
        "train_r2": train_r2,
        "test_r2": test_r2,
        "train_mape": train_mape,
        "test_mape": test_mape,
        "train_directional_acc": train_directional_acc,
        "test_directional_acc": test_directional_acc,
        "training_time": training_time,
        "evaluation_time": evaluation_time,
        "patience": patience
    }

    # Save result to a CSV file
    with open(f'{file_prefix}_{target_column}.csv', 'a', newline='') as f:
        writer = csv.DictWriter(f, fieldnames=result.keys())
        if f.tell() == 0:
            writer.writeheader()  # Write header only if file is empty
        writer.writerow(result)

    # Save training and validation losses to a JSON file
    losses = {
        "training_losses": training_losses,
        "validation_losses": validation_losses
    }
    with open(f'{file_prefix}_{target_column}_losses.json', 'w') as f:
        json.dump(losses, f)

    # Save predictions and actual values to a JSON file
    predictions = {
        "train_predictions": train_predictions_inverse.tolist(),
        "test_predictions": test_predictions_inverse.tolist(),
        "y_train": y_train_inverse.tolist(),
        "y_test": y_test_inverse.tolist()
    }
    with open(f'{file_prefix}_{target_column}_predictions.json', 'w') as f:
        json.dump(predictions, f)

    # Save hyperparameters to a JSON file, excluding any non-serializable types
    serializable_params = {k: v for k, v in params.items() if isinstance(v, (int, float, str, bool))}
    with open(f'{file_prefix}_{target_column}_params.json', 'w') as f:
        json.dump(serializable_params, f)

    # Print summary of the results
    print(f"Finished model with parameters: {params}")
    print(f"Results: Train MSE: {train_mse:.4f}, Test MSE: {test_mse:.4f}, Train MAE: {train_mae:.4f}, Test MAE: {test_mae:.4f}")
    print(f"Train RMSE: {train_rmse:.4f}, Test RMSE: {test_rmse:.4f}, Train R2: {train_r2:.4f}, Test R2: {test_r2:.4f}")
    print(f"Train MAPE: {train_mape:.4f}, Test MAPE: {test_mape:.4f}")
    print(f"Train Directional Accuracy: {train_directional_acc:.4f}, Test Directional Accuracy: {test_directional_acc:.4f}")
    print(f"Training Time: {training_time:.4f} seconds, Evaluation Time: {evaluation_time:.4f} seconds\n")

    # Plot loss over epochs if specified
    if plot_loss:
        plot_loss_over_epochs(training_losses, validation_losses, f'{file_prefix}_{target_column}', start_epoch=3)

    return result

# %%
def plot_saved_losses(file_prefix, target_column, start_epoch=3):
    # Load losses from JSON file
    with open(f'{file_prefix}_{target_column}_losses.json', 'r') as f:
        losses = json.load(f)
    
    training_losses = losses['training_losses']
    validation_losses = losses['validation_losses']
    
    # Plot losses
    plt.figure(figsize=(10, 6))
    plt.plot(range(start_epoch, len(training_losses)), training_losses[start_epoch:], label='Training Loss')
    plt.plot(range(start_epoch, len(validation_losses)), validation_losses[start_epoch:], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss Over Epochs')
    plt.legend()
    # plt.savefig(f'{file_prefix}_loss_plot.png')
    plt.show()

# plot_saved_losses('results_complete', 'close')

def plot_predicted_vs_actual(file_prefix, target_column, dataset='test'):
    import json
    import matplotlib.pyplot as plt
    
    # Load predictions and actual values from JSON file
    with open(f'{file_prefix}_{target_column}_predictions.json', 'r') as f:
        data = json.load(f)
    
    if dataset == 'train':
        predictions = np.array(data['train_predictions'])
        actual = np.array(data['y_train'])
        title = 'Training Set: Predicted vs Actual'
    elif dataset == 'test':
        predictions = np.array(data['test_predictions'])
        actual = np.array(data['y_test'])
        title = 'Test Set: Predicted vs Actual'
    else:
        raise ValueError("Invalid dataset value. Use 'train' or 'test'.")
    
    # Plot predicted vs actual
    plt.figure(figsize=(10, 6))
    plt.plot(actual, label='Actual')
    plt.plot(predictions, label='Predicted')
    plt.xlabel('Time')
    plt.ylabel('Values')
    plt.title(title)
    plt.legend()
    plt.savefig(f'{file_prefix}_{target_column}_predicted_vs_actual_{dataset}.png')
    plt.show()

# plot_predicted_vs_actual('results_complete', 'close', dataset='test')
# plot_predicted_vs_actual('results_complete', 'close', dataset='train')

# %%
# Define parameter space
parameter_space = {
    'window_size': [24],
    'lstm_dim': [96, 128, 150],
    'dense_dim': [96, 128, 150],
    'num_layers': [1],
    'dropout': [0.001, 0.0001],
    'lr': [0.0001, 0.001],
    'num_epochs': [50, 100, 150],
    'batch_size': [64],
    'optimizer_type': ['Adam'],
    'patience': [24],
    'activation_function': [nn.Tanh]
}

# Define target columns
target_columns = ['close']

# Define feature combinations
feature_combinations = [
    ['open', 'high', 'low', 'close', 'volume',
       'quote_vol', 'count', 'buy_base', 'buy_quote', 'open_p', 'high_p', 'low_p', 'close_p']
]

# %%
# Grid search
for params in itertools.product(*parameter_space.values()):
    param_dict = dict(zip(parameter_space.keys(), params))
    for target_column in target_columns:
        for features in feature_combinations:
            print(f"Running model with parameters: {param_dict}, target column: {target_column}, features: {features}")
            # Run with early stopping
            train_and_evaluate(df, target_column=target_column, feature_columns=features, params=param_dict, file_prefix='results_complete2', use_early_stopping=True, plot_loss=False)
            # Run with fixed epochs
            train_and_evaluate(df, target_column=target_column, feature_columns=features, params=param_dict, file_prefix='results_complete_fixed_epochs2', use_early_stopping=False, plot_loss=False)
# Out:
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 50, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}, target column: close, features: ['open', 'high', 'low', 'close', 'volume', 'quote_vol', 'count', 'buy_base', 'buy_quote', 'open_p', 'high_p', 'low_p', 'close_p']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[57], line 8
#       6 print(f"Running model with parameters: {param_dict}, target column: {target_column}, features: {features}")
#       7 # Run with early stopping
# ----> 8 train_and_evaluate(df, target_column=target_column, feature_columns=features, params=param_dict, file_prefix='results_complete2', use_early_stopping=True, plot_loss=False)
#       9 # Run with fixed epochs
#      10 train_and_evaluate(df, target_column=target_column, feature_columns=features, params=param_dict, file_prefix='results_complete_fixed_epochs2', use_early_stopping=False, plot_loss=False)
#
# Cell In[54], line 69, in train_and_evaluate(df, target_column, feature_columns, params, file_prefix, use_early_stopping, plot_loss)
#      67 model.train()
#      68 epoch_train_loss = 0
# ---> 69 for inputs, labels in train_loader:
#      70     optimizer.zero_grad()
#      71     outputs = model(inputs)
#
# File ~\anaconda3\envs\torch\Lib\site-packages\torch\utils\data\dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File ~\anaconda3\envs\torch\Lib\site-packages\torch\utils\data\dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~\anaconda3\envs\torch\Lib\site-packages\torch\utils\data\_utils\fetch.py:54, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
# ---> 54 return self.collate_fn(data)
#
# File ~\anaconda3\envs\torch\Lib\site-packages\torch\utils\data\_utils\collate.py:277, in default_collate(batch)
#     216 def default_collate(batch):
#     217     r"""
#     218     Take in a batch of data and put the elements within the batch into a tensor with an additional outer dimension - batch size.
#     219
#    (...)
#     275         >>> default_collate(batch)  # Handle `CustomType` automatically
#     276     """
# --> 277     return collate(batch, collate_fn_map=default_collate_fn_map)
#
# File ~\anaconda3\envs\torch\Lib\site-packages\torch\utils\data\_utils\collate.py:144, in collate(batch, collate_fn_map)
#     141 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     143 if isinstance(elem, tuple):
# --> 144     return [collate(samples, collate_fn_map=collate_fn_map) for samples in transposed]  # Backwards compatibility.
#     145 else:
#     146     try:
#
# File ~\anaconda3\envs\torch\Lib\site-packages\torch\utils\data\_utils\collate.py:144, in <listcomp>(.0)
#     141 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     143 if isinstance(elem, tuple):
# --> 144     return [collate(samples, collate_fn_map=collate_fn_map) for samples in transposed]  # Backwards compatibility.
#     145 else:
#     146     try:
#
# File ~\anaconda3\envs\torch\Lib\site-packages\torch\utils\data\_utils\collate.py:121, in collate(batch, collate_fn_map)
#     119 if collate_fn_map is not None:
#     120     if elem_type in collate_fn_map:
# --> 121         return collate_fn_map[elem_type](batch, collate_fn_map=collate_fn_map)
#     123     for collate_type in collate_fn_map:
#     124         if isinstance(elem, collate_type):
#
# File ~\anaconda3\envs\torch\Lib\site-packages\torch\utils\data\_utils\collate.py:174, in collate_tensor_fn(batch, collate_fn_map)
#     172     storage = elem._typed_storage()._new_shared(numel, device=elem.device)
#     173     out = elem.new(storage).resize_(len(batch), *list(elem.size()))
# --> 174 return torch.stack(batch, 0, out=out)
#
# KeyboardInterrupt:

# %% [markdown]
# # THE CODE ABOVE I SORT OF DELETED BY ACCIDENT I PRESSED GO AGAIN AND WIPED THE OUTPUT BUT IT SHOULD BE SAVED - HOPEFULLY NOTHING WAS OVERWRITTEN BUT I DONT THINK SO IT

# %%
# the following has modified the variable management (cuda)
# also modified some of the printouts etc

# %%
# def train_and_evaluate(df, target_column, feature_columns, params, file_prefix='results', use_early_stopping=True, plot_loss=False):
#     # Extract parameters
#     window_size = params['window_size']
#     lstm_dim = params['lstm_dim']
#     dense_dim = params['dense_dim']
#     num_layers = params['num_layers']
#     dropout = params['dropout']
#     lr = params['lr']
#     batch_size = params['batch_size']
#     num_epochs = params['num_epochs']
#     optimizer_type = params['optimizer_type']
#     patience = params['patience']

#     # Clear CUDA cache
#     torch.cuda.empty_cache()

#     # Prepare data
#     X_train_seq, X_test_seq, y_train_seq, y_test_seq, scaler_y = prepare_data(df, target_column, window_size, feature_columns)

#     # Convert to PyTorch tensors
#     X_train_tensor = torch.tensor(X_train_seq, dtype=torch.float32).to(device)
#     X_test_tensor = torch.tensor(X_test_seq, dtype=torch.float32).to(device)
#     y_train_tensor = torch.tensor(y_train_seq, dtype=torch.float32).view(-1, 1).to(device)
#     y_test_tensor = torch.tensor(y_test_seq, dtype=torch.float32).view(-1, 1).to(device)

#     # Create data loaders
#     train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
#     test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
#     train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
#     test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

#     # Clear intermediate data variables
#     del X_train_seq, X_test_seq, y_train_seq, y_test_seq
#     del X_train_tensor, X_test_tensor, y_train_tensor, y_test_tensor
#     del train_dataset, test_dataset
#     torch.cuda.empty_cache()

#     # Model parameters
#     input_dim = train_loader.dataset.tensors[0].shape[2]
#     output_dim = 1

#     model = LSTMModel(input_dim, lstm_dim, dense_dim, output_dim, num_layers, dropout).to(device)

#     # Define loss and optimizer
#     criterion = nn.MSELoss()
#     optimizer = getattr(optim, optimizer_type)(model.parameters(), lr=lr)

#     # Training loop
#     best_loss = float('inf')
#     patience_counter = 0
#     start_time = time.time()

#     training_losses = []
#     validation_losses = []

#     for epoch in range(num_epochs):
#         model.train()
#         epoch_train_loss = 0
#         for inputs, labels in train_loader:
#             optimizer.zero_grad()
#             outputs = model(inputs)
#             loss = criterion(outputs, labels)
#             loss.backward()
#             optimizer.step()
#             epoch_train_loss += loss.item()
#             # Clear variables at the end of each iteration
#             del inputs, labels, outputs
#             torch.cuda.empty_cache()

#         epoch_train_loss /= len(train_loader)
#         training_losses.append(epoch_train_loss)

#         model.eval()
#         val_loss = 0
#         with torch.no_grad():
#             for inputs, labels in test_loader:
#                 outputs = model(inputs)
#                 val_loss += criterion(outputs, labels).item()
#                 # Clear variables at the end of each iteration
#                 del inputs, labels, outputs
#                 torch.cuda.empty_cache()

#         val_loss /= len(test_loader)
#         validation_losses.append(val_loss)

#         if use_early_stopping:
#             if val_loss < best_loss:
#                 best_loss = val_loss
#                 patience_counter = 0
#                 torch.save(model.state_dict(), f'{file_prefix}_{target_column}_best_model.pth')
#             else:
#                 patience_counter += 1
#                 if patience_counter >= patience:
#                     break

#     training_time = time.time() - start_time

#     # Save the final model if early stopping was not used or not triggered
#     if not use_early_stopping or patience_counter < patience:
#         torch.save(model.state_dict(), f'{file_prefix}_{target_column}_final_model.pth')

#     # Clear training-related variables
#     del train_loader, test_loader, criterion, optimizer
#     torch.cuda.empty_cache()

#     # Evaluate the model
#     model.eval()
#     evaluation_start_time = time.time()
#     with torch.no_grad():
#         train_predictions = model(train_loader.dataset.tensors[0]).cpu().numpy()
#         test_predictions = model(test_loader.dataset.tensors[0]).cpu().numpy()

#         # Inverse transform predictions and actual values
#         y_train_seq = train_loader.dataset.tensors[1].cpu().numpy()
#         y_test_seq = test_loader.dataset.tensors[1].cpu().numpy()
#         train_predictions_inverse = scaler_y.inverse_transform(train_predictions)
#         test_predictions_inverse = scaler_y.inverse_transform(test_predictions)
#         y_train_inverse = scaler_y.inverse_transform(y_train_seq)
#         y_test_inverse = scaler_y.inverse_transform(y_test_seq)

#         train_mse = mean_squared_error(y_train_inverse, train_predictions_inverse)
#         test_mse = mean_squared_error(y_test_inverse, test_predictions_inverse)
#         train_mae = mean_absolute_error(y_train_inverse, train_predictions_inverse)
#         test_mae = mean_absolute_error(y_test_inverse, test_predictions_inverse)
#         train_rmse = np.sqrt(train_mse)
#         test_rmse = np.sqrt(test_mse)
#         train_r2 = r2_score(y_train_inverse, train_predictions_inverse)
#         test_r2 = r2_score(y_test_inverse, test_predictions_inverse)

#         train_mape = np.mean(np.abs((y_train_inverse - train_predictions_inverse) / y_train_inverse)) * 100
#         test_mape = np.mean(np.abs((y_test_inverse - test_predictions_inverse) / y_test_inverse)) * 100

#         train_directional_acc = np.mean(np.sign(y_train_inverse[1:] - y_train_inverse[:-1]) == np.sign(train_predictions_inverse[1:] - train_predictions_inverse[:-1]))
#         test_directional_acc = np.mean(np.sign(y_test_inverse[1:] - y_test_inverse[:-1]) == np.sign(test_predictions_inverse[1:] - test_predictions_inverse[:-1]))

#     evaluation_time = time.time() - evaluation_start_time

#     result = {
#         "window_size": window_size,
#         "lstm_dim": lstm_dim,
#         "num_layers": num_layers,
#         "dense_dim": dense_dim,
#         "dropout": dropout,
#         "lr": lr,
#         "batch_size": batch_size,
#         "num_epochs": num_epochs,
#         "optimizer_type": optimizer_type,
#         "train_mse": train_mse,
#         "test_mse": test_mse,
#         "train_mae": train_mae,
#         "test_mae": test_mae,
#         "train_rmse": train_rmse,
#         "test_rmse": test_rmse,
#         "train_r2": train_r2,
#         "test_r2": test_r2,
#         "train_mape": train_mape,
#         "test_mape": test_mape,
#         "train_directional_acc": train_directional_acc,
#         "test_directional_acc": test_directional_acc,
#         "training_time": training_time,
#         "evaluation_time": evaluation_time,
#         "patience": patience
#     }

#     # Save result to a CSV file
#     with open(f'{file_prefix}_{target_column}.csv', 'a', newline='') as f:
#         writer = csv.DictWriter(f, fieldnames=result.keys())
#         if f.tell() == 0:
#             writer.writeheader()  # Write header only if file is empty
#         writer.writerow(result)

#     # Save training and validation losses to a JSON file
#     losses = {
#         "training_losses": training_losses,
#         "validation_losses": validation_losses
#     }
#     with open(f'{file_prefix}_{target_column}_losses.json', 'w') as f:
#         json.dump(losses, f)

#     # Save predictions and actual values to a JSON file
#     predictions = {
#         "train_predictions": train_predictions_inverse.tolist(),
#         "test_predictions": test_predictions_inverse.tolist(),
#         "y_train": y_train_inverse.tolist(),
#         "y_test": y_test_inverse.tolist()
#     }
#     with open(f'{file_prefix}_{target_column}_predictions.json', 'w') as f:
#         json.dump(predictions, f)

#     # Save hyperparameters to a JSON file, excluding any non-serializable types
#     serializable_params = {k: v for k, v in params.items() if isinstance(v, (int, float, str, bool))}
#     with open(f'{file_prefix}_{target_column}_params.json', 'w') as f:
#         json.dump(serializable_params, f)

#     # Clear evaluation-related variables
#     del train_predictions, test_predictions
#     del train_predictions_inverse, test_predictions_inverse
#     del y_train_inverse, y_test_inverse
#     del losses, predictions
#     torch.cuda.empty_cache()

#     # Print summary of the results
#     print(f"Results: Train MSE: {train_mse:.4f}, Test MSE: {test_mse:.4f}, Train MAE: {train_mae:.4f}, Test MAE: {test_mae:.4f}")
#     print(f"Train RMSE: {train_rmse:.4f}, Test RMSE: {test_rmse:.4f}, Train R2: {train_r2:.4f}, Test R2: {test_r2:.4f}")
#     print(f"Train MAPE: {train_mape:.4f}, Test MAPE: {test_mape:.4f}")
#     print(f"Train Directional Accuracy: {train_directional_acc:.4f}, Test Directional Accuracy: {test_directional_acc:.4f}")
#     print(f"Training Time: {training_time:.4f} seconds, Evaluation Time: {evaluation_time:.4f} seconds\n")

#     # Plot loss over epochs if specified
#     if plot_loss:
#         plot_loss_over_epochs(training_losses, validation_losses, f'{file_prefix}_{target_column}', start_epoch=3)

#     # Clear remaining variables
#     del model, result, serializable_params
#     torch.cuda.empty_cache()

#     return result

# %%
# def create_sequences(data, target, window_size):
#     sequences = []
#     labels = []
#     for i in range(len(data) - window_size):
#         seq = data[i:i + window_size]
#         label = target[i + window_size]
#         sequences.append(seq)
#         labels.append(label)
#     return np.array(sequences), np.array(labels)

# def prepare_data(df, target_column, window_size, feature_columns):
#     X = df[feature_columns].values
#     y = df[target_column].values.reshape(-1, 1)

#     scaler_X = MinMaxScaler()
#     X_scaled = scaler_X.fit_transform(X)

#     scaler_y = MinMaxScaler()
#     y_scaled = scaler_y.fit_transform(y)

#     X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, shuffle=False)
#     X_train_seq, y_train_seq = create_sequences(X_train, y_train, window_size)
#     X_test_seq, y_test_seq = create_sequences(X_test, y_test, window_size)

#     return X_train_seq, X_test_seq, y_train_seq, y_test_seq, scaler_y

# class LSTMModel(nn.Module):
#     def __init__(self, input_dim, lstm_dim, dense_dim, output_dim, num_layers=1, dropout=0.0):
#         super(LSTMModel, self).__init__()
#         self.lstm = nn.LSTM(input_dim, lstm_dim, num_layers=num_layers, batch_first=True, dropout=(dropout if num_layers > 1 else 0))
#         self.fc1 = nn.Linear(lstm_dim, dense_dim)
#         self.activation = nn.Tanh()
#         self.fc2 = nn.Linear(dense_dim, output_dim)

#     def forward(self, x):
#         x, _ = self.lstm(x)
#         x = x[:, -1, :]
#         x = self.fc1(x)
#         x = self.activation(x)
#         x = self.fc2(x)
#         return x

# %%
# def train_and_evaluate(df, target_column, feature_columns, params, file_prefix='results', use_early_stopping=True, plot_loss=False):
#     result = {}  # Initialize result to ensure it's always defined
#     try:
#         # Extract parameters
#         window_size = params['window_size']
#         lstm_dim = params['lstm_dim']
#         dense_dim = params['dense_dim']
#         num_layers = params['num_layers']
#         dropout = params['dropout']
#         lr = params['lr']
#         batch_size = params['batch_size']
#         num_epochs = params['num_epochs']
#         optimizer_type = params['optimizer_type']
#         patience = params['patience']

#         # Clear CUDA cache
#         torch.cuda.empty_cache()

#         # Prepare data
#         X_train_seq, X_test_seq, y_train_seq, y_test_seq, scaler_y = prepare_data(df, target_column, window_size, feature_columns)

#         # Convert to PyTorch tensors
#         X_train_tensor = torch.tensor(X_train_seq, dtype=torch.float32).to(device)
#         X_test_tensor = torch.tensor(X_test_seq, dtype=torch.float32).to(device)
#         y_train_tensor = torch.tensor(y_train_seq, dtype=torch.float32).view(-1, 1).to(device)
#         y_test_tensor = torch.tensor(y_test_seq, dtype=torch.float32).view(-1, 1).to(device)

#         # Create data loaders
#         train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
#         test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
#         train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
#         test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

#         # Model parameters
#         input_dim = X_train_tensor.shape[2]
#         output_dim = 1

#         model = LSTMModel(input_dim, lstm_dim, dense_dim, output_dim, num_layers, dropout).to(device)

#         # Define loss and optimizer
#         criterion = nn.MSELoss()
#         optimizer = getattr(optim, optimizer_type)(model.parameters(), lr=lr)

#         # Training loop
#         best_loss = float('inf')
#         patience_counter = 0
#         start_time = time.time()

#         training_losses = []
#         validation_losses = []

#         for epoch in range(num_epochs):
#             model.train()
#             epoch_train_loss = 0
#             for inputs, labels in train_loader:
#                 optimizer.zero_grad()
#                 outputs = model(inputs)
#                 loss = criterion(outputs, labels)
#                 loss.backward()
#                 optimizer.step()
#                 epoch_train_loss += loss.item()

#             epoch_train_loss /= len(train_loader)
#             training_losses.append(epoch_train_loss)

#             model.eval()
#             val_loss = 0
#             with torch.no_grad():
#                 for inputs, labels in test_loader:
#                     outputs = model(inputs)
#                     val_loss += criterion(outputs, labels).item()

#             val_loss /= len(test_loader)
#             validation_losses.append(val_loss)

#             if use_early_stopping:
#                 if val_loss < best_loss:
#                     best_loss = val_loss
#                     patience_counter = 0
#                     torch.save(model.state_dict(), f'{file_prefix}_{target_column}_best_model.pth')
#                 else:
#                     patience_counter += 1
#                     if patience_counter >= patience:
#                         break

#         training_time = time.time() - start_time

#         # Save the final model if early stopping was not used or not triggered
#         if not use_early_stopping or patience_counter < patience:
#             torch.save(model.state_dict(), f'{file_prefix}_{target_column}_final_model.pth')

#         # Evaluate the model
#         model.eval()
#         evaluation_start_time = time.time()
#         with torch.no_grad():
#             train_predictions = model(X_train_tensor).cpu().numpy()
#             test_predictions = model(X_test_tensor).cpu().numpy()

#             # Inverse transform predictions and actual values
#             y_train_seq = y_train_seq.reshape(-1, 1)
#             y_test_seq = y_test_seq.reshape(-1, 1)
#             train_predictions_inverse = scaler_y.inverse_transform(train_predictions)
#             test_predictions_inverse = scaler_y.inverse_transform(test_predictions)
#             y_train_inverse = scaler_y.inverse_transform(y_train_seq)
#             y_test_inverse = scaler_y.inverse_transform(y_test_seq)

#             train_mse = mean_squared_error(y_train_inverse, train_predictions_inverse)
#             test_mse = mean_squared_error(y_test_inverse, test_predictions_inverse)
#             train_mae = mean_absolute_error(y_train_inverse, train_predictions_inverse)
#             test_mae = mean_absolute_error(y_test_inverse, test_predictions_inverse)
#             train_rmse = np.sqrt(train_mse)
#             test_rmse = np.sqrt(test_mse)
#             train_r2 = r2_score(y_train_inverse, train_predictions_inverse)
#             test_r2 = r2_score(y_test_inverse, test_predictions_inverse)

#             train_mape = np.mean(np.abs((y_train_inverse - train_predictions_inverse) / y_train_inverse)) * 100
#             test_mape = np.mean(np.abs((y_test_inverse - test_predictions_inverse) / y_test_inverse)) * 100

#             train_directional_acc = np.mean(np.sign(y_train_inverse[1:] - y_train_inverse[:-1]) == np.sign(train_predictions_inverse[1:] - train_predictions_inverse[:-1]))
#             test_directional_acc = np.mean(np.sign(y_test_inverse[1:] - y_test_inverse[:-1]) == np.sign(test_predictions_inverse[1:] - test_predictions_inverse[:-1]))

#         evaluation_time = time.time() - evaluation_start_time

#         result = {
#             "window_size": window_size,
#             "lstm_dim": lstm_dim,
#             "num_layers": num_layers,
#             "dense_dim": dense_dim,
#             "dropout": dropout,
#             "lr": lr,
#             "batch_size": batch_size,
#             "num_epochs": num_epochs,
#             "optimizer_type": optimizer_type,
#             "train_mse": train_mse,
#             "test_mse": test_mse,
#             "train_mae": train_mae,
#             "test_mae": test_mae,
#             "train_rmse": train_rmse,
#             "test_rmse": test_rmse,
#             "train_r2": train_r2,
#             "test_r2": test_r2,
#             "train_mape": train_mape,
#             "test_mape": test_mape,
#             "train_directional_acc": train_directional_acc,
#             "test_directional_acc": test_directional_acc,
#             "training_time": training_time,
#             "evaluation_time": evaluation_time,
#             "patience": patience
#         }

#         # Save result to a CSV file
#         with open(f'{file_prefix}_{target_column}.csv', 'a', newline='') as f:
#             writer = csv.DictWriter(f, fieldnames=result.keys())
#             if f.tell() == 0:
#                 writer.writeheader()  # Write header only if file is empty
#             writer.writerow(result)

#         # Save training and validation losses to a JSON file
#         losses = {
#             "training_losses": training_losses,
#             "validation_losses": validation_losses
#         }
#         with open(f'{file_prefix}_{target_column}_losses.json', 'w') as f:
#             json.dump(losses, f)

#         # Save predictions and actual values to a JSON file
#         predictions = {
#             "train_predictions": train_predictions_inverse.tolist(),
#             "test_predictions": test_predictions_inverse.tolist(),
#             "y_train": y_train_inverse.tolist(),
#             "y_test": y_test_inverse.tolist()
#         }
#         with open(f'{file_prefix}_{target_column}_predictions.json', 'w') as f:
#             json.dump(predictions, f)

#     # Save hyperparameters to a JSON file, excluding any non-serializable types
#     serializable_params = {k: v for k, v in params.items() if isinstance(v, (int, float, str, bool))}
#     with open(f'{file_prefix}_{target_column}_params.json', 'w') as f:
#         json.dump(serializable_params, f)

#     # Print summary of the results
#     print(f"Results: Train MSE: {train_mse:.4f}, Test MSE: {test_mse:.4f}, Train MAE: {train_mae:.4f}, Test MAE: {test_mae:.4f}")
#     print(f"Train RMSE: {train_rmse:.4f}, Test RMSE: {test_rmse:.4f}, Train R2: {train_r2:.4f}, Test R2: {test_r2:.4f}")
#     print(f"Train MAPE: {train_mape:.4f}, Test MAPE: {test_mape:.4f}")
#     print(f"Train Directional Accuracy: {train_directional_acc:.4f}, Test Directional Accuracy: {test_directional_acc:.4f}")
#     print(f"Training Time: {training_time:.4f} seconds, Evaluation Time: {evaluation_time:.4f} seconds\n")

#     # Plot loss over epochs if specified
#     if plot_loss:
#         plot_loss_over_epochs(training_losses, validation_losses, f'{file_prefix}_{target_column}', start_epoch=3)

#     # Clear remaining variables
#     del model, result, serializable_params
#     torch.cuda.empty_cache()

#     # Plot loss over epochs if specified
#     if plot_loss:
#         plot_loss_over_epochs(training_losses, validation_losses, f'{file_prefix}_{target_column}', start_epoch=3)

#     # Clear remaining variables
#     del model, result, serializable_params
#     torch.cuda.empty_cache()

#     return result
#     except Exception as e:
#         print(f"An error occurred: {e}")
#         # Ensure result is always defined, even in case of error
#         result = {
#             "window_size": window_size,
#             "lstm_dim": lstm_dim,
#             "num_layers": num_layers,
#             "dense_dim": dense_dim,
#             "dropout": dropout,
#             "lr": lr,
#             "batch_size": batch_size,
#             "num_epochs": num_epochs,
#             "optimizer_type": optimizer_type,
#             "error": str(e)
#         }

#     return result
# Out:
#   Cell In[65], line 177
#     serializable_params = {k: v for k, v in params.items() if isinstance(v, (int, float, str, bool))}
#     ^
# SyntaxError: expected 'except' or 'finally' block

# %%
def create_sequences(data, target, window_size):
    sequences = []
    labels = []
    for i in range(len(data) - window_size):
        seq = data[i:i + window_size]
        label = target[i + window_size]
        sequences.append(seq)
        labels.append(label)
    return np.array(sequences), np.array(labels)

def prepare_data(df, target_column, window_size, feature_columns):
    X = df[feature_columns].values
    y = df[target_column].values.reshape(-1, 1)

    scaler_X = MinMaxScaler()
    X_scaled = scaler_X.fit_transform(X)

    scaler_y = MinMaxScaler()
    y_scaled = scaler_y.fit_transform(y)

    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, shuffle=False)
    X_train_seq, y_train_seq = create_sequences(X_train, y_train, window_size)
    X_test_seq, y_test_seq = create_sequences(X_test, y_test, window_size)

    return X_train_seq, X_test_seq, y_train_seq, y_test_seq, scaler_y

class LSTMModel(nn.Module):
    def __init__(self, input_dim, lstm_dim, dense_dim, output_dim, num_layers=1, dropout=0.0):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_dim, lstm_dim, num_layers=num_layers, batch_first=True, dropout=(dropout if num_layers > 1 else 0))
        self.fc1 = nn.Linear(lstm_dim, dense_dim)
        self.activation = nn.Tanh()
        self.fc2 = nn.Linear(dense_dim, output_dim)

    def forward(self, x):
        x, _ = self.lstm(x)
        x = x[:, -1, :]
        x = self.fc1(x)
        x = self.activation(x)
        x = self.fc2(x)
        return x

def train_and_evaluate(df, target_column, feature_columns, params, file_prefix='results', use_early_stopping=True, plot_loss=False):
    result = {}  # Initialize result to ensure it's always defined
    try:
        # Extract parameters
        window_size = params['window_size']
        lstm_dim = params['lstm_dim']
        dense_dim = params['dense_dim']
        num_layers = params['num_layers']
        dropout = params['dropout']
        lr = params['lr']
        batch_size = params['batch_size']
        num_epochs = params['num_epochs']
        optimizer_type = params['optimizer_type']
        patience = params['patience']

        # Clear CUDA cache
        torch.cuda.empty_cache()

        # Prepare data
        X_train_seq, X_test_seq, y_train_seq, y_test_seq, scaler_y = prepare_data(df, target_column, window_size, feature_columns)

        # Convert to PyTorch tensors
        X_train_tensor = torch.tensor(X_train_seq, dtype=torch.float32).to(device)
        X_test_tensor = torch.tensor(X_test_seq, dtype=torch.float32).to(device)
        y_train_tensor = torch.tensor(y_train_seq, dtype=torch.float32).view(-1, 1).to(device)
        y_test_tensor = torch.tensor(y_test_seq, dtype=torch.float32).view(-1, 1).to(device)

        # Create data loaders
        train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
        test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
        train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
        test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

        # Model parameters
        input_dim = X_train_tensor.shape[2]
        output_dim = 1

        model = LSTMModel(input_dim, lstm_dim, dense_dim, output_dim, num_layers, dropout).to(device)

        # Define loss and optimizer
        criterion = nn.MSELoss()
        optimizer = getattr(optim, optimizer_type)(model.parameters(), lr=lr)

        # Training loop
        best_loss = float('inf')
        patience_counter = 0
        start_time = time.time()

        training_losses = []
        validation_losses = []

        for epoch in range(num_epochs):
            model.train()
            epoch_train_loss = 0
            for inputs, labels in train_loader:
                optimizer.zero_grad()
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()
                epoch_train_loss += loss.item()

            epoch_train_loss /= len(train_loader)
            training_losses.append(epoch_train_loss)

            model.eval()
            val_loss = 0
            with torch.no_grad():
                for inputs, labels in test_loader:
                    outputs = model(inputs)
                    val_loss += criterion(outputs, labels).item()

            val_loss /= len(test_loader)
            validation_losses.append(val_loss)

            if use_early_stopping:
                if val_loss < best_loss:
                    best_loss = val_loss
                    patience_counter = 0
                    torch.save(model.state_dict(), f'{file_prefix}_{target_column}_best_model.pth')
                else:
                    patience_counter += 1
                    if patience_counter >= patience:
                        break

        training_time = time.time() - start_time

        # Save the final model if early stopping was not used or not triggered
        if not use_early_stopping or patience_counter < patience:
            torch.save(model.state_dict(), f'{file_prefix}_{target_column}_final_model.pth')

        # Evaluate the model
        model.eval()
        evaluation_start_time = time.time()
        with torch.no_grad():
            train_predictions = model(X_train_tensor).cpu().numpy()
            test_predictions = model(X_test_tensor).cpu().numpy()

            # Inverse transform predictions and actual values
            y_train_seq = y_train_seq.reshape(-1, 1)
            y_test_seq = y_test_seq.reshape(-1, 1)
            train_predictions_inverse = scaler_y.inverse_transform(train_predictions)
            test_predictions_inverse = scaler_y.inverse_transform(test_predictions)
            y_train_inverse = scaler_y.inverse_transform(y_train_seq)
            y_test_inverse = scaler_y.inverse_transform(y_test_seq)

            train_mse = mean_squared_error(y_train_inverse, train_predictions_inverse)
            test_mse = mean_squared_error(y_test_inverse, test_predictions_inverse)
            train_mae = mean_absolute_error(y_train_inverse, train_predictions_inverse)
            test_mae = mean_absolute_error(y_test_inverse, test_predictions_inverse)
            train_rmse = np.sqrt(train_mse)
            test_rmse = np.sqrt(test_mse)
            train_r2 = r2_score(y_train_inverse, train_predictions_inverse)
            test_r2 = r2_score(y_test_inverse, test_predictions_inverse)

            train_mape = np.mean(np.abs((y_train_inverse - train_predictions_inverse) / y_train_inverse)) * 100
            test_mape = np.mean(np.abs((y_test_inverse - test_predictions_inverse) / y_test_inverse)) * 100

            train_directional_acc = np.mean(np.sign(y_train_inverse[1:] - y_train_inverse[:-1]) == np.sign(train_predictions_inverse[1:] - train_predictions_inverse[:-1]))
            test_directional_acc = np.mean(np.sign(y_test_inverse[1:] - y_test_inverse[:-1]) == np.sign(test_predictions_inverse[1:] - test_predictions_inverse[:-1]))

        evaluation_time = time.time() - evaluation_start_time

        result = {
            "window_size": window_size,
            "lstm_dim": lstm_dim,
            "num_layers": num_layers,
            "dense_dim": dense_dim,
            "dropout": dropout,
            "lr": lr,
            "batch_size": batch_size,
            "num_epochs": num_epochs,
            "optimizer_type": optimizer_type,
            "train_mse": train_mse,
            "test_mse": test_mse,
            "train_mae": train_mae,
            "test_mae": test_mae,
            "train_rmse": train_rmse,
            "test_rmse": test_rmse,
            "train_r2": train_r2,
            "test_r2": test_r2,
            "train_mape": train_mape,
            "test_mape": test_mape,
            "train_directional_acc": train_directional_acc,
            "test_directional_acc": test_directional_acc,
            "training_time": training_time,
            "evaluation_time": evaluation_time,
            "patience": patience
        }

        # Save result to a CSV file
        with open(f'{file_prefix}_{target_column}.csv', 'a', newline='') as f:
            writer = csv.DictWriter(f, fieldnames=result.keys())
            if f.tell() == 0:
                writer.writeheader()  # Write header only if file is empty
            writer.writerow(result)

        # Save training and validation losses to a JSON file
        losses = {
            "training_losses": training_losses,
            "validation_losses": validation_losses
        }
        with open(f'{file_prefix}_{target_column}_losses.json', 'w') as f:
            json.dump(losses, f)

        # Save predictions and actual values to a JSON file
        predictions = {
            "train_predictions": train_predictions_inverse.tolist(),
            "test_predictions": test_predictions_inverse.tolist(),
            "y_train": y_train_inverse.tolist(),
            "y_test": y_test_inverse.tolist()
        }
        with open(f'{file_prefix}_{target_column}_predictions.json', 'w') as f:
            json.dump(predictions, f)

        # Save hyperparameters to a JSON file, excluding any non-serializable types
        serializable_params = {k: v for k, v in params.items() if isinstance(v, (int, float, str, bool))}
        with open(f'{file_prefix}_{target_column}_params.json', 'w') as f:
            json.dump(serializable_params, f)

        # Print summary of the results
        print(f"Results: Train MSE: {train_mse:.4f}, Test MSE: {test_mse:.4f}, Train MAE: {train_mae:.4f}, Test MAE: {test_mae:.4f}")
        print(f"Train RMSE: {train_rmse:.4f}, Test RMSE: {test_rmse:.4f}, Train R2: {train_r2:.4f}, Test R2: {test_r2:.4f}")
        print(f"Train MAPE: {train_mape:.4f}, Test MAPE: {test_mape:.4f}")
        print(f"Train Directional Accuracy: {train_directional_acc:.4f}, Test Directional Accuracy: {test_directional_acc:.4f}")
        print(f"Training Time: {training_time:.4f} seconds, Evaluation Time: {evaluation_time:.4f} seconds\n")

        # Plot loss over epochs if specified
        if plot_loss:
            plot_loss_over_epochs(training_losses, validation_losses, f'{file_prefix}_{target_column}', start_epoch=3)

    except Exception as e:
        print(f"An error occurred: {e}")
        # Ensure result is always defined, even in case of error
        result = {
            "window_size": window_size,
            "lstm_dim": lstm_dim,
            "num_layers": num_layers,
            "dense_dim": dense_dim,
            "dropout": dropout,
            "lr": lr,
            "batch_size": batch_size,
            "num_epochs": num_epochs,
            "optimizer_type": optimizer_type,
            "error": str(e)
        }

    return result

# %%
# Define target column
target_column = ['log_close']

# Define feature combination
features = ['log_open', 'log_high', 'log_low', 'log_close', 'volume',
       'quote_vol', 'count', 'buy_base', 'buy_quote', 'open_p', 'high_p', 'low_p', 'close_p']

# %%
# Grid search
for params in itertools.product(*parameter_space.values()):
    param_dict = dict(zip(parameter_space.keys(), params))
    print(f"Running model with parameters: {param_dict}\n")
    # Run with early stopping
    print('Results with early stopping:\n')
    train_and_evaluate(df, target_column=target_column, feature_columns=features, params=param_dict, file_prefix='results_complete3', use_early_stopping=True, plot_loss=False)
    # Run with fixed epochs
    print('Results with fixed epochs:\n')
    train_and_evaluate(df, target_column=target_column, feature_columns=features, params=param_dict, file_prefix='results_complete_fixed_epochs3', use_early_stopping=False, plot_loss=False)
# Out:
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 50, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 50, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 0.0001, Test MSE: 0.0001, Train MAE: 0.0072, Test MAE: 0.0060
# Train RMSE: 0.0104, Test RMSE: 0.0075, Train R2: 0.9997, Test R2: 0.9995
# Train MAPE: 0.0714, Test MAPE: 0.0564
# Train Directional Accuracy: 0.4634, Test Directional Accuracy: 0.4646
# Training Time: 51.1476 seconds, Evaluation Time: 0.1477 seconds
#
# Results with fixed epochs:
#
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 50, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 0.0001, Test MSE: 0.0001, Train MAE: 0.0077, Test MAE: 0.0059
# Train RMSE: 0.0105, Test RMSE: 0.0074, Train R2: 0.9997, Test R2: 0.9995
# Train MAPE: 0.0770, Test MAPE: 0.0560
# Train Directional Accuracy: 0.4656, Test Directional Accuracy: 0.4721
# Training Time: 51.1443 seconds, Evaluation Time: 0.1542 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 0.0001, Test MSE: 0.0000, Train MAE: 0.0051, Test MAE: 0.0036
# Train RMSE: 0.0083, Test RMSE: 0.0055, Train R2: 0.9998, Test R2: 0.9997
# Train MAPE: 0.0501, Test MAPE: 0.0335
# Train Directional Accuracy: 0.4702, Test Directional Accuracy: 0.4724
# Training Time: 103.7163 seconds, Evaluation Time: 0.1631 seconds
#
# Results with fixed epochs:
#
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 0.0001, Test MSE: 0.0000, Train MAE: 0.0050, Test MAE: 0.0033
# Train RMSE: 0.0082, Test RMSE: 0.0052, Train R2: 0.9998, Test R2: 0.9997
# Train MAPE: 0.
# Train Directional Accuracy: 0.4698, Test Directional Accuracy: 0.4710
# Training Time: 62.0716 seconds, Evaluation Time: 3.9116 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.0001, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.0001, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 0.0001, Test MSE: 0.0000, Train MAE: 0.0054, Test MAE: 0.0047
# Train RMSE: 0.0084, Test RMSE: 0.0064, Train R2: 0.9998, Test R2: 0.9996
# Train MAPE: 0.0535, Test MAPE: 0.0444
# Train Directional Accuracy: 0.4727, Test Directional Accuracy: 0.4716
# Training Time: 124.5994 seconds, Evaluation Time: 3.9423 seconds
#
# Results with fixed epochs:
#
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.0001, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 0.0001, Test MSE: 0.0000, Train MAE: 0.0055, Test MAE: 0.0036
# Train RMSE: 0.0084, Test RMSE: 0.0054, Train R2: 0.9998, Test R2: 0.9997
# Train MAPE: 0.0547, Test MAPE: 0.0340
# Train Directional Accuracy: 0.4727, Test Directional Accuracy: 0.4689
# Training Time: 123.2631 seconds, Evaluation Time: 3.7267 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.0001, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.0001, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 0.0001, Test MSE: 0.0001, Train MAE: 0.0079, Test MAE: 0.0090
# Train RMSE: 0.0103, Test RMSE: 0.0101, Train R2: 0.9997, Test R2: 0.9990
# Train MAPE: 0.0772, Test MAPE: 0.0844
# Train Directional Accuracy: 0.4720, Test Directional Accuracy: 0.4713
# Training Time: 185.7341 seconds, Evaluation Time: 3.8082 seconds
#
# Results with fixed epochs:
#
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.0001, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 0.0001, Test MSE: 0.0000, Train MAE: 0.0050, Test MAE: 0.0035
# Train RMSE: 0.0080, Test RMSE: 0.0053, Train R2: 0.9998, Test R2: 0.9997
# Train MAPE: 0.0498, Test MAPE: 0.0330
# Train Directional Accuracy: 0.4720, Test Directional Accuracy: 0.4729
# Training Time: 186.7603 seconds, Evaluation Time: 3.9221 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.0001, 'lr': 0.001, 'num_epochs': 50, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.0001, 'lr': 0.001, 'num_epochs': 50, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 0.0001, Test MSE: 0.0001, Train MAE: 0.0068, Test MAE: 0.0069
# Train RMSE: 0.0096, Test RMSE: 0.0083, Train R2: 0.9998, Test R2: 0.9994
# Train MAPE: 0.0668, Test MAPE: 0.0652
# Train Directional Accuracy: 0.4709, Test Directional Accuracy: 0.4716
# Training Time: 61.8923 seconds, Evaluation Time: 4.0604 seconds
#
# Results with fixed epochs:
#
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.0001, 'lr': 0.001, 'num_epochs': 50, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 0.0001, Test MSE: 0.0000, Train MAE: 0.0061, Test MAE: 0.0047
# Train RMSE: 0.0087, Test RMSE: 0.0062, Train R2: 0.9998, Test R2: 0.9996
# Train MAPE: 0.0609, Test MAPE: 0.0443
# Train Directional Accuracy: 0.4701, Test Directional Accuracy: 0.4730
# Training Time: 62.4808 seconds, Evaluation Time: 3.6627 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.0001, 'lr': 0.001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.0001, 'lr': 0.001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 0.0001, Test MSE: 0.0001, Train MAE: 0.0089, Test MAE: 0.0096
# Train RMSE: 0.0109, Test RMSE: 0.0107, Train R2: 0.9997, Test R2: 0.9989
# Train MAPE: 0.0878, Test MAPE: 0.0909
# Train Directional Accuracy: 0.4710, Test Directional Accuracy: 0.4710
# Training Time: 123.3175 seconds, Evaluation Time: 3.8226 seconds
#
# Results with fixed epochs:
#
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.0001, 'lr': 0.001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 0.0001, Test MSE: 0.0001, Train MAE: 0.0092, Test MAE: 0.0087
# Train RMSE: 0.0113, Test RMSE: 0.0097, Train R2: 0.9997, Test R2: 0.9991
# Train MAPE: 0.0907, Test MAPE: 0.0826
# Train Directional Accuracy: 0.4715, Test Directional Accuracy: 0.4681
# Training Time: 123.9521 seconds, Evaluation Time: 4.7474 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.0001, 'lr': 0.001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.0001, 'lr': 0.001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 0.0001, Test MSE: 0.0001, Train MAE: 0.0074, Test MAE: 0.0074
# Train RMSE: 0.0099, Test RMSE: 0.0085, Train R2: 0.9998, Test R2: 0.9993
# Train MAPE: 0.0730, Test MAPE: 0.0701
# Train Directional Accuracy: 0.4721, Test Directional Accuracy: 0.4703
# Training Time: 86.3312 seconds, Evaluation Time: 4.7841 seconds
#
# Results with fixed epochs:
#
# Finished model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.0001, 'lr': 0.001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
# Results: Train MSE: 0.0001, Test MSE: 0.0000, Train MAE: 0.0057, Test MAE: 0.0051
# Train RMSE: 0.0083, Test RMSE: 0.0065, Train R2: 0.9998, Test R2: 0.9996
# Train MAPE: 0.0568, Test MAPE: 0.0485
# Train Directional Accuracy: 0.4695, Test Directional Accuracy: 0.4684
# Training Time: 188.1623 seconds, Evaluation Time: 4.6192 seconds

# %%
# Define feature combination
features = ['log_open', 'log_high', 'log_low', 'log_close', 'volume',
       'quote_vol', 'count', 'buy_base', 'buy_quote']

# %%
# Start total timer
start = time.time()

# Grid search
for params in itertools.product(*parameter_space.values()):
    param_dict = dict(zip(parameter_space.keys(), params))
    print(f"Running model with parameters: {param_dict}\n")
    # Run with early stopping
    print('Results with early stopping:\n')
    train_and_evaluate(df, target_column=target_column, feature_columns=features, params=param_dict, file_prefix='results_complete5', use_early_stopping=True, plot_loss=False)
    # Run with fixed epochs
    print('Results with fixed epochs:\n')
    train_and_evaluate(df, target_column=target_column, feature_columns=features, params=param_dict, file_prefix='results_complete_fixed_epochs5', use_early_stopping=False, plot_loss=False)

# Calculate total time
end = time.time()
total_time = end - start

# Print the total time taken
print(f"Total time taken: {total_time} seconds")

# Function to play a beep sound in a loop
def play_beep():
    while not stop_beep_flag:
        winsound.Beep(2000, 600)
        time.sleep(0.7)
        
# Start the beep sound
stop_beep_flag = False
beep_thread = Thread(target=play_beep)
beep_thread.start()

input("Press Enter to stop the beep sound...")
stop_beep_flag = True
beep_thread.join()
print("Beep sound stopped.")
# Out:
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 50, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Results: Train MSE: 0.0001, Test MSE: 0.0000, Train MAE: 0.0058, Test MAE: 0.0037
# Train RMSE: 0.0094, Test RMSE: 0.0057, Train R2: 0.9998, Test R2: 0.9997
# Train MAPE: 0.0578, Test MAPE: 0.0346
# Train Directional Accuracy: 0.4653, Test Directional Accuracy: 0.4656
# Training Time: 52.2349 seconds, Evaluation Time: 0.1622 seconds
#
# Results with fixed epochs:
#
# Results: Train MSE: 0.0001, Test MSE: 0.0000, Train MAE: 0.0058, Test MAE: 0.0037
# Train RMSE: 0.0093, Test RMSE: 0.0057, Train R2: 0.9998, Test R2: 0.9997
# Train MAPE: 0.0574, Test MAPE: 0.0350
# Train Directional Accuracy: 0.4666, Test Directional Accuracy: 0.4664
# Training Time: 52.2403 seconds, Evaluation Time: 0.1437 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Results: Train MSE: 0.0001, Test MSE: 0.0000, Train MAE: 0.0054, Test MAE: 0.0042
# Train RMSE: 0.0086, Test RMSE: 0.0060, Train R2: 0.9998, Test R2: 0.9997
# Train MAPE: 0.0533, Test MAPE: 0.0397
# Train Directional Accuracy: 0.4689, Test Directional Accuracy: 0.4696
# Training Time: 104.4131 seconds, Evaluation Time: 0.1436 seconds
#
# Results with fixed epochs:
#
# Results: Train MSE: 0.0001, Test MSE: 0.0000, Train MAE: 0.0051, Test MAE: 0.0033
# Train RMSE: 0.0084, Test RMSE: 0.0052, Train R2: 0.9998, Test R2: 0.9997
# Train MAPE: 0.0507, Test MAPE: 0.0314
# Train Directional Accuracy: 0.4686, Test Directional Accuracy: 0.4710
# Training Time: 103.9989 seconds, Evaluation Time: 0.1897 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Results: Train MSE: 0.0001, Test MSE: 0.0000, Train MAE: 0.0056, Test MAE: 0.0040
# Train RMSE: 0.0087, Test RMSE: 0.0058, Train R2: 0.9998, Test R2: 0.9997
# Train MAPE: 0.0560, Test MAPE: 0.0379
# Train Directional Accuracy: 0.4690, Test Directional Accuracy: 0.4705
# Training Time: 89.8161 seconds, Evaluation Time: 0.1641 seconds
#
# Results with fixed epochs:
#
# Results: Train MSE: 0.0001, Test MSE: 0.0000, Train MAE: 0.0050, Test MAE: 0.0034
# Train RMSE: 0.0081, Test RMSE: 0.0052, Train R2: 0.9998, Test R2: 0.9998
# Train MAPE: 0.0500, Test MAPE: 0.0322
# Train Directional Accuracy: 0.4702, Test Directional Accuracy: 0.4716
# Training Time: 158.3642 seconds, Evaluation Time: 0.1522 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.001, 'num_epochs': 50, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Results: Train MSE: 0.0001, Test MSE: 0.0000, Train MAE: 0.0048, Test MAE: 0.0033
# Train RMSE: 0.0079, Test RMSE: 0.0052, Train R2: 0.9998, Test R2: 0.9998
# Train MAPE: 0.0475, Test MAPE: 0.0309
# Train Directional Accuracy: 0.4716, Test Directional Accuracy: 0.4680
# Training Time: 52.9868 seconds, Evaluation Time: 0.1451 seconds
#
# Results with fixed epochs:
#
# Results: Train MSE: 0.0001, Test MSE: 0.0000, Train MAE: 0.0052, Test MAE: 0.0040
# Train RMSE: 0.0082, Test RMSE: 0.0058, Train R2: 0.9998, Test R2: 0.9997
# Train MAPE: 0.0511, Test MAPE: 0.0373
# Train Directional Accuracy: 0.4714, Test Directional Accuracy: 0.4720
# Training Time: 52.3733 seconds, Evaluation Time: 0.1612 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Results: Train MSE: 0.0001, Test MSE: 0.0001, Train MAE: 0.
seconds
#
# Results with fixed epochs:
#
# Results: Train MSE: 0.0001, Test MSE: 0.0001, Train MAE: 0.0084, Test MAE: 0.0084
# Train RMSE: 0.0107, Test RMSE: 0.0094, Train R2: 0.9997, Test R2: 0.9992
# Train MAPE: 0.0829, Test MAPE: 0.0794
# Train Directional Accuracy: 0.4703, Test Directional Accuracy: 0.4693
# Training Time: 178.2708 seconds, Evaluation Time: 0.4530 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.0001, 'lr': 0.001, 'num_epochs': 50, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Results: Train MSE: 0.0001, Test MSE: 0.0001, Train MAE: 0.0082, Test MAE: 0.0084
# Train RMSE: 0.0106, Test RMSE: 0.0094, Train R2: 0.9997, Test R2: 0.9992
# Train MAPE: 0.0812, Test MAPE: 0.0794
# Train Directional Accuracy: 0.4698, Test Directional Accuracy: 0.4703
# Training Time: 59.8361 seconds, Evaluation Time: 0.4530 seconds
#
# Results with fixed epochs:
#
# Results: Train MSE: 0.0001, Test MSE: 0.0001, Train MAE: 0.0063, Test MAE: 0.0062
# Train RMSE: 0.0089, Test RMSE: 0.0076, Train R2: 0.9998, Test R2: 0.9995
# Train MAPE: 0.0617, Test MAPE: 0.0578
# Train Directional Accuracy: 0.4708, Test Directional Accuracy: 0.4697
# Training Time: 60.0706 seconds, Evaluation Time: 0.4308 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.0001, 'lr': 0.001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Results: Train MSE: 0.0001, Test MSE: 0.0000, Train MAE: 0.0053, Test MAE: 0.0037
# Train RMSE: 0.0082, Test RMSE: 0.0054, Train R2: 0.9998, Test R2: 0.9997
# Train MAPE: 0.0522, Test MAPE: 0.0352
# Train Directional Accuracy: 0.4683, Test Directional Accuracy: 0.4671
# Training Time: 113.6967 seconds, Evaluation Time: 0.4565 seconds
#
# Results with fixed epochs:
#
# Results: Train MSE: 0.0001, Test MSE: 0.0001, Train MAE: 0.0090, Test MAE: 0.0100
# Train RMSE: 0.0113, Test RMSE: 0.0111, Train R2: 0.9997, Test R2: 0.9988
# Train MAPE: 0.0879, Test MAPE: 0.0944
# Train Directional Accuracy: 0.4695, Test Directional Accuracy: 0.4708
# Training Time: 120.1349 seconds, Evaluation Time: 0.4549 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.0001, 'lr': 0.001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Results: Train MSE: 0.0001, Test MSE: 0.0000, Train MAE: 0.0053, Test MAE: 0.0038
# Train RMSE: 0.0081, Test RMSE: 0.0054, Train R2: 0.9998, Test R2: 0.9997
# Train MAPE: 0.0526, Test MAPE: 0.0354
# Train Directional Accuracy: 0.4698, Test Directional Accuracy: 0.4704
# Training Time: 107.7720 seconds, Evaluation Time: 0.4433 seconds
#
# Results with fixed epochs:
#
# Results: Train MSE: 0.0001, Test MSE: 0.0001, Train MAE: 0.0077, Test MAE: 0.0080
# Train RMSE: 0.0102, Test RMSE: 0.0091, Train R2: 0.9997, Test R2: 0.9992
# Train MAPE: 0.0753, Test MAPE: 0.0759
# Train Directional Accuracy: 0.4702, Test Directional Accuracy: 0.4684
# Training Time: 177.9819 seconds, Evaluation Time: 0.4338 seconds
#
# Total time taken: 22283.479600429535 seconds
# Press Enter to stop the beep sound...
# Beep sound stopped.

# %%
def create_sequences(data, target, window_size):
    sequences = []
    labels = []
    for i in range(len(data) - window_size):
        seq = data[i:i + window_size]
        label = target[i + window_size]
        sequences.append(seq)
        labels.append(label)
    return np.array(sequences), np.array(labels)

def prepare_data(df, target_column, window_size, feature_columns):
    X = df[feature_columns].values
    y = df[target_column].values.reshape(-1, 1)
    
    scaler_X = MinMaxScaler()
    X_scaled = scaler_X.fit_transform(X)

    scaler_y = MinMaxScaler()
    y_scaled = scaler_y.fit_transform(y)

    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, shuffle=False)
    X_train_seq, y_train_seq = create_sequences(X_train, y_train, window_size)
    X_test_seq, y_test_seq = create_sequences(X_test, y_test, window_size)

    return X_train_seq, X_test_seq, y_train_seq, y_test_seq, scaler_y

class LSTMModel(nn.Module):
    def __init__(self, input_dim, lstm_dim, dense_dim, output_dim, num_layers=1, dropout=0.0):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_dim, lstm_dim, num_layers=num_layers, batch_first=True, dropout=(dropout if num_layers > 1 else 0))
        self.fc1 = nn.Linear(lstm_dim, dense_dim)
        self.activation = nn.Tanh()
        self.fc2 = nn.Linear(dense_dim, output_dim)

    def forward(self, x):
        x, _ = self.lstm(x)
        x = x[:, -1, :]
        x = self.fc1(x)
        x = self.activation(x)
        x = self.fc2(x)
        return x

def train_and_evaluate(df, target_column, feature_columns, params, file_prefix='results', use_early_stopping=True, plot_loss=False):
    result = {}  # Initialize result to ensure it's always defined
    try:
        # Extract parameters
        window_size = params['window_size']
        lstm_dim = params['lstm_dim']
        dense_dim = params['dense_dim']
        num_layers = params['num_layers']
        dropout = params['dropout']
        lr = params['lr']
        batch_size = params['batch_size']
        num_epochs = params['num_epochs']
        optimizer_type = params['optimizer_type']
        patience = params['patience']

        # Clear CUDA cache
        torch.cuda.empty_cache()

        # Prepare data
        X_train_seq, X_test_seq, y_train_seq, y_test_seq, scaler_y = prepare_data(df, target_column, window_size, feature_columns)

        # Convert to PyTorch tensors
        X_train_tensor = torch.tensor(X_train_seq, dtype=torch.float32).to(device)
        X_test_tensor = torch.tensor(X_test_seq, dtype=torch.float32).to(device)
        y_train_tensor = torch.tensor(y_train_seq, dtype=torch.float32).view(-1, 1).to(device)
        y_test_tensor = torch.tensor(y_test_seq, dtype=torch.float32).view(-1, 1).to(device)

        # Create data loaders
        train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
        test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
        train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
        test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

        # Model parameters
        input_dim = X_train_tensor.shape[2]
        output_dim = 1

        model = LSTMModel(input_dim, lstm_dim, dense_dim, output_dim, num_layers, dropout).to(device)

        # Define loss and optimizer
        criterion = nn.MSELoss()
        optimizer = getattr(optim, optimizer_type)(model.parameters(), lr=lr)

        # Training loop
        best_loss = float('inf')
        patience_counter = 0
        start_time = time.time()

        training_losses = []
        validation_losses = []

        for epoch in range(num_epochs):
            model.train()
            epoch_train_loss = 0
            for inputs, labels in train_loader:
                optimizer.zero_grad()
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()
                epoch_train_loss += loss.item()

            epoch_train_loss /= len(train_loader)
            training_losses.append(epoch_train_loss)

            model.eval()
            val_loss = 0
            with torch.no_grad():
                for inputs, labels in test_loader:
                    outputs = model(inputs)
                    val_loss += criterion(outputs, labels).item()

            val_loss /= len(test_loader)
            validation_losses.append(val_loss)

            if use_early_stopping:
                if val_loss < best_loss:
                    best_loss = val_loss
                    patience_counter = 0
                    torch.save(model.state_dict(), f'{file_prefix}_{target_column}_best_model.pth')
                else:
                    patience_counter += 1
                    if patience_counter >= patience:
                        break

        training_time = time.time() - start_time

        # Save the final model if early stopping was not used or not triggered
        if not use_early_stopping or patience_counter < patience:
            torch.save(model.state_dict(), f'{file_prefix}_{target_column}_final_model.pth')

        # Evaluate the model
        model.eval()
        evaluation_start_time = time.time()
        with torch.no_grad():
            train_predictions = model(X_train_tensor).cpu().numpy()
            test_predictions = model(X_test_tensor).cpu().numpy()

            # Inverse transform predictions and actual values
            y_train_seq = y_train_seq.reshape(-1, 1)
            y_test_seq = y_test_seq.reshape(-1, 1)
            train_predictions_inverse = scaler_y.inverse_transform(train_predictions)
            test_predictions_inverse = scaler_y.inverse_transform(test_predictions)
            y_train_inverse = scaler_y.inverse_transform(y_train_seq)
            y_test_inverse = scaler_y.inverse_transform(y_test_seq)

            # # Invert log transformation
            # train_predictions_inverse = np.exp(train_predictions_inverse) - 1
            # test_predictions_inverse = np.exp(test_predictions_inverse) - 1
            # y_train_inverse = np.exp(y_train_inverse) - 1
            # y_test_inverse = np.exp(y_test_inverse) - 1

            train_mse = mean_squared_error(y_train_inverse, train_predictions_inverse)
            test_mse = mean_squared_error(y_test_inverse, test_predictions_inverse)
            train_mae = mean_absolute_error(y_train_inverse, train_predictions_inverse)
            test_mae = mean_absolute_error(y_test_inverse, test_predictions_inverse)
            train_rmse = np.sqrt(train_mse)
            test_rmse = np.sqrt(test_mse)
            train_r2 = r2_score(y_train_inverse, train_predictions_inverse)
            test_r2 = r2_score(y_test_inverse, test_predictions_inverse)

            train_mape = np.mean(np.abs((y_train_inverse - train_predictions_inverse) / y_train_inverse)) * 100
            test_mape = np.mean(np.abs((y_test_inverse - test_predictions_inverse) / y_test_inverse)) * 100

            train_directional_acc = np.mean(np.sign(y_train_inverse[1:] - y_train_inverse[:-1]) == np.sign(train_predictions_inverse[1:] - train_predictions_inverse[:-1]))
            test_directional_acc = np.mean(np.sign(y_test_inverse[1:] - y_test_inverse[:-1]) == np.sign(test_predictions_inverse[1:] - test_predictions_inverse[:-1]))

        evaluation_time = time.time() - evaluation_start_time

        result = {
            "window_size": window_size,
            "lstm_dim": lstm_dim,
            "num_layers": num_layers,
            "dense_dim": dense_dim,
            "dropout": dropout,
            "lr": lr,
            "batch_size": batch_size,
            "num_epochs": num_epochs,
            "optimizer_type": optimizer_type,
            "train_mse": train_mse,
            "test_mse": test_mse,
            "train_mae": train_mae,
            "test_mae": test_mae,
            "train_rmse": train_rmse,
            "test_rmse": test_rmse,
            "train_r2": train_r2,
            "test_r2": test_r2,
            "train_mape": train_mape,
            "test_mape": test_mape,
            "train_directional_acc": train_directional_acc,
            "test_directional_acc": test_directional_acc,
            "training_time": training_time,
            "evaluation_time": evaluation_time,
            "patience": patience
        }

        # Save result to a CSV file
        with open(f'{file_prefix}_{target_column}.csv', 'a', newline='') as f:
            writer = csv.DictWriter(f, fieldnames=result.keys())
            if f.tell() == 0:
                writer.writeheader()  # Write header only if file is empty
            writer.writerow(result)

        # Save training and validation losses to a JSON file
        losses = {
            "training_losses": training_losses,
            "validation_losses": validation_losses
        }
        with open(f'{file_prefix}_{target_column}_losses.json', 'w') as f:
            json.dump(losses, f)

        # Save predictions and actual values to a JSON file
        predictions = {
            "train_predictions": train_predictions_inverse.tolist(),
            "test_predictions": test_predictions_inverse.tolist(),
            "y_train": y_train_inverse.tolist(),
            "y_test": y_test_inverse.tolist()
        }
        with open(f'{file_prefix}_{target_column}_predictions.json', 'w') as f:
            json.dump(predictions, f)

        # Save hyperparameters to a JSON file, excluding any non-serializable types
        serializable_params = {k: v for k, v in params.items() if isinstance(v, (int, float, str, bool))}
        with open(f'{file_prefix}_{target_column}_params.json', 'w') as f:
            json.dump(serializable_params, f)

        # Print summary of the results
        print(f"Results: Train MSE: {train_mse:.4f}, Test MSE: {test_mse:.4f}, Train MAE: {train_mae:.4f}, Test MAE: {test_mae:.4f}")
        print(f"Train RMSE: {train_rmse:.4f}, Test RMSE: {test_rmse:.4f}, Train R2: {train_r2:.4f}, Test R2: {test_r2:.4f}")
        print(f"Train MAPE: {train_mape:.4f}, Test MAPE: {test_mape:.4f}")
        print(f"Train Directional Accuracy: {train_directional_acc:.4f}, Test Directional Accuracy: {test_directional_acc:.4f}")
        print(f"Training Time: {training_time:.4f} seconds, Evaluation Time: {evaluation_time:.4f} seconds\n")

        # Plot loss over epochs if specified
        if plot_loss:
            plot_loss_over_epochs(training_losses, validation_losses, f'{file_prefix}_{target_column}', start_epoch=3)

    except Exception as e:
        print(f"An error occurred: {e}")
        # Ensure result is always defined, even in case of error
        result = {
            "window_size": window_size,
            "lstm_dim": lstm_dim,
            "num_layers": num_layers,
            "dense_dim": dense_dim,
            "dropout": dropout,
            "lr": lr,
            "batch_size": batch_size,
            "num_epochs": num_epochs,
            "optimizer_type": optimizer_type,
            "error": str(e)
        }

    return result

# %%
# Start total timer
start = time.time()

# Grid search
for params in itertools.product(*parameter_space.values()):
    param_dict = dict(zip(parameter_space.keys(), params))
    print(f"Running model with parameters: {param_dict}\n")
    # Run with early stopping
    print('Results with early stopping:\n')
    train_and_evaluate(df, target_column=target_column, feature_columns=features, params=param_dict, file_prefix='results_complete5', use_early_stopping=True, plot_loss=False)
    # Run with fixed epochs
    print('Results with fixed epochs:\n')
    train_and_evaluate(df, target_column=target_column, feature_columns=features, params=param_dict, file_prefix='results_complete5_fixed', use_early_stopping=False, plot_loss=False)

# Calculate total time
end = time.time()
total_time = end - start

# Print the total time taken
print(f"Total time taken: {total_time} seconds")

# Function to play a beep sound in a loop
def play_beep():
    while not stop_beep_flag:
        winsound.Beep(2000, 600)
        time.sleep(0.7)
        
# Start the beep sound
stop_beep_flag = False
beep_thread = Thread(target=play_beep)
beep_thread.start()

input("Press Enter to stop the beep sound...")
stop_beep_flag = True
beep_thread.join()
print("Beep sound stopped.")
# Out:
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 50, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Results: Train MSE: 92285.7046, Test MSE: 81719.2967, Train MAE: 171.0536, Test MAE: 165.1405
# Train RMSE: 303.7856, Test RMSE: 285.8659, Train R2: 0.9996, Test R2: 0.9996
# Train MAPE: 0.5729, Test MAPE: 0.3653
# Train Directional Accuracy: 0.4658, Test Directional Accuracy: 0.4679
# Training Time: 49.9402 seconds, Evaluation Time: 0.1813 seconds
#
# Results with fixed epochs:
#
# Results: Train MSE: 98398.3183, Test MSE: 95692.2604, Train MAE: 178.2315, Test MAE: 188.2710
# Train RMSE: 313.6851, Test RMSE: 309.3417, Train R2: 0.9996, Test R2: 0.9995
# Train MAPE: 0.5911, Test MAPE: 0.4161
# Train Directional Accuracy: 0.4627, Test Directional Accuracy: 0.4617
# Training Time: 50.6274 seconds, Evaluation Time: 0.1592 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Results: Train MSE: 84286.9953, Test MSE: 83252.4676, Train MAE: 171.1171, Test MAE: 184.6332
# Train RMSE: 290.3222, Test RMSE: 288.5350, Train R2: 0.9997, Test R2: 0.9996
# Train MAPE: 0.5712, Test MAPE: 0.4279
# Train Directional Accuracy: 0.4670, Test Directional Accuracy: 0.4705
# Training Time: 100.4790 seconds, Evaluation Time: 0.1757 seconds
#
# Results with fixed epochs:
#
# Results: Train MSE: 82601.0883, Test MSE: 80693.2502, Train MAE: 163.6342, Test MAE: 173.5274
# Train RMSE: 287.4041, Test RMSE: 284.0656, Train R2: 0.9997, Test R2: 0.9996
# Train MAPE: 0.
Train R2: 0.9997, Test R2: 0.9996
# Train MAPE: 0.5030, Test MAPE: 0.3493
# Train Directional Accuracy: 0.4690, Test Directional Accuracy: 0.4689
# Training Time: 117.1944 seconds, Evaluation Time: 0.4579 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.0001, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Results: Train MSE: 67567.5721, Test MSE: 68221.3020, Train MAE: 145.3200, Test MAE: 152.7802
# Train RMSE: 259.9376, Test RMSE: 261.1921, Train R2: 0.9997, Test R2: 0.9997
# Train MAPE: 0.4818, Test MAPE: 0.3341
# Train Directional Accuracy: 0.4727, Test Directional Accuracy: 0.4696
# Training Time: 176.6695 seconds, Evaluation Time: 0.4759 seconds
#
# Results with fixed epochs:
#
# Results: Train MSE: 75296.1456, Test MSE: 88913.0025, Train MAE: 162.6423, Test MAE: 198.7818
# Train RMSE: 274.4014, Test RMSE: 298.1828, Train R2: 0.9997, Test R2: 0.9996
# Train MAPE: 0.5374, Test MAPE: 0.4475
# Train Directional Accuracy: 0.4708, Test Directional Accuracy: 0.4713
# Training Time: 177.5327 seconds, Evaluation Time: 0.4539 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.0001, 'lr': 0.001, 'num_epochs': 50, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Results: Train MSE: 175567.4099, Test MSE: 323283.5407, Train MAE: 289.4023, Test MAE: 464.8919
# Train RMSE: 419.0076, Test RMSE: 568.5803, Train R2: 0.9993, Test R2: 0.9984
# Train MAPE: 0.8906, Test MAPE: 1.0629
# Train Directional Accuracy: 0.4695, Test Directional Accuracy: 0.4688
# Training Time: 59.4560 seconds, Evaluation Time: 0.4795 seconds
#
# Results with fixed epochs:
#
# Results: Train MSE: 131584.9534, Test MSE: 179347.1262, Train MAE: 242.5976, Test MAE: 347.7932
# Train RMSE: 362.7464, Test RMSE: 423.4940, Train R2: 0.9995, Test R2: 0.9991
# Train MAPE: 0.7796, Test MAPE: 0.8326
# Train Directional Accuracy: 0.4708, Test Directional Accuracy: 0.4722
# Training Time: 59.6388 seconds, Evaluation Time: 0.4664 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.0001, 'lr': 0.001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Results: Train MSE: 114090.1980, Test MSE: 194241.2302, Train MAE: 219.2773, Test MAE: 336.5634
# Train RMSE: 337.7724, Test RMSE: 440.7281, Train R2: 0.9996, Test R2: 0.9991
# Train MAPE: 0.6810, Test MAPE: 0.7597
# Train Directional Accuracy: 0.4696, Test Directional Accuracy: 0.4696
# Training Time: 105.1811 seconds, Evaluation Time: 0.4489 seconds
#
# Results with fixed epochs:
#
# Results: Train MSE: 66536.3577, Test MSE: 62745.8283, Train MAE: 142.7028, Test MAE: 140.3771
# Train RMSE: 257.9464, Test RMSE: 250.4912, Train R2: 0.9997, Test R2: 0.9997
# Train MAPE: 0.4739, Test MAPE: 0.3091
# Train Directional Accuracy: 0.4690, Test Directional Accuracy: 0.4677
# Training Time: 117.0854 seconds, Evaluation Time: 0.4694 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.0001, 'lr': 0.001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Results: Train MSE: 90863.1170, Test MSE: 134337.0664, Train MAE: 182.5792, Test MAE: 259.2161
# Train RMSE: 301.4351, Test RMSE: 366.5202, Train R2: 0.9996, Test R2: 0.9994
# Train MAPE: 0.5670, Test MAPE: 0.5726
# Train Directional Accuracy: 0.4675, Test Directional Accuracy: 0.4699
# Training Time: 130.2494 seconds, Evaluation Time: 0.4785 seconds
#
# Results with fixed epochs:
#
# Results: Train MSE: 74772.0890, Test MSE: 71395.3986, Train MAE: 166.1625, Test MAE: 174.1263
# Train RMSE: 273.4449, Test RMSE: 267.1992, Train R2: 0.9997, Test R2: 0.9997
# Train MAPE: 0.5895, Test MAPE: 0.4074
# Train Directional Accuracy: 0.4697, Test Directional Accuracy: 0.4689
# Training Time: 176.4575 seconds, Evaluation Time: 0.4835 seconds
#
# Total time taken: 24246.54213452339 seconds
# Press Enter to stop the beep sound...
# Beep sound stopped.

# %%
# Define target column
target_column = ['log_close']

# Define feature combination
features = ['log_open', 'log_high', 'log_low', 'log_close', 'volume',
       'quote_vol', 'count', 'buy_base', 'buy_quote', 'open_p', 'high_p', 'low_p', 'close_p']

# %%
# Start total timer
start = time.time()

# Grid search
for params in itertools.product(*parameter_space.values()):
    param_dict = dict(zip(parameter_space.keys(), params))
    print(f"Running model with parameters: {param_dict}\n")
    # Run with early stopping
    print('Results with early stopping:\n')
    train_and_evaluate(df, target_column=target_column, feature_columns=features, params=param_dict, file_prefix='results_complete6', use_early_stopping=True, plot_loss=False)
    # Run with fixed epochs
    print('Results with fixed epochs:\n')
    train_and_evaluate(df, target_column=target_column, feature_columns=features, params=param_dict, file_prefix='results_complete6_(fixed)', use_early_stopping=False, plot_loss=False)

# Calculate total time
end = time.time()
total_time = end - start

# Print the total time taken
print(f"Total time taken: {total_time} seconds")

# Function to play a beep sound in a loop
def play_beep():
    while not stop_beep_flag:
        winsound.Beep(2000, 600)
        time.sleep(0.7)
        
# Start the beep sound
stop_beep_flag = False
beep_thread = Thread(target=play_beep)
beep_thread.start()


input("Press Enter to stop the beep sound...")
stop_beep_flag = True
beep_thread.join()
print("Beep sound stopped.")
# Out:
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 50, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Results: Train MSE: 105412.6889, Test MSE: 101252.8078, Train MAE: 192.3417, Test MAE: 203.8002
# Train RMSE: 324.6732, Test RMSE: 318.2025, Train R2: 0.9996, Test R2: 0.9995
# Train MAPE: 0.6307, Test MAPE: 0.4670
# Train Directional Accuracy: 0.4652, Test Directional Accuracy: 0.4691
# Training Time: 50.7363 seconds, Evaluation Time: 0.1807 seconds
#
# Results with fixed epochs:
#
# Results: Train MSE: 103390.7881, Test MSE: 122094.7894, Train MAE: 191.9788, Test MAE: 241.4375
# Train RMSE: 321.5444, Test RMSE: 349.4206, Train R2: 0.9996, Test R2: 0.9994
# Train MAPE: 0.6163, Test MAPE: 0.5464
# Train Directional Accuracy: 0.4669, Test Directional Accuracy: 0.4684
# Training Time: 50.3618 seconds, Evaluation Time: 0.1747 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Results: Train MSE: 131743.4866, Test MSE: 213591.1795, Train MAE: 241.3310, Test MAE: 360.4016
# Train RMSE: 362.9649, Test RMSE: 462.1593, Train R2: 0.9995, Test R2: 0.9990
# Train MAPE: 0.7751, Test MAPE: 0.8240
# Train Directional Accuracy: 0.4714, Test Directional Accuracy: 0.4717
# Training Time: 91.6508 seconds, Evaluation Time: 0.1651 seconds
#
# Results with fixed epochs:
#
# Results: Train MSE: 75849.9215, Test MSE: 72011.6084, Train MAE: 154.7139, Test MAE: 153.5688
# Train RMSE: 275.4086, Test RMSE: 268.3498, Train R2: 0.9997, Test R2: 0.9997
# Train MAPE: 0.5118, Test MAPE: 0.3390
# Train Directional Accuracy: 0.4696, Test Directional Accuracy: 0.4729
# Training Time: 99.4570 seconds, Evaluation Time: 0.2197 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Results: Train MSE: 71013.2804, Test MSE: 74641.4418, Train MAE: 150.7069, Test MAE: 164.2065
# Train RMSE: 266.4832, Test RMSE: 273.2059, Train R2: 0.9997, Test R2: 0.9996
# Train MAPE: 0.4972, Test MAPE: 0.3627
# Train Directional Accuracy: 0.4717, Test Directional Accuracy: 0.4696
# Training Time: 151.1457 seconds, Evaluation Time: 0.1656 seconds
#
# Results with fixed epochs:
#
# Results: Train MSE: 71026.1442, Test MSE: 76162.9805, Train MAE: 153.3315, Test MAE: 165.7583
# Train RMSE: 266.5073, Test RMSE: 275.9764, Train R2: 0.9997, Test R2: 0.9996
# Train MAPE: 0.5146, Test MAPE: 0.3654
# Train Directional Accuracy: 0.4726, Test Directional Accuracy: 0.4714
# Training Time: 152.2619 seconds, Evaluation Time: 0.1701 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.001, 'num_epochs': 50, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Results: Train MSE: 72219.4370, Test MSE: 89723.0418, Train MAE: 155.1002, Test MAE: 190.8654
# Train RMSE: 268.7367, Test RMSE: 299.5380, Train R2: 0.9997, Test R2: 0.9996
# Train MAPE: 0.5077, Test MAPE: 0.4182
# Train Directional Accuracy: 0.4733, Test Directional Accuracy: 0.4693
# Training Time: 50.1081 seconds, Evaluation Time: 0.1692 seconds
#
# Results with fixed epochs:
#
# Results: Train MSE:
Train R2: 0.9997, Test R2: 0.9996
# Train MAPE: 0.5063, Test MAPE: 0.4188
# Train Directional Accuracy: 0.4718, Test Directional Accuracy: 0.4716
# Training Time: 190.4224 seconds, Evaluation Time: 0.4383 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.0001, 'lr': 0.001, 'num_epochs': 50, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Results: Train MSE: 169807.4467, Test MSE: 303866.2014, Train MAE: 287.3675, Test MAE: 440.8696
# Train RMSE: 412.0770, Test RMSE: 551.2406, Train R2: 0.9993, Test R2: 0.9985
# Train MAPE: 0.9103, Test MAPE: 1.0014
# Train Directional Accuracy: 0.4711, Test Directional Accuracy: 0.4703
# Training Time: 63.7722 seconds, Evaluation Time: 0.4545 seconds
#
# Results with fixed epochs:
#
# Results: Train MSE: 139784.3420, Test MSE: 199408.8568, Train MAE: 241.0636, Test MAE: 338.6584
# Train RMSE: 373.8774, Test RMSE: 446.5522, Train R2: 0.9995, Test R2: 0.9990
# Train MAPE: 0.7325, Test MAPE: 0.7604
# Train Directional Accuracy: 0.4717, Test Directional Accuracy: 0.4745
# Training Time: 63.5032 seconds, Evaluation Time: 0.4561 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.0001, 'lr': 0.001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Results: Train MSE: 71418.0539, Test MSE: 66121.1711, Train MAE: 153.4838, Test MAE: 153.7050
# Train RMSE: 267.2416, Test RMSE: 257.1404, Train R2: 0.9997, Test R2: 0.9997
# Train MAPE: 0.5096, Test MAPE: 0.3462
# Train Directional Accuracy: 0.4711, Test Directional Accuracy: 0.4696
# Training Time: 120.6005 seconds, Evaluation Time: 0.4674 seconds
#
# Results with fixed epochs:
#
# Results: Train MSE: 116775.3443, Test MSE: 194122.5111, Train MAE: 226.8968, Test MAE: 341.9116
# Train RMSE: 341.7241, Test RMSE: 440.5934, Train R2: 0.9995, Test R2: 0.9991
# Train MAPE: 0.7198, Test MAPE: 0.7793
# Train Directional Accuracy: 0.4700, Test Directional Accuracy: 0.4713
# Training Time: 126.9773 seconds, Evaluation Time: 0.4559 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.0001, 'lr': 0.001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Results: Train MSE: 142499.2246, Test MSE: 242031.3374, Train MAE: 260.1991, Test MAE: 392.5267
# Train RMSE: 377.4907, Test RMSE: 491.9668, Train R2: 0.9994, Test R2: 0.9988
# Train MAPE: 0.8244, Test MAPE: 0.8995
# Train Directional Accuracy: 0.4709, Test Directional Accuracy: 0.4730
# Training Time: 93.1849 seconds, Evaluation Time: 0.4402 seconds
#
# Results with fixed epochs:
#
# Results: Train MSE: 85366.7856, Test MSE: 97153.6555, Train MAE: 173.4571, Test MAE: 210.6157
# Train RMSE: 292.1759, Test RMSE: 311.6948, Train R2: 0.9997, Test R2: 0.9995
# Train MAPE: 0.5585, Test MAPE: 0.4747
# Train Directional Accuracy: 0.4719, Test Directional Accuracy: 0.4646
# Training Time: 189.8218 seconds, Evaluation Time: 0.4705 seconds
#
# Total time taken: 22366.196262598038 seconds
# Press Enter to stop the beep sound...
# Beep sound stopped.

# %%
# Define target column
target_column = ['close']

# Define feature combination
features = ['open', 'high', 'low', 'close', 'volume',
       'quote_vol', 'count', 'buy_base', 'buy_quote']

# %%
# Start total timer
start = time.time()

# Grid search
for params in itertools.product(*parameter_space.values()):
    param_dict = dict(zip(parameter_space.keys(), params))
    print(f"Running model with parameters: {param_dict}\n")
    # Run with early stopping
    print('Results with early stopping:\n')
    train_and_evaluate(df, target_column=target_column, feature_columns=features, params=param_dict, file_prefix='results_complete7', use_early_stopping=True, plot_loss=False)
    # Run with fixed epochs
    print('Results with fixed epochs:\n')
    train_and_evaluate(df, target_column=target_column, feature_columns=features, params=param_dict, file_prefix='results_complete7_(fixed)', use_early_stopping=False, plot_loss=False)

# Calculate total time
end = time.time()
total_time = end - start

# Print the total time taken
print(f"Total time taken: {total_time} seconds")
# Out:
# Running model with parameters: {'window_size': 24, 'lstm_dim': 96, 'dense_dim': 96, 'num_layers': 1, 'dropout': 0.001, 'lr': 0.0001, 'num_epochs': 50, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Results: Train MSE: 76069.6537, Test MSE: 66389.5368, Train MAE: 158.5131, Test MAE: 144.2361
# Train RMSE: 275.8073, Test RMSE: 257.6617, Train R2: 0.9997, Test R2: 0.9997
# Train MAPE: 0.
seconds
#
# Results with fixed epochs:
#
# Results: Train MSE: 124715.2215, Test MSE: 167586.5111, Train MAE: 269.6814, Test MAE: 343.6858
# Train RMSE: 353.1504, Test RMSE: 409.3733, Train R2: 0.9995, Test R2: 0.9992
# Train MAPE: 1.0774, Test MAPE: 0.8509
# Train Directional Accuracy: 0.4680, Test Directional Accuracy: 0.4701
# Training Time: 179.7049 seconds, Evaluation Time: 0.4189 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.0001, 'lr': 0.001, 'num_epochs': 50, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Results: Train MSE: 66493.3461, Test MSE: 65905.7555, Train MAE: 149.8710, Test MAE: 161.0038
# Train RMSE: 257.8630, Test RMSE: 256.7212, Train R2: 0.9997, Test R2: 0.9997
# Train MAPE: 0.5269, Test MAPE: 0.3751
# Train Directional Accuracy: 0.4709, Test Directional Accuracy: 0.4663
# Training Time: 59.6252 seconds, Evaluation Time: 0.4009 seconds
#
# Results with fixed epochs:
#
# Results: Train MSE: 65816.5560, Test MSE: 61954.5852, Train MAE: 143.0347, Test MAE: 142.1772
# Train RMSE: 256.5474, Test RMSE: 248.9068, Train R2: 0.9997, Test R2: 0.9997
# Train MAPE: 0.4799, Test MAPE: 0.3168
# Train Directional Accuracy: 0.4688, Test Directional Accuracy: 0.4669
# Training Time: 59.4665 seconds, Evaluation Time: 0.3978 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.0001, 'lr': 0.001, 'num_epochs': 100, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Results: Train MSE: 157962.1158, Test MSE: 262830.7106, Train MAE: 299.6183, Test MAE: 427.6226
# Train RMSE: 397.4445, Test RMSE: 512.6702, Train R2: 0.9994, Test R2: 0.9987
# Train MAPE: 1.1086, Test MAPE: 1.0114
# Train Directional Accuracy: 0.4703, Test Directional Accuracy: 0.4679
# Training Time: 57.8022 seconds, Evaluation Time: 0.4023 seconds
#
# Results with fixed epochs:
#
# Results: Train MSE: 65018.9386, Test MSE: 65212.0305, Train MAE: 142.6175, Test MAE: 147.9387
# Train RMSE: 254.9881, Test RMSE: 255.3665, Train R2: 0.9997, Test R2: 0.9997
# Train MAPE: 0.4753, Test MAPE: 0.3269
# Train Directional Accuracy: 0.4693, Test Directional Accuracy: 0.4668
# Training Time: 120.6757 seconds, Evaluation Time: 0.3998 seconds
#
# Running model with parameters: {'window_size': 24, 'lstm_dim': 150, 'dense_dim': 150, 'num_layers': 1, 'dropout': 0.0001, 'lr': 0.001, 'num_epochs': 150, 'batch_size': 64, 'optimizer_type': 'Adam', 'patience': 24, 'activation_function': <class 'torch.nn.modules.activation.Tanh'>}
#
# Results with early stopping:
#
# Results: Train MSE: 89741.6334, Test MSE: 126024.4200, Train MAE: 188.1906, Test MAE: 265.6593
# Train RMSE: 299.5691, Test RMSE: 354.9992, Train R2: 0.9997, Test R2: 0.9994
# Train MAPE: 0.6060, Test MAPE: 0.6162
# Train Directional Accuracy: 0.4689, Test Directional Accuracy: 0.4672
# Training Time: 68.4327 seconds, Evaluation Time: 0.4036 seconds
#
# Results with fixed epochs:
#
# Results: Train MSE: 64753.8038, Test MSE: 62875.8481, Train MAE: 146.6504, Test MAE: 144.3378
# Train RMSE: 254.4677, Test RMSE: 250.7506, Train R2: 0.9997, Test R2: 0.9997
# Train MAPE: 0.5281, Test MAPE: 0.3200
# Train Directional Accuracy: 0.4691, Test Directional Accuracy: 0.4652
# Training Time: 179.6851 seconds, Evaluation Time: 0.4013 seconds
#
# Total time taken: 21101.441566467285 seconds

# %%
# Define target column
target_column = ['close']

# Define feature combination
features = ['open', 'high', 'low', 'close', 'volume',
       'quote_vol', 'count', 'buy_base', 'buy_quote', 'open_p', 'high_p', 'low_p', 'close_p']

# %%
# Start total timer
start = time.time()

# Grid search
for params in itertools.product(*parameter_space.values()):
    param_dict = dict(zip(parameter_space.keys(), params))
    print(f"Running model with parameters: {param_dict}\n")
    # Run with early stopping
    print('Results with early stopping:\n')
    train_and_evaluate(df, target_column=target_column, feature_columns=features, params=param_dict, file_prefix='results_complete8', use_early_stopping=True, plot_loss=False)
    # Run with fixed epochs
    print('Results with fixed epochs:\n')
    train_and_evaluate(df, target_column=target_column, feature_columns=features, params=param_dict, file_prefix='